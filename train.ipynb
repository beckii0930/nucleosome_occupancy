# %%
# !pip install theano
# Out:
# Requirement already satisfied: theano in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (1.0.5)
# Requirement already satisfied: scipy>=0.14 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from theano) (1.7.0)
# Requirement already satisfied: six>=1.9.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from theano) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from theano) (1.19.5)

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/yibeijiang/Library/Python/3.6/lib/python/site-packages (21.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade virtualenv
# Out:
# Requirement already satisfied: virtualenv in /Users/yibeijiang/Library/Python/3.6/lib/python/site-packages (20.4.7)
# Requirement already satisfied: six<2,>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from virtualenv) (1.15.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from virtualenv) (4.6.1)
# Requirement already satisfied: filelock<4,>=3.0.0 in /Users/yibeijiang/Library/Python/3.6/lib/python/site-packages (from virtualenv) (3.0.12)
# Requirement already satisfied: appdirs<2,>=1.4.3 in /Users/yibeijiang/Library/Python/3.6/lib/python/site-packages (from virtualenv) (1.4.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in /Users/yibeijiang/Library/Python/3.6/lib/python/site-packages (from virtualenv) (0.3.2)
# Requirement already satisfied: importlib-resources>=1.0 in /Users/yibeijiang/Library/Python/3.6/lib/python/site-packages (from virtualenv) (5.2.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from importlib-metadata>=0.12->virtualenv) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from importlib-metadata>=0.12->virtualenv) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from h5py) (1.19.5)

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.7.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.0.1)

# %%
# !pip install keras==2.4.3
# Out:
# Collecting keras==2.4.3
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: scipy>=0.14 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from keras==2.4.3) (1.7.0)
# Requirement already satisfied: h5py in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from keras==2.4.3) (3.1.0)
# Requirement already satisfied: pyyaml in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from keras==2.4.3) (5.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from keras==2.4.3) (1.19.5)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.2.4
#     Uninstalling Keras-2.2.4:
#       Successfully uninstalled Keras-2.2.4
# Successfully installed keras-2.4.3

# %%
# !pip install tensorflow==2.5.0
# Out:
# Requirement already satisfied: tensorflow==2.5.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (2.5.0)
# Requirement already satisfied: tensorboard~=2.5 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (2.6.0)
# Requirement already satisfied: wheel~=0.35 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (0.36.2)
# Requirement already satisfied: flatbuffers~=1.12.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.12)
# Requirement already satisfied: absl-py~=0.10 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (0.13.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (3.17.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (3.7.4.3)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (2.5.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (2.5.0.dev2021032900)
# Requirement already satisfied: six~=1.15.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.15.0)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.12.1)
# Requirement already satisfied: astunparse~=1.6.3 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (0.2.0)
# Requirement already satisfied: gast==0.4.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (0.4.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (3.3.0)
# Requirement already satisfied: grpcio~=1.34.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.34.1)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.1.0)
# Requirement already satisfied: h5py~=3.1.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (3.1.0)
# Requirement already satisfied: numpy~=1.19.2 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.19.5)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.34.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.4.5)
# Requirement already satisfied: markdown>=2.6.8 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (49.6.0.post20210108)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/yibeijia/miniconda2/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (3.1.1)

# %%
import numpy as np
import h5py
import scipy.io
from sklearn import metrics
import pandas as pd
import os
os.environ['THEANO_FLAGS'] = "device=cuda0,force_device=True,floatX=float32,gpuarray.preallocate=0.3"
import theano
print(theano.config.device)
from keras.layers import Embedding
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten, Layer, merge, Input, Concatenate, Reshape, concatenate,Lambda,multiply,Permute,Reshape,RepeatVector
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers.pooling import GlobalMaxPooling1D
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import optimizers
from keras import backend as K
from keras import regularizers
# Out:
# cuda0

# %% [markdown]
# ### Load data (training and validation)

# %%
data_folder = "./data/nucleosome_occupancy_train/"

#trainmat = h5py.File(data_folder+'train.mat')
trainmat = h5py.File(data_folder+'train.mat')
validmat = scipy.io.loadmat(data_folder+'valid.mat')

X_train = np.transpose(np.array(trainmat['trainxdata']),axes=(2,0,1))
y_train = np.array(trainmat['traindata']).T

trainmat.close()

# %% [markdown]
# ### Choose only the targets that correspond to the TF binding

# %%
y_train = y_train[:,125:815]

# %% [markdown]
# ### Run TBiNet

# %%
sequence_input = Input(shape=(1000,4))

# Convolutional Layer
output = Conv1D(320,kernel_size=26,padding="valid",activation="relu")(sequence_input)
output = MaxPooling1D(pool_size=13, strides=13)(output)
output = Dropout(0.2)(output)

#Attention Layer
attention = Dense(1)(output)
attention = Permute((2, 1))(attention)
attention = Activation('softmax')(attention)
attention = Permute((2, 1))(attention)
attention = Lambda(lambda x: K.mean(x, axis=2), name='attention',output_shape=(75,))(attention)
attention = RepeatVector(320)(attention)
attention = Permute((2,1))(attention)
output = multiply([output, attention])

#BiLSTM Layer
output = Bidirectional(LSTM(320,return_sequences=True))(output)
output = Dropout(0.5)(output)

flat_output = Flatten()(output)

#FC Layer
FC_output = Dense(695)(flat_output)
FC_output = Activation('relu')(FC_output)

#Output Layer
output = Dense(690)(FC_output)
output = Activation('sigmoid')(output)

model = Model(inputs=sequence_input, outputs=output)

print('compiling model')
model.compile(loss='binary_crossentropy', optimizer='adam')

print('model summary')
model.summary()

checkpointer = ModelCheckpoint(filepath="./model/tbinet.{epoch:02d}-{val_loss:.2f}.hdf5", verbose=1, save_best_only=False)
earlystopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

model.fit(X_train, y_train, batch_size=100, epochs=60, shuffle=True, verbose=1, validation_data=(np.transpose(validmat['validxdata'],axes=(0,2,1)),validmat['validdata'][:,125:815]), callbacks=[checkpointer,earlystopper])

model.save('./model/tbinet.h5')
