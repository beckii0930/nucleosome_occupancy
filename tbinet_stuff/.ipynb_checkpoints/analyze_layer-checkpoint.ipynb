# %%
import numpy as np
import scipy.io
from sklearn import metrics
import pandas as pd
import os
# os.environ['THEANO_FLAGS'] = "device=cuda0,force_device=True,floatX=float32"
# from aesara_theano_fallback import aesara as theano
#import theano

# print(theano.config.device)
# import sys, getopt
import tensorflow.keras as keras
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.layers import Embedding
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten, Layer, merge, Input, Concatenate, Reshape
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers.pooling import GlobalMaxPooling1D
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import backend as K
import tensorflow.keras as keras
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
data_folder = "/Users/yibeijia/Downloads/nucleosome_occupancy/tbinet_stuff/model2/"

data_folder = "/Users/yibeijia/Downloads/nucleosome_occupancy/tbinet_stuff/model2_reduced_dense10/"
model = load_model(data_folder+"tbinet.h5")
model.load_weights("/Users/yibeijia/Downloads/nucleosome_occupancy/tbinet_stuff//model2_reduced_dense10/tbinet.38-0.08.hdf5")
# model.load_weights("/Users/yibeijia/Downloads/nucleosome_occupancy/tbinet_stuff/model2/tbinet.22-0.21.hdf5")

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 147, 4)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 138, 320)     13120       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 134, 320)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 134, 320)     0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 134, 1)       321         dropout[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 1, 134)       0           dense[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 134)       0           permute[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 134, 1)       0           activation[0][0]
# __________________________________________________________________________________________________
# attention2 (Lambda)             (None, 134)          0           permute_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 320, 134)     0           attention2[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 134, 320)     0           repeat_vector[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 134, 320)     0           dropout[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 134, 640)     1640960     multiply[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 134, 640)     0           bidirectional[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 85760)        0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           857610      flatten[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            11          activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1)            0           dense_2[0][0]
# ==================================================================================================
# Total params: 2,512,022
# Trainable params: 2,512,022
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
layer_names = [layer.name for layer in model.layers]
layer_names
# Out:
# ['input_1',
#  'conv1d',
#  'max_pooling1d',
#  'dropout',
#  'dense',
#  'permute',
#  'activation',
#  'permute_1',
#  'attention2',
#  'repeat_vector',
#  'permute_2',
#  'multiply',
#  'bidirectional',
#  'dropout_1',
#  'flatten',
#  'dense_1',
#  'activation_1',
#  'dense_2',
#  'activation_2']

# %%
attention = model.layers[8]
attention

# %%
layer_outputs = [layer.output for layer in model.layers]
layer_outputs
# Out:
# [<KerasTensor: shape=(None, 147, 4) dtype=float32 (created by layer 'input_1')>,
#  <KerasTensor: shape=(None, 138, 320) dtype=float32 (created by layer 'conv1d')>,
#  <KerasTensor: shape=(None, 134, 320) dtype=float32 (created by layer 'max_pooling1d')>,
#  <KerasTensor: shape=(None, 134, 320) dtype=float32 (created by layer 'dropout')>,
#  <KerasTensor: shape=(None, 134, 1) dtype=float32 (created by layer 'dense')>,
#  <KerasTensor: shape=(None, 1, 134) dtype=float32 (created by layer 'permute')>,
#  <KerasTensor: shape=(None, 1, 134) dtype=float32 (created by layer 'activation')>,
#  <KerasTensor: shape=(None, 134, 1) dtype=float32 (created by layer 'permute_1')>,
#  <KerasTensor: shape=(None, 134) dtype=float32 (created by layer 'attention2')>,
#  <KerasTensor: shape=(None, 320, 134) dtype=float32 (created by layer 'repeat_vector')>,
#  <KerasTensor: shape=(None, 134, 320) dtype=float32 (created by layer 'permute_2')>,
#  <KerasTensor: shape=(None, 134, 320) dtype=float32 (created by layer 'multiply')>,
#  <KerasTensor: shape=(None, 134, 640) dtype=float32 (created by layer 'bidirectional')>,
#  <KerasTensor: shape=(None, 134, 640) dtype=float32 (created by layer 'dropout_1')>,
#  <KerasTensor: shape=(None, 85760) dtype=float32 (created by layer 'flatten')>,
#  <KerasTensor: shape=(None, 10) dtype=float32 (created by layer 'dense_1')>,
#  <KerasTensor: shape=(None, 10) dtype=float32 (created by layer 'activation_1')>,
#  <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_2')>,
#  <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'activation_2')>]

# %%
feature_map_model = tf.keras.models.Model(inputs=model.inputs, outputs=layer_outputs)

# %%
def ReverseOneHotEncode(arr):
    seq = ''
    nuc_map = ['A', 'C', 'G', 'T']
    for subarr in arr:
        nuc = nuc_map[np.argmax(subarr)]
        seq+=nuc
    return seq;

def writeSeqToFile(d,ones,zeros):
    fname = '/Users/yibeijia/Downloads/nucleosome_occupancy/data/SeqsForFeature.txt'
    out = 'Enriched:\n'
    for i in ones:
#         print(d[i])
        seq = ReverseOneHotEncode(d[i])
        out = out + str(1) + ' ' + seq + '\n'
    out += 'Depleted:\n'
    for i in zeros:
#         print(d[i])
        seq = ReverseOneHotEncode(d[i])
        out = out + str(0) + ' ' + seq + '\n'
    with open(fname, 'w+') as f:
        f.write(out)
#     return out;

# %%
# data_folder = "./data/"
data_folder = "/Users/yibeijia/Downloads/nucleosome_occupancy/data/train_test_data/"
testmat = scipy.io.loadmat(data_folder+'Test_data.mat')
d = testmat['Test_data'][::1000]

labels = testmat['Test_labels']
# print(f"labels.shape: {labels.shape}")
# print(f"labels: {labels}")
# new_labels = labels[0][:10000]
new_labels = labels[0][::1000]
print(f"new_labels.shape: {new_labels.shape}")
ones = np.flatnonzero(new_labels == np.max(new_labels))
zeros = np.flatnonzero(new_labels == np.min(new_labels))
print(f'ones.shape {ones.shape}')
print(f'zeros.shape {zeros.shape}')
# print(ones)
# print(zeros)

writeSeqToFile(d,ones,zeros)
# print(f"Total Test Seq is: {len(testmat['Test_data'])}, we take: {len(d)}")
feature_maps = feature_map_model.predict(np.transpose(d,axes=(0,1,2)))
# testmat = scipy.io.loadmat(data_folder+'SampleTest.mat')
# feature_maps = feature_map_model.predict(np.transpose(testmat['Test_data'],axes=(0,1,2)))
# feature_maps = feature_map_model.predict(np.transpose(testmat['Test_data'],axes=(0,1,2))[::1000])
# feature_maps = feature_map_model.predict(np.transpose(testmat['Test_data'],axes=(0,1,2))[:10000])
# feature_maps = model.predict(testmat['Test_data'])
# Out:
# new_labels.shape: (151,)
# ones.shape (73,)
# zeros.shape (78,)

# %%
# The last shape parameter, the number of channels, tells how many features there are for that layer
for layer_name, feature_map in zip(layer_names, feature_maps):print(f"The shape of the {layer_name} is =======>> {feature_map.shape}")
# Out:
# The shape of the input_1 is =======>> (151, 147, 4)
# The shape of the conv1d is =======>> (151, 138, 320)
# The shape of the max_pooling1d is =======>> (151, 134, 320)
# The shape of the dropout is =======>> (151, 134, 320)
# The shape of the dense is =======>> (151, 134, 1)
# The shape of the permute is =======>> (151, 1, 134)
# The shape of the activation is =======>> (151, 1, 134)
# The shape of the permute_1 is =======>> (151, 134, 1)
# The shape of the attention2 is =======>> (151, 134)
# The shape of the repeat_vector is =======>> (151, 320, 134)
# The shape of the permute_2 is =======>> (151, 134, 320)
# The shape of the multiply is =======>> (151, 134, 320)
# The shape of the bidirectional is =======>> (151, 134, 640)
# The shape of the dropout_1 is =======>> (151, 134, 640)
# The shape of the flatten is =======>> (151, 85760)
# The shape of the dense_1 is =======>> (151, 10)
# The shape of the activation_1 is =======>> (151, 10)
# The shape of the dense_2 is =======>> (151, 1)
# The shape of the activation_2 is =======>> (151, 1)

# %%
def plot_feature_map(y, plt_title):
    plt.rcParams["figure.figsize"] = 5,2
    x = range(1,135)

    fig, (ax,ax2) = plt.subplots(nrows=2, sharex=True)

    extent = [x[0]-(x[1]-x[0])/2., x[-1]+(x[1]-x[0])/2.,0,1]
    ax.imshow(y[np.newaxis,:], cmap="plasma", aspect="auto", extent=extent)
    ax.set_yticks([])
    ax.set_xlim(extent[0], extent[1])

    ax2.plot(x,y)
    fig.suptitle(plt_title)
    plt.tight_layout()
    plt.show()

# %%
def plot_all_feature_maps(data, plt_title):
    plt.rcParams["figure.figsize"] = 20,10
    x = range(1,135)
    fig, axis = plt.subplots()

    extent = [x[0]-(x[1]-x[0])/2., x[-1]+(x[1]-x[0])/2.,0,1]
    heatmap = axis.pcolor(data, cmap="plasma") 
    axis.set_yticks(np.arange(data.shape[0])+0.5, minor=False)
#     axis.set_xticks(np.arange(data.shape[1])+0.5, 5)
    
    row_labels = list(range(1,data.shape[0]+1))
    axis.set_yticklabels(row_labels)
#     axis.set_xticklabels(x, 5)
    fig.suptitle(plt_title)
    plt.colorbar(heatmap)
    plt.tight_layout()
    plt.show()

# %%
def plot_both_feature_maps(y0, y1, plt_title):
    plt.rcParams["figure.figsize"] = 10,4
    x = range(1,135)
    data = np.concatenate(([y0], [y1]))
#     print(data)
    fig, axis = plt.subplots()

    extent = [x[0]-(x[1]-x[0])/2., x[-1]+(x[1]-x[0])/2.,0,1]
    heatmap = axis.pcolor(data, cmap="Blues") 
    axis.set_yticks(np.arange(data.shape[0])+0.5, minor=False)
#     axis.set_xticks(np.arange(data.shape[1])+0.5, 5)
    
    row_labels = ["Depleted - 0", "Enriched - 1"]
    axis.set_yticklabels(row_labels)
#     axis.set_xticklabels(x, 5)
    fig.suptitle(plt_title)
    plt.colorbar(heatmap)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #

# %%
for layer_name, feature_map in zip(layer_names, feature_maps):

    if layer_name == 'permute_1':
        
        print(len(feature_map))
        feature_map -= feature_map.mean()
        feature_map /= feature_map.std ()
#         print(f'layer_name: {layer_name}')
#         print(f'feature_map.shape: {feature_map.shape}')
        print(f"Total number of Enriched {len(ones)}" )
        print(f"Total number of Depleted {len(zeros)}" )
        for i in ones:
            feature_map_ones = feature_map[i]
            name = "Feature Map Avg Ones-" + str(i) 
            plot_feature_map(feature_map_ones, name)
        for i in zeros:
            feature_map_zeros = feature_map[i]
            name = "Feature Map Avg Zeros-" + str(i) 
            plot_feature_map(feature_map_zeros, name)
#         feature_map_ones1 = feature_map[1]
#         feature_map_zeros2 = feature_map[2]
#         feature_map_zeros3 = feature_map[3]
#         print(zeros)
#         print(f'feature_map_ones.shape: {feature_map_ones.shape}')
#         print(f'feature_map_zeros.shape: {feature_map_zeros.shape}')
#         feature_map_avg_ones0 = feature_map_ones.sum(axis=0)
#         feature_map_avg_zeros = feature_map_zeros.sum(axis=0)
#         feature_map_avg_zeros1 = feature_map[1]
#         feature_map_avg_zeros2 = feature_map[2]
#         feature_map_avg_zeros3 = feature_map[3]
#         feature_map_avg_zeros4 = feature_map[4]
#         print(feature_map_zeros)
#         plot_feature_map(feature_map_avg_ones, "Feature Map Avg Ones")
#         plot_feature_map(feature_map_avg_zeros1, "Feature Map Avg Zeros")
#         plot_feature_map(feature_map_ones0, "Feature Map Avg Ones")
#         plot_feature_map(feature_map_ones1, "Feature Map Avg Ones")
#         plot_feature_map(feature_map_zeros2, "Feature Map Avg Zeros")
#         plot_feature_map(feature_map_zeros3, "Feature Map Avg Zeros")
#         plot_feature_map(feature_map_avg_zeros4, "Feature Map Avg Zeros")
#         plot_both_feature_maps(feature_map_avg_ones, feature_map_avg_zeros1, feature_map_avg_zeros2,"Feature Maps Reduced Model")
# Out:
# 151
# Total number of Enriched 73
# Total number of Depleted 78

# %%
# 134 channels, 

for layer_name, feature_map in zip(layer_names, feature_maps):

    if layer_name == 'multiply':
        k = feature_map.shape[-1]  
        feature_map_ones = feature_map[ones]
        feature_map_zeros = feature_map[zeros]
        
#         plt.rcParams["figure.figsize"] = 20,20
        data = []
        for i in range(k):
            feature_img_zeros = feature_map_zeros[:, :, i]
            feature_img_zeros -= feature_img_zeros.mean()
            feature_img_zeros /= feature_img_zeros.std()
            size=feature_img_zeros.shape[1]
            for fmap in feature_img_zeros:
                feature_map_curr_zeros = fmap
#             feature_map_avg_zeros = feature_img_zeros.sum(axis=0)
                if len(data) == 0:
                    data = [feature_map_avg_zeros]
                else:
                    data = np.concatenate((data, [feature_map_avg_zeros]))
        plot_all_feature_maps(data, "feature_map_avg_zeros")
#         for i in range(k):
#             feature_img_ones = feature_map_ones[:, :, i]
#             feature_img_ones -= feature_img_ones.mean()
#             feature_img_ones /= feature_img_ones.std()            
#             size=feature_img_ones.shape[1]
#             for fmap in feature_img_zeros:
#                 feature_map_avg_ones = fmap
# #                 feature_map_avg_ones = feature_img_ones.sum(axis=0)            
#                 if len(data) == 0:
#                     data = [feature_map_avg_ones]
#                 else:
#                     data = np.concatenate((data, [feature_map_avg_ones]))
        plot_all_feature_maps(data, "feature_map_avg_ones")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-875cef8da606> in <module>
#      22                 else:
#      23                     data = np.concatenate((data, [feature_map_avg_zeros]))
# ---> 24         plot_all_feature_maps(data, "feature_map_avg_zeros")
#      25 #         for i in range(k):
#      26 #             feature_img_ones = feature_map_ones[:, :, i]
#
# <ipython-input-16-55f128c01d2e> in plot_all_feature_maps(data, plt_title)
#       5
#       6     extent = [x[0]-(x[1]-x[0])/2., x[-1]+(x[1]-x[0])/2.,0,1]
# ----> 7     heatmap = axis.pcolor(data, cmap="plasma")
#       8     axis.set_yticks(np.arange(data.shape[0])+0.5, minor=False)
#       9 #     axis.set_xticks(np.arange(data.shape[1])+0.5, 5)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pcolor(self, shading, alpha, norm, cmap, vmin, vmax, *args, **kwargs)
#    5819             shading = rcParams['pcolor.shading']
#    5820         shading = shading.lower()
# -> 5821         X, Y, C, shading = self._pcolorargs('pcolor', *args, shading=shading,
#    5822                                             kwargs=kwargs)
#    5823         Ny, Nx = X.shape
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _pcolorargs(self, funcname, shading, *args, **kwargs)
#    5554         if len(args) == 1:
#    5555             C = np.asanyarray(args[0])
# -> 5556             nrows, ncols = C.shape
#    5557             if shading in ['gouraud', 'nearest']:
#    5558                 X, Y = np.meshgrid(np.arange(ncols), np.arange(nrows))
#
# ValueError: too many values to unpack (expected 2)

# %%
#### Plot each feature in permute_1 for all sequences
# The shape of the permute_1 is =======>> (# seqs (150), 134, 1)

for layer_name, feature_map in zip(layer_names, feature_maps):

    if layer_name == 'permute_1':
#         print(feature_map)
        feature_map -= feature_map.mean()
        feature_map /= feature_map.std ()
#         print(f'layer_name: {layer_name}')
#         print(f'feature_map.shape: {feature_map.shape}')
        feature_map_ones = feature_map[ones]
        feature_map_zeros = feature_map[zeros]
        print(f'feature_map_ones.shape: {feature_map_ones.shape}')
        print(f'feature_map_zeros.shape: {feature_map_zeros.shape}')
        Features = []
        for seqArr in feature_map_ones:
            newSeqArr = np.transpose(seqArr)
            if(len(Features) == 0):
                Features=newSeqArr
            else:
                Features = Features + newSeqArr
            print(Features[0])
#         feature_map_avg_ones = feature_map_ones.sum(axis=0)
#         feature_map_avg_zeros = feature_map_zeros.sum(axis=0)
#         plot_feature_map(feature_map_avg_ones, "Feature Map Avg Ones")
#         plot_feature_map(feature_map_avg_zeros, "Feature Map Avg Zeros")
#         plot_both_feature_maps(feature_map_avg_ones, feature_map_avg_zeros,"Feature Maps Reduced Model")
# Out:
# feature_map_ones.shape: (73, 134, 1)
# feature_map_zeros.shape: (78, 134, 1)
# [[  9.026196    -1.8257611   -1.1021953   -5.2917156   -6.188075
#    -7.275644    -0.33118978  -4.1090894   -8.649109     2.8712292
#    -3.9920774    1.3958817   -0.84120107   1.0494368    1.8833683
#    12.3757       2.9489646    0.09271425   2.1788158   -2.4939065
#     2.3573172    8.280198     0.7212124   -2.23443      2.7196765
#    -3.3465903   -2.057333    -8.458022    -6.817389   -12.044618
#    -9.834436   -10.642943   -15.267145    -1.8232434   13.377917
#    13.388253     6.9936323   10.697484    -4.440979    -0.46565646
#     3.2297843    6.9989305    8.743664     6.414275    15.753881
#     7.4481153   -3.858265     1.7022613    4.365867    -6.071427
#    13.937807    15.963598    11.259338    11.273446     7.767804
#     3.9136407   -4.4671173   -1.2713946   -0.89876807  -4.861015
#    -5.7996197   -3.7291336    3.2565582   -2.1622944   -7.8150725
#    -7.328239   -11.784988    -6.639074    -3.44024      3.4849665
#     6.550243    -2.3769002   -8.785462    -3.1708727   -3.726404
#     0.05510867   5.6218143    6.908755     3.9000545    7.351725
#     6.488349     8.91271     22.108427    17.176964     5.9598775
#    -5.3937316   -7.9895473   -8.713686    -6.7627296   -6.0580845
#    -5.4936457   -4.7979255    5.298864     1.4290724   -3.147706
#    -1.1182134   -3.8181276   -4.746867     2.3186045   -2.1217275
#    -4.9664383   -4.0936904   -5.829962    -2.2157717    0.47549468
#     3.5669885   -4.752248    -3.0085783    1.5473819   -6.0477934
#   -10.641014    -6.494121     3.3181462   15.457164     9.68535
#    28.406565    11.767528     1.032708    -1.8821871   -6.960153
#    -5.291015    -7.486246    -4.3489466   -5.0187187  -11.976634
#   -13.066915   -10.301683   -11.634418    -4.532578     3.9673774
#     2.0602746    1.8710357   -1.9304467   -0.7479108 ]]

# %%
for layer_name, feature_map in zip(layer_names, feature_maps):

    if layer_name == 'attention2':
        print((len(feature_map[0])))
# Out:
# 134

# %%
for lay in model.layers:
    print(lay.name)
#     if lay.name  == 'conv1d':
#         print(lay.get_weights())
    print(lay.get_weights())
    
# How to get weight for the attention layer?
# Out:
# input_1
# []
# conv1d
# [array([[[ 5.88397272e-02,  2.07488209e-01,  8.40836167e-02, ...,
#          -3.15940112e-01, -4.38121036e-02,  3.51109475e-01],
#         [-1.36742115e+00,  1.56361237e-01, -2.93634355e-01, ...,
#          -3.67846102e-01, -1.07533956e+00, -1.48016497e-01],
#         [-2.13828936e-01, -4.23114002e-01,  5.64018525e-02, ...,
#          -7.41358325e-02,  2.84077730e-02, -4.51969028e-01],
#         [ 1.19928317e-02, -2.94223696e-01, -1.40417039e-01, ...,
#           2.28891373e-01, -1.38400747e-02, -3.85565668e-01]],
#
#        [[-2.60685891e-01, -4.67808694e-01, -4.22161192e-01, ...,
#          -1.98711663e-01, -2.71421641e-01,  6.20961597e-04],
#         [ 3.42346542e-03,  5.07777989e-01,  4.25025113e-02, ...,
#           2.93700010e-01, -1.04705608e+00, -4.44006085e-01],
#         [ 1.49761960e-01, -4.15357888e-01,  6.40992597e-02, ...,
#          -2.48696476e-01, -5.86653352e-01,  1.73690543e-01],
#         [-5.50932825e-01, -2.39410391e-03,  2.35363171e-02, ...,
#          -2.99403697e-01,  5.41783273e-01, -2.39912942e-01]],
#
#        [[ 2.52119675e-02,  3.27004761e-01, -4.18308258e-01, ...,
#          -4.15220469e-01, -3.25051755e-01, -1.43975580e+00],
#         [-2.52018511e-01, -9.35524106e-02,  3.53023380e-01, ...,
#           2.75002494e-02, -3.89724612e-01, -4.80240621e-02],
#         [-2.58664843e-02, -9.36170202e-03, -1.56402901e-01, ...,
#          -8.04976046e-01,  3.16696286e-01, -3.27794015e-01],
#        [-0.1123679 ],
#        [-0.12681381],
#        [ 0.04452003],
#        [-0.4002993 ],
#        [ 0.08764995],
#        [ 0.30254376],
#        [-0.39777753],
#        [ 0.09427023],
#        [-0.137297  ],
#        [ 0.21684948],
#        [-0.13604666],
#        [-0.29227963],
#        [-0.10339247],
#        [-0.1236485 ],
#        [ 0.08552475],
#        [-0.13376252],
#        [-0.07229993],
#        [ 0.1280456 ],
#        [ 0.12505756],
#        [-0.10676864],
#        [ 0.12356028],
#        [-0.07823464],
#        [-0.28111953],
#        [-0.19107547],
#        [ 0.04227184],
#        [-0.3715645 ],
#        [-0.07971872],
#        [ 0.03588236],
#        [ 0.12327977],
#        [ 0.24661565],
#        [ 0.11495786],
#        [ 0.25791013],
#        [ 0.08469118],
#        [-0.13728455],
#        [ 0.12397975],
#        [-0.2155777 ],
#        [-0.1619005 ],
#        [ 0.23375909],
#        [-0.10978141],
#        [ 0.02418798],
#        [ 0.04321541],
#        [ 0.11625873],
#        [-0.04802852],
#        [-0.11675083],
#        [-0.1628946 ],
#        [-0.11031498],
#        [-0.15067086],
#        [-0.15639341],
#        [-0.21056488],
#        [ 0.17877893],
#        [-0.00148184],
#        [-0.18798214],
#        [ 0.12309442],
#        [-0.0681319 ],
#        [ 0.04717904],
#        [ 0.28908655],
#        [ 0.11925871],
#        [ 0.17423435],
#        [-0.5359493 ],
#        [-0.17220137],
#        [-0.14393158],
#        [ 0.05020021],
#        [ 0.14776233],
#        [ 0.23243728],
#        [-0.28402537],
#        [-0.15797341],
#        [-0.10181546],
#        [ 0.02180503],
#        [-0.30654144],
#        [ 0.16669033],
#        [ 0.11225121],
#        [ 0.03156676],
#        [ 0.07162606],
#        [-0.1488806 ],
#        [ 0.14602585],
#        [-0.34540126],
#        [-0.03886138],
#        [-0.2573579 ],
#        [-0.0829909 ],
#        [ 0.16644025],
#        [-0.10011259],
#        [-0.09305974],
#        [-0.2668359 ],
#        [-0.15427066],
#        [-0.14444423],
#        [ 0.09173843],
#        [-0.38646728],
#        [ 0.2363522 ],
#        [ 0.15259795],
#        [ 0.13086638],
#        [-0.13163126],
#        [ 0.1308728 ],
#        [-0.6580395 ],
#        [ 0.17294948],
#        [-0.14280872],
#        [-0.0236606 ],
#        [ 0.16060603],
#        [ 0.04277575],
#        [-0.12611605],
#        [-0.17188582],
#        [-0.22177432],
#        [ 0.06992127],
#        [ 0.06663524],
#        [-0.00861675],
#        [ 0.11826869],
#        [ 0.2116444 ],
#        [ 0.21319911],
#        [-0.1830783 ],
#        [ 0.17515011],
#        [ 0.09477288],
#        [-0.00285887],
#        [-0.08553213],
#        [ 0.11093051],
#        [-0.15920867],
#        [ 0.15583406],
#        [-0.15494478],
#        [-0.11375602],
#        [ 0.12188473],
#        [-0.03739594],
#        [ 0.14727631],
#        [ 0.02263405],
#        [-0.2424298 ],
#        [-0.2290384 ],
#        [-0.18109728],
#        [-0.18270998],
#        [-0.298669  ],
#        [ 0.06681669],
#        [ 0.24934119],
#        [ 0.16968581],
#        [ 0.3717396 ],
#        [-0.08642486],
#        [-0.28714392],
#        [ 0.27358845],
#        [-0.04783867],
#        [-0.18703048],
#        [-0.13707867],
#        [-0.20549294],
#        [-0.06336827],
#        [-0.18620381],
#        [-0.2169309 ],
#        [ 0.10493486],
#        [-0.10679037],
#        [-0.23914245],
#        [-0.4875883 ],
#        [-0.0632119 ],
#        [-0.3381398 ],
#        [-0.24175785],
#        [-0.17784597],
#        [-0.1173432 ],
#        [ 0.23477049],
#        [-0.03696972],
#        [ 0.2650335 ],
#        [-0.16735788],
#        [-0.24174808],
#        [-0.05018402],
#        [-0.192251  ],
#        [-0.19101837],
#        [-0.30359745],
#        [-0.18154429],
#        [-0.22303301],
#        [-0.23420337],
#        [ 0.22637407],
#        [ 0.11520875],
#        [-0.28832683],
#        [ 0.07450469],
#        [-0.316306  ],
#        [ 0.20075084],
#        [-0.08143837],
#        [-0.08150828],
#        [-0.3573496 ],
#        [ 0.16426851],
#        [ 0.11252005],
#        [ 0.231173  ],
#        [ 0.00313528],
#        [ 0.02811504],
#        [-0.00274019],
#        [-0.2292614 ],
#        [ 0.09749625],
#        [-0.3737633 ],
#        [-0.11439326],
#        [ 0.16815054],
#        [-0.12514016],
#        [ 0.2834118 ],
#        [ 0.19198802],
#        [ 0.15708752],
#        [-0.08459788],
#        [-0.18867017],
#        [-0.14219247],
#        [-0.08335987],
#        [-0.19932435],
#        [ 0.2630504 ],
#        [ 0.18279147],
#        [ 0.06242581],
#        [ 0.16091368],
#        [-0.27012277],
#        [-0.13976783],
#        [ 0.1994754 ],
#        [-0.11242701],
#        [-0.13346224],
#        [-0.07693631],
#        [ 0.19772203],
#        [ 0.06686118],
#        [ 0.08434056],
#        [-0.12094264],
#        [ 0.05298534],
#        [-0.4547937 ],
#        [-0.12401266],
#        [-0.20057684],
#        [-0.14793928],
#        [-0.4816322 ],
#        [ 0.12897067],
#        [-0.18738611],
#        [-0.02778917],
#        [-0.10681077],
#        [-0.16608399],
#        [-0.1701249 ],
#        [-0.05435199],
#        [-0.10582401],
#        [-0.13104317],
#        [-0.0713954 ],
#        [ 0.19409439],
#        [ 0.29137534],
#        [ 0.29489163],
#        [ 0.20768696],
#        [-0.43058494],
#        [-0.10224611],
#        [ 0.3206153 ],
#        [ 0.25378278],
#        [-0.21540938],
#        [ 0.20478877],
#        [ 0.10098471],
#        [-0.03861237],
#        [-0.2267236 ],
#        [-0.07863225],
#        [-0.17482509],
#        [-0.26592818],
#        [ 0.15206768],
#        [ 0.10839833],
#        [ 0.27699494],
#        [-0.14753908],
#        [ 0.15556736],
#        [-0.07254013],
#        [ 0.19765998],
#        [ 0.0769956 ],
#        [ 0.20986085],
#        [-0.17616123],
#        [-0.12802523],
#        [-0.15758242],
#        [ 0.11027505],
#        [ 0.13556415],
#        [-0.14056893],
#        [ 0.17086835],
#        [ 0.1964466 ],
#        [ 0.20717645],
#        [-0.28570172],
#        [ 0.22390172],
#        [-0.15054479],
#        [-0.23399408],
#        [-0.19873478],
#        [-0.1203788 ],
#        [ 0.06343374],
#        [-0.22915234],
#        [ 0.16034286],
#        [-0.11690267],
#        [ 0.06152962],
#        [-0.12629724],
#        [ 0.10391634],
#        [ 0.06441248],
#        [ 0.17128184],
#        [-0.06365186],
#        [ 0.22744973],
#        [ 0.24795131],
#        [-0.09475387],
#        [ 0.09408303],
#        [-0.15710764],
#        [-0.15998746],
#        [-0.2611165 ],
#        [ 0.17281498],
#        [-0.28209198],
#        [-0.03762002],
#        [-0.1485982 ],
#        [-0.17958912],
#        [-0.3795752 ],
#        [ 0.12462277],
#        [-0.12481797],
#        [-0.17253052],
#        [-0.19019544],
#        [-0.04845938],
#        [ 0.24390739],
#        [-0.28329405],
#        [-0.17461652],
#        [ 0.2372645 ],
#        [-0.10508178],
#        [-0.16109422],
#        [-0.1759025 ],
#        [-0.14217643],
#        [ 0.1342398 ],
#        [ 0.14361797],
#        [-0.2208555 ],
#        [ 0.25880364],
#        [-0.08253816],
#        [-0.708012  ],
#        [-0.1436977 ],
#        [-0.16374414],
#        [-0.14552332],
#        [-0.19268328],
#        [-0.1494347 ],
#        [ 0.37366506],
#        [ 0.16779341],
#        [ 0.3470055 ],
#        [-0.11626855],
#        [ 0.10515043],
#        [-0.2618299 ],
#        [-0.6658947 ],
#        [-0.2399906 ],
#        [-0.13936213]], dtype=float32), array([0.0113089], dtype=float32)]
# permute
# []
# activation
# []
# permute_1
# []
# attention2
# []
# repeat_vector
# []
# permute_2
# []
# multiply
# []
# bidirectional
# [array([[ 0.06491383,  0.10184055, -0.08888885, ..., -0.39010724,
#          0.28687418, -0.16121553],
#        [-0.41142383,  0.01457828,  0.10081427, ...,  0.25473973,
#         -0.3619755 , -0.08392883],
#        [-0.49174267, -0.12140246,  0.19513258, ...,  0.45104614,
#          1.016936  , -0.21459702],
#        ...,
#        [ 0.3074077 ,  0.10446355,  0.48874763, ...,  0.07519916,
#         -0.07196572, -0.2004526 ],
#        [ 0.45283282,  0.22485752,  0.3769666 , ..., -0.08981919,
#          0.6615152 ,  0.53440493],
#        [-0.19268376, -0.13004221,  0.25539368, ..., -0.168717  ,
#         -0.5707367 , -0.65255505]], dtype=float32), array([[-0.13424769, -0.09337007, -0.07624011, ..., -0.4458852 ,
#         -0.2915578 ,  0.514362  ],
#        [-0.28591534,  0.47588605,  0.54013157, ..., -0.16293125,
#         -0.39654085,  0.66059256],
#        [-0.33258894, -0.4047925 , -0.06480077, ..., -0.11924566,
#         -0.3410744 , -0.41653016],
#        ...,
#        [-0.2718475 , -0.24761406,  0.3877032 , ...,  0.08297686,
#         -0.35341844, -0.71777415],
#        [ 0.18064584, -0.3367017 , -0.59166497, ...,  0.74063045,
#          0.00960122, -0.34493035],
#        [ 0.03088472,  0.17491105,  0.7616495 , ...,  0.5909508 ,
#         -0.04187702,  0.11978026]], dtype=float32), array([-1.0938616, -1.0822116, -1.1726213, ..., -1.1294583, -0.9081095,
#        -1.1641431], dtype=float32), array([[-1.1927941 , -0.67366856, -0.02351744, ..., -0.38281062,
#         -0.12802964,  0.4430447 ],
#        [-0.88475674, -0.79735726, -1.1122762 , ..., -0.2955804 ,
#         -0.2938665 , -0.3415224 ],
#        [ 0.25779337, -0.60383034,  0.23302205, ..., -0.6054571 ,
#         -0.74670476,  0.46582663],
#        ...,
#        [-0.00399611, -0.8771631 , -0.28941548, ..., -0.20643844,
#         -0.27736178, -0.88734204],
#        [-0.56454766, -0.13009186, -1.239146  , ..., -0.24807703,
#          0.12967795, -0.40874213],
#        [ 0.04521575,  0.23487146, -0.9595035 , ...,  0.03987993,
#         -0.36999756, -0.2756662 ]], dtype=float32), array([[ 0.13363971, -0.145476  , -0.34575304, ...,  0.47642052,
#         -0.06900512, -0.18466562],
#        [ 0.32162413, -0.13046406, -0.07882891, ...,  0.5341788 ,
#          0.16487968,  0.07079367],
#        [-0.42041048,  0.7246731 , -0.07169238, ...,  0.08729521,
#         -0.6067065 , -0.6138396 ],
#        ...,
#        [ 0.17418174, -0.07703853,  0.00895904, ..., -0.13376674,
#          0.40590462, -0.18346155],
#        [-0.23295596,  0.2514596 , -0.34033677, ..., -0.07161633,
#         -0.15532047,  0.16926388],
#        [ 0.03724905,  0.18290037,  0.2684431 , ...,  0.43161234,
#          0.30249318,  0.07406149]], dtype=float32), array([-1.262075 , -0.8528008, -1.2411969, ..., -1.1600486, -1.1356245,
#        -1.3361189], dtype=float32)]
# dropout_1
# []
# flatten
# []
# dense_1
# [array([[ 0.2908427 ,  0.23809026, -0.40762648, ...,  0.73656297,
#         -0.488599  ,  0.6629092 ],
#        [ 0.02090357,  0.4286053 , -0.47638726, ...,  0.6224057 ,
#         -0.46685052,  0.55431855],
#        [-0.21845932, -0.26023796,  0.25521052, ..., -0.8765805 ,
#          0.31524488, -1.0389024 ],
#        ...,
#        [-0.5993228 , -0.40561092,  0.33798087, ..., -0.19515721,
#          0.6829013 , -0.12578264],
#        [ 0.64865583,  0.537418  , -0.37440228, ...,  0.47685677,
#         -0.4106346 , -0.13010058],
#        [ 0.08583998, -0.01425243,  0.10667069, ..., -0.25763822,
#         -0.0866868 , -0.398856  ]], dtype=float32), array([ 0.19275616,  0.11148793, -0.13950995,  0.16086933, -0.8495843 ,
#         0.10316109, -0.9031974 ,  0.2192185 ,  0.08371203, -0.08851316],
#       dtype=float32)]
# activation_1
# []
# dense_2
# [array([[ 0.43828407],
#        [ 0.3065309 ],
#        [-0.33889377],
#        [-0.55035704],
#        [ 1.0996702 ],
#        [-0.45250723],
#        [ 1.0031906 ],
#        [ 0.29908657],
#        [-0.5607721 ],
#        [ 0.28101355]], dtype=float32), array([-0.12197685], dtype=float32)]
# activation_2
# []
