# %%
import numpy as np
import scipy.io
from sklearn import metrics
import pandas as pd
import os
# os.environ['THEANO_FLAGS'] = "device=cuda0,force_device=True,floatX=float32"
# from aesara_theano_fallback import aesara as theano
#import theano

# print(theano.config.device)
# import sys, getopt

from keras.layers import Embedding
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten, Layer, merge, Input, Concatenate, Reshape
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers.pooling import GlobalMaxPooling1D
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import backend as K
import tensorflow.keras as keras
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
data_folder = "/Users/yibeijia/Downloads/nucleosome_occupancy/tbinet_stuff/model/"
model = load_model(data_folder+"tbinet.h5")

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 147, 4)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 122, 320)     33600       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 9, 320)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 9, 320)       0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 9, 1)         321         dropout[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 1, 9)         0           dense[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 9)         0           permute[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 9, 1)         0           activation[0][0]
# __________________________________________________________________________________________________
# attention (Lambda)              (None, 9)            0           permute_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 320, 9)       0           attention[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 9, 320)       0           repeat_vector[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 9, 320)       0           dropout[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 9, 640)       1640960     multiply[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 9, 640)       0           bidirectional[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 5760)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 695)          4003895     flatten[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 695)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            696         activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1)            0           dense_2[0][0]
# ==================================================================================================
# Total params: 5,679,472
# Trainable params: 5,679,472
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
layer_names = [layer.name for layer in model.layers]
layer_names
# Out:
# ['input_1',
#  'conv1d',
#  'max_pooling1d',
#  'dropout',
#  'dense',
#  'permute',
#  'activation',
#  'permute_1',
#  'attention',
#  'repeat_vector',
#  'permute_2',
#  'multiply',
#  'bidirectional',
#  'dropout_1',
#  'flatten',
#  'dense_1',
#  'activation_1',
#  'dense_2',
#  'activation_2']

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f911cc3e880>,
#  <keras.layers.convolutional.Conv1D at 0x7f911cc3e850>,
#  <keras.layers.pooling.MaxPooling1D at 0x7f911cd03eb0>,
#  <keras.layers.core.Dropout at 0x7f911cd03fd0>,
#  <keras.layers.core.Dense at 0x7f911cdb1310>,
#  <keras.layers.core.Permute at 0x7f911cdb1700>,
#  <keras.layers.core.Activation at 0x7f911cdb1880>,
#  <keras.layers.core.Permute at 0x7f911cdb1910>,
#  <keras.layers.core.Lambda at 0x7f911cc3e730>,
#  <keras.layers.core.RepeatVector at 0x7f911cdb1f10>,
#  <keras.layers.core.Permute at 0x7f911cdd1070>,
#  <keras.layers.merge.Multiply at 0x7f911cdb1f70>,
#  <keras.layers.wrappers.Bidirectional at 0x7f911cdb1b80>,
#  <keras.layers.core.Dropout at 0x7f911ce228b0>,
#  <keras.layers.core.Flatten at 0x7f911ce22970>,
#  <keras.layers.core.Dense at 0x7f911ce22c10>,
#  <keras.layers.core.Activation at 0x7f911ce22fa0>,
#  <keras.layers.core.Dense at 0x7f911ce22fd0>,
#  <keras.layers.core.Activation at 0x7f911ce27520>]

# %%
conv1D = model.layers[1]
conv1D

# %%
attention = model.layers[8]
attention

# %%
layer_outputs = [layer.output for layer in model.layers]
layer_outputs
# Out:
# [<KerasTensor: shape=(None, 147, 4) dtype=float32 (created by layer 'input_1')>,
#  <KerasTensor: shape=(None, 122, 320) dtype=float32 (created by layer 'conv1d')>,
#  <KerasTensor: shape=(None, 9, 320) dtype=float32 (created by layer 'max_pooling1d')>,
#  <KerasTensor: shape=(None, 9, 320) dtype=float32 (created by layer 'dropout')>,
#  <KerasTensor: shape=(None, 9, 1) dtype=float32 (created by layer 'dense')>,
#  <KerasTensor: shape=(None, 1, 9) dtype=float32 (created by layer 'permute')>,
#  <KerasTensor: shape=(None, 1, 9) dtype=float32 (created by layer 'activation')>,
#  <KerasTensor: shape=(None, 9, 1) dtype=float32 (created by layer 'permute_1')>,
#  <KerasTensor: shape=(None, 9) dtype=float32 (created by layer 'attention')>,
#  <KerasTensor: shape=(None, 320, 9) dtype=float32 (created by layer 'repeat_vector')>,
#  <KerasTensor: shape=(None, 9, 320) dtype=float32 (created by layer 'permute_2')>,
#  <KerasTensor: shape=(None, 9, 320) dtype=float32 (created by layer 'multiply')>,
#  <KerasTensor: shape=(None, 9, 640) dtype=float32 (created by layer 'bidirectional')>,
#  <KerasTensor: shape=(None, 9, 640) dtype=float32 (created by layer 'dropout_1')>,
#  <KerasTensor: shape=(None, 5760) dtype=float32 (created by layer 'flatten')>,
#  <KerasTensor: shape=(None, 695) dtype=float32 (created by layer 'dense_1')>,
#  <KerasTensor: shape=(None, 695) dtype=float32 (created by layer 'activation_1')>,
#  <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_2')>,
#  <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'activation_2')>]

# %%
model.inputs
# Out:
# [<KerasTensor: shape=(None, 147, 4) dtype=float32 (created by layer 'input_1')>]

# %%
attention.output
# Out:
# <KerasTensor: shape=(None, 9) dtype=float32 (created by layer 'attention')>

# %%
tf.keras.Input
# Out:
# <function keras.engine.input_layer.Input(shape=None, batch_size=None, name=None, dtype=None, sparse=None, tensor=None, ragged=None, type_spec=None, **kwargs)>

# %%
feature_map_model = tf.keras.models.Model(inputs=model.inputs, outputs=layer_outputs)

# %%
# data_folder = "./data/"
data_folder = "../data/train_test_data/"
testmat = scipy.io.loadmat(data_folder+'Test_data.mat')
feature_maps = feature_map_model.predict(np.transpose(testmat['Test_data'],axes=(0,1,2)))

# %%
labels = testmat['Test_labels']
ones = np.flatnonzero(labels == np.max(labels)).T
zeros = np.flatnonzero(labels == np.min(labels)).T
print(f'ones.shape {ones.shape}')
print(f'zeros.shape {zeros.shape}')
# Out:
# ones.shape (59269,)
# zeros.shape (91621,)

# %%
for layer_name, feature_map in zip(layer_names, feature_maps):print(f"The shape of the {layer_name} is =======>> {feature_map.shape}")
# Out:
# The shape of the input_1 is =======>> (150890, 147, 4)
# The shape of the conv1d is =======>> (150890, 122, 320)
# The shape of the max_pooling1d is =======>> (150890, 9, 320)
# The shape of the dropout is =======>> (150890, 9, 320)
# The shape of the dense is =======>> (150890, 9, 1)
# The shape of the permute is =======>> (150890, 1, 9)
# The shape of the activation is =======>> (150890, 1, 9)
# The shape of the permute_1 is =======>> (150890, 9, 1)
# The shape of the attention is =======>> (150890, 9)
# The shape of the repeat_vector is =======>> (150890, 320, 9)
# The shape of the permute_2 is =======>> (150890, 9, 320)
# The shape of the multiply is =======>> (150890, 9, 320)
# The shape of the bidirectional is =======>> (150890, 9, 640)
# The shape of the dropout_1 is =======>> (150890, 9, 640)
# The shape of the flatten is =======>> (150890, 5760)
# The shape of the dense_1 is =======>> (150890, 695)
# The shape of the activation_1 is =======>> (150890, 695)
# The shape of the dense_2 is =======>> (150890, 1)
# The shape of the activation_2 is =======>> (150890, 1)

# %%
def plot_feature_map(y, plt_title):
    plt.rcParams["figure.figsize"] = 5,2
    x = range(1,10)

    fig, (ax,ax2) = plt.subplots(nrows=2, sharex=True)

    extent = [x[0]-(x[1]-x[0])/2., x[-1]+(x[1]-x[0])/2.,0,1]
    ax.imshow(y[np.newaxis,:], cmap="plasma", aspect="auto", extent=extent)
    ax.set_yticks([])
    ax.set_xlim(extent[0], extent[1])

    ax2.plot(x,y)
    fig.suptitle(plt_title)
    plt.tight_layout()
    plt.show()

# %%
def plot_both_feature_maps(y0, y1, plt_title):
    plt.rcParams["figure.figsize"] = 5,2
    x = range(1,10)
    data = np.concatenate(([y0], [y1]))
    print(data)
    fig, axis = plt.subplots()

    extent = [x[0]-(x[1]-x[0])/2., x[-1]+(x[1]-x[0])/2.,0,1]
    heatmap = axis.pcolor(data, cmap=plt.cm.Blues) 
    axis.set_yticks(np.arange(data.shape[0])+0.5, minor=False)
#     axis.set_xlim(x[0], x[-1])
    axis.set_xticks(np.arange(data.shape[1])+0.5, minor=False)
    
    row_labels = ["Zeros", "Ones"]
    axis.set_yticklabels(row_labels, minor=False)
    axis.set_xticklabels(x, minor=False)
#     ax2.set_yticklabels(row_labels[1], minor=False)
    fig.suptitle(plt_title)
    plt.colorbar(heatmap)
    plt.tight_layout()
    plt.show()

# %%
for layer_name, feature_map in zip(layer_names, feature_maps):

    if layer_name == 'attention':
        k = feature_map.shape[-1]  
        size=feature_map.shape[1]
        feature_map -= feature_map.mean()
        feature_map /= feature_map.std ()
        print(f'feature_map.shape: {feature_map.shape}')
        print(f'layer_name: {layer_name}')
        feature_map_ones = feature_map[ones]
        feature_map_zeros = feature_map[zeros]
        print(f'feature_map_ones.shape: {feature_map_ones.shape}')
        print(f'feature_map_zeros.shape: {feature_map_zeros.shape}')
        feature_map_avg_ones = feature_map_ones.sum(axis=0)
        feature_map_avg_zeros = feature_map_zeros.sum(axis=0)
        plot_feature_map(feature_map_avg_ones, "Feature Map Avg Ones")
        plot_feature_map(feature_map_avg_zeros, "Feature Map Avg Zeros")
        plot_both_feature_maps(feature_map_avg_ones, feature_map_avg_zeros,"Feature Maps")
# Out:
# feature_map.shape: (150890, 9)
# layer_name: attention
# feature_map_ones.shape: (59269, 9)
# feature_map_zeros.shape: (91621, 9)
# y.shape: (9,)
# y.shape: (9,)
# [[ 385.2093  -169.66095 -118.10258  303.81967 -119.33921 -150.43033
#   -174.79251 -236.09299  279.38828]
#  [-222.2179  -604.44885 -579.92645 -104.27901 -120.43572  450.228
#    174.63539  574.992    431.44284]]
