# %%
def readInputAsArray(fileName):
    with open(fileName, 'r') as myfile:
        data = myfile.readlines()

    # Strip newline
    for i in range(0, len(data)):
        data[i] = data[i].rstrip()
    # print(data)
    return data

# %%
performance=readInputAsArray('/Users/yibeijia/Downloads/test_out2')
e = 0
E = []
avgs=[]
for i in performance:


    i = i.split()
#     print("line", i[3])
    if i[0] == '1/1944':
        avg = total / 1944;
        avgs = avgs + [avg]
        total = 0
        e+=1
        E+=[e]
        print("epoch", e)
        print(avg)
    else:
        val = float(i[7][:5])
        total += val

print (avgs)
# Out:
# epoch 1
# end of epoch 1
# 0.010523148148148162
# epoch 2
# end of epoch 2
# 0.21138117283950755
# epoch 3
# end of epoch 3
# 0.13504475308641903
# epoch 4
# end of epoch 4
# 0.09271193415637914
# epoch 5
# end of epoch 5
# 0.0667829218106987
# epoch 6
# end of epoch 6
# 0.054619855967076726
# epoch 7
# end of epoch 7
# 0.0533569958847738
# epoch 8
# end of epoch 8
# 0.04383641975308579
# epoch 9
# end of epoch 9
# 0.040485596707819815
# epoch 10
# end of epoch 10
# 0.037174382716048594
# epoch 11
# end of epoch 11
# 0.0349490740740734
# epoch 12
# end of epoch 12
# 0.034125514403292825
# epoch 13
# end of epoch 13
# 0.03080144032921798
# epoch 14
# end of epoch 14
# 0.028378086419753035
# epoch 15
# end of epoch 15
# 0.028945473251029342
# epoch 16
# end of epoch 16
# 0.02665123456790081
# epoch 17
# end of epoch 17
# 0.026221193415638337
# epoch 18
# end of epoch 18
# 0.02428292181069948
# epoch 19
# end of epoch 19
# 0.023407921810700023
# epoch 20
# end of epoch 20
# 0.02255761316872483
# epoch 21
# end of epoch 21
# 0.02173302469135768
# epoch 22
# end of epoch 22
# 0.021580246913580844
# epoch 23
# end of epoch 23
# 0.019395576131686965
# epoch 24
# end of epoch 24
# 0.019682613168723755
# epoch 25
# end of epoch 25
# 0.019395061728395245
# epoch 26
# end of epoch 26
# 0.01820267489711926
# epoch 27
# end of epoch 27
# 0.01801954732510229
# epoch 28
# end of epoch 28
# 0.017853395061728086
# epoch 29
# end of epoch 29
# 0.01592746913580237
# epoch 30
# end of epoch 30
# 0.014871399176954557
# epoch 31
# end of epoch 31
# 0.01513631687242748
# epoch 32
# end of epoch 32
# 0.013872427983539291
# [0.010523148148148162, 0.21138117283950755, 0.13504475308641903, 0.09271193415637914, 0.0667829218106987, 0.054619855967076726, 0.0533569958847738, 0.04383641975308579, 0.040485596707819815, 0.037174382716048594, 0.0349490740740734, 0.034125514403292825, 0.03080144032921798, 0.028378086419753035, 0.028945473251029342, 0.02665123456790081, 0.026221193415638337, 0.02428292181069948, 0.023407921810700023, 0.02255761316872483, 0.02173302469135768, 0.021580246913580844, 0.019395576131686965, 0.019682613168723755, 0.019395061728395245, 0.01820267489711926, 0.01801954732510229, 0.017853395061728086, 0.01592746913580237, 0.014871399176954557, 0.01513631687242748, 0.013872427983539291]

# %%
performance=readInputAsArray('/Users/yibeijia/Downloads/data/test_out3')
e = 0
E = []
avgs_val=[]
for i in performance:
    i = i.split()
    avgs_val += [float(i[1])]

print (avgs_val)
# Out:
# [0.1819, 0.1539, 0.0958, 0.0746, 0.0856, 0.0578, 0.0592, 0.0505, 0.0483, 0.0452, 0.051, 0.046, 0.0439, 0.0547, 0.0423, 0.0505, 0.0431, 0.0431, 0.0428, 0.0447, 0.0422, 0.0537, 0.0461, 0.0432, 0.045, 0.0427, 0.0419, 0.0471, 0.0551, 0.0428, 0.0432]

# %%
import matplotlib.pyplot as plt
print(len(E))
print(len(avgs))
avgs = avgs[::1]
print(len(avgs))
plt.scatter(range(len(avgs)), avgs, s=10, color='blue')
plt.scatter(range(len(avgs_val)), avgs, s=10, color='orange')
# Out:
# 0
# 31
# 31
