# %%
def readInputAsArray(fileName):
    with open(fileName, 'r') as myfile:
        data = myfile.readlines()

    # Strip newline
    for i in range(0, len(data)):
        data[i] = data[i].rstrip()
    # print(data)
    return data

# %%
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/train_model1_out')
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/train_model2_out')
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/train_model2_REDUCED_out')
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/train_model2_REDUCED2_out')
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/train_model2_REDUCED_10_out')
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/train_model3_removeLSTM_out')
#     for i in performance:

#         if start == 1:
# #             val = float(i[7][:6])
# #             val = i.split(',')
# #             print("val")
# #             print(val)
#             arr += [val]
        
#         if 'early stopping' in i and 'Epoch' in i:
# #             print((i))
#             start = 1
#     print(arr[len(arr)-1])
        
        
#         if start == 1:
#             val = float(i[7][:6])
#     #         print("val")
#     #         print(val)
#             total += val
#             start = 0
#             num_lines = 0

#         # New Epoch
#         elif i[0] == '1/1944':

#             avg = total / num_lines;
#             avgs = avgs + [avg]
#             total = 0
#             e+=1
#             E+=[e]
#     #         print("epoch", e)
#     #         print(avg)
#             num_lines = 0
#         else:
#             val = float(i[7][:6])
#     #         print(val)
#             total += val
#         num_lines += 1
#     #         print(total)
#     # The last epoch
#     avg = total / num_lines;
#     avgs = avgs + [avg]
#     e+=1
#     E+=[e]
#     print("epoch", e)
#     print(avg)
#     print (avgs)
#     print (len(avgs))

# %%
All_loss = {}
All_val_loss = {} 
index_max = 0
count = 1
for f in range(1,11):
    performance=readInputAsArray('/home/yibei/Projects/nucleosome_occupancy/tbinet_stuff/train_dense10_kernel10_run' + str(f)+ '.out')
    e = 0
    E = []
    avgs=[]
    start = 1
    total = 0

    vals = performance[(len(performance) - 3):(len(performance) -1)]
#     print(vals[0])
    loss_str = str(vals[0][1:len(vals[0])-1]).split(',')
    val_loss_str = str(vals[1][1:len(vals[1])-1]).split(',')
#     print(len(loss_str))
    loss = []
    val_loss = []
    if len(loss_str) > index_max:
        index_max = len(loss_str)

    for i in range(len(loss_str)):
        loss.append(float(loss_str[i]) )
        val_loss.append(float(val_loss_str[i]))

#     print(len(val_loss))

    if (val_loss[-1] < 0.5):
        All_loss["Model_"+str(count)] = loss
        All_val_loss["Model_"+str(count)]=val_loss
        count+=1
print(index_max)
indexes = []
for i in range(index_max):
    indexes.append(str(i))
All_val_loss
# Out:
# 52
# {'Model_1': [0.22079086303710938,
#   0.23576520383358002,
#   0.1930026412010193,
#   0.19911915063858032,
#   0.20884187519550323,
#   0.15929953753948212,
#   0.14919820427894592,
#   0.14326100051403046,
#   0.15941673517227173,
#   0.12086077034473419,
#   0.13233952224254608,
#   0.11721796542406082,
#   0.10937648266553879,
#   0.10343312472105026,
#   0.09526156634092331,
#   0.09317611157894135,
#   0.09484128654003143,
#   0.10433732718229294,
#   0.08952733129262924,
#   0.0835089311003685,
#   0.07956025004386902,
#   0.10058785229921341,
#   0.07919108867645264,
#   0.19362014532089233,
#   0.10040413588285446,
#   0.0911479964852333,
#   0.0817970335483551,
#   0.07918272912502289,
#   0.08061668276786804,
#   0.10955321043729782,
#   0.07313106954097748,
#   0.07747366279363632,
#   0.07294707000255585,
#   0.07484693080186844,
#   0.07437563687562943,
#   0.07732145488262177,
#   0.08547557145357132,
#   0.07723915576934814,
#   0.0817846730351448,
# ...

# %%
# df = pd.DataFrame(data=All_val_loss)
val_loss_df = pd.DataFrame(data=dict([ (k,pd.Series(v)) for k,v in All_val_loss.items()]))
val_loss_df.add_prefix('Model_')
val_loss_df['Epoches'] = indexes
val_loss_avg_df = val_loss_df.copy()
val_loss_avg_df['average'] = val_loss_avg_df.mean(numeric_only=True, axis=1)
val_loss_avg_df


loss_df = pd.DataFrame(data=dict([ (k,pd.Series(v)) for k,v in All_loss.items()]))
loss_df.add_prefix('Model_')
loss_df['Epoches'] = indexes

loss_avg_df = loss_df.copy()
loss_avg_df['average'] = loss_avg_df.mean(numeric_only=True, axis=1)
loss_avg_df
# loss_df
# Out:
#      Model_1   Model_2   Model_3   Model_4   Model_5   Model_6   Model_7  \
# 0   0.247908  0.255933  0.247526  0.253453  0.269699  0.247609  0.249833
# 1   0.221710  0.222833  0.222332  0.220558  0.224578  0.219184  0.221744
# 2   0.207784  0.210579  0.209039  0.207618  0.212019  0.206156  0.210932
# 3   0.192828  0.197162  0.200596  0.193074  0.199566  0.192493  0.198406
# 4   0.181124  0.183367  0.186340  0.179914  0.186095  0.179650  0.185450
# 5   0.168632  0.170543  0.175789  0.167721  0.172639  0.167680  0.172701
# 6   0.157004  0.160050  0.162440  0.155048  0.162004  0.155644  0.162307
# 7   0.147919  0.148980  0.153936  0.145802  0.150583  0.146209  0.152919
# 8   0.138467  0.139268  0.143612  0.136189  0.145230  0.136007  0.144110
# 9   0.130578  0.131965  0.135280  0.128514  0.133455  0.128196  0.135421
# 10  0.122811  0.123164  0.129025  0.118990  0.125088  0.120877  0.147732
# 11  0.116867  0.114236  0.121724  0.112933  0.117837  0.113843  0.188828
# ...

# %%
import seaborn as sns
# sns.lineplot(data=val_loss_df, x='Epoches', y=i, err_style="bars")
fig_dims = (10, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=val_loss_df,ax=ax )
# ax.set_ylim(0.92, 1)
ax.set_xlabel('Epoch', fontsize=15)
ax.set_ylabel('Validation Loss', fontsize=15)
ax.set_title("Validation Loss among Trained Models", fontsize=20)
# for i in range(1, 9):
#     sns.lineplot(data=val_loss_df, x=0, y="Model_"+str(i), ax=ax )
# sns.lineplot(data=All_loss)
fig_path='/home/yibei/Projects/nucleosome_occupancy/figs/'
plt.savefig( fig_path + 'val_loss_across_models.png', dpi=200)

# %%
import seaborn as sns
# sns.lineplot(data=val_loss_df, x='Epoches', y=i, err_style="bars")
fig_dims = (10, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=loss_df,ax=ax )
# ax.set_ylim(0.92, 1)
ax.set_xlabel('Epoch', fontsize=15)
ax.set_ylabel('Training Loss', fontsize=15)
ax.set_title("Training Loss among Trained Models", fontsize=20)
# for i in range(1, 9):
#     sns.lineplot(data=val_loss_df, x=0, y="Model_"+str(i), ax=ax )
# sns.lineplot(data=All_loss)
plt.savefig( fig_path + 'train_loss_across_models.png', dpi=200)

# %%
import seaborn as sns
# sns.lineplot(data=val_loss_df, x='Epoches', y=i, err_style="bars")
fig_dims = (8, 6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.scatterplot(data=loss_avg_df,x='Epoches', y='average', ax=ax )
sns.scatterplot(data=val_loss_avg_df,x='Epoches', y='average', ax=ax )
plt.legend(labels=["Training","Validation"], fontsize=15)
ax.set_xticks(list(range(0,51))[::5])
ax.set_xlabel('Epoch', fontsize=15)
ax.set_ylabel('Loss', fontsize=15)
ax.set_title("Average Loss among Trained Models", fontsize=20)
plt.savefig( fig_path + 'avg_loss_across_models.png', dpi=200)

# %%
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/test_out3')
# From train output data
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/val_loss_model2')
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/val_loss_model2_REDUCED')
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/val_loss_model2_REDUCED2')
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/val_loss_model2_REDUCED_10')
performance=readInputAsArray('/Users/yibeijia/Downloads/data/val_loss_model3')
e = 0
E = []
avgs_val=[]
for i in performance:
    i = i.split()
    avgs_val += [float(i[1])]

print (avgs_val)
print (len(avgs_val))
# Out:
# [0.2278, 0.2222, 0.2206, 0.2204, 0.2166, 0.2082, 0.2235, 0.2089, 0.2044, 0.2047, 0.2054, 0.2031, 0.2032, 0.201, 0.2017, 0.202, 0.2028, 0.1996, 0.2, 0.2013, 0.2007, 0.2024, 0.2022, 0.2071, 0.2021, 0.2026, 0.2017, 0.2029]
# 28

# %%
import matplotlib.pyplot as plt

# plt.scatter(range((len(avgs_val))), avgs[1:], s=10, color='blue', label='Train')
plt.scatter(range((len(avgs))), avgs, s=10, color='blue', label='Train')
plt.scatter(range(len(avgs_val)), avgs_val, s=10, color='orange', label='Test')
plt.legend()
plt.title('Model Loss 5mer Dense 10 Remove LSTM')
plt.savefig("ModelLoss_5mer_10_RemoveLSTM.jpg")

# %%
import matplotlib.pyplot as plt

# plt.scatter(range((len(avgs_val))), avgs[1:], s=10, color='blue', label='Train')
plt.scatter(range((len(avgs))), avgs, s=10, color='blue', label='Train')
plt.scatter(range(len(avgs_val)), avgs_val, s=10, color='orange', label='Test')
plt.legend()
plt.title('Model Loss 5mer 2')
plt.savefig("ModelLoss_5mer_2.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8122/3875753855.py in <module>
#       2
#       3 # plt.scatter(range((len(avgs_val))), avgs[1:], s=10, color='blue', label='Train')
# ----> 4 plt.scatter(range((len(avgs))), avgs, s=10, color='blue', label='Train')
#       5 plt.scatter(range(len(avgs_val)), avgs_val, s=10, color='orange', label='Test')
#       6 plt.legend()
#
# NameError: name 'avgs' is not defined

# %%
# performance=readInputAsArray('/Users/yibeijia/Downloads/data/test_out3')
# From train output data
performance=readInputAsArray('/Users/yibeijia/Downloads/data/val_loss_model2')
performance1=readInputAsArray('/Users/yibeijia/Downloads/data/val_loss_model2_REDUCED')
performance2=readInputAsArray('/Users/yibeijia/Downloads/data/val_loss_model2_REDUCED2')
performance3=readInputAsArray('/Users/yibeijia/Downloads/data/val_loss_model2_REDUCED_10')
e = 0
E = []

avgs_val=[]
for i in performance:
    i = i.split()
    avgs_val += [float(i[1])]

print (avgs_val)
print (len(avgs_val))
avgs_val0 = avgs_val

avgs_val=[]
for i in performance1:
    i = i.split()
    avgs_val += [float(i[1])]

print (avgs_val)
print (len(avgs_val))
avgs_val1 = avgs_val

avgs_val=[]
for i in performance2:
    i = i.split()
    avgs_val += [float(i[1])]

print (avgs_val)
print (len(avgs_val))
avgs_val2 = avgs_val

avgs_val=[]
for i in performance3:
    i = i.split()
    avgs_val += [float(i[1])]

print (avgs_val)
print (len(avgs_val))
avgs_val10 = avgs_val

import matplotlib.pyplot as plt

# plt.scatter(range((len(avgs_val))), avgs[1:], s=10, color='blue', label='Train')
plt.scatter(range((len(avgs_val0))), avgs_val0, s=10, color='red', label='dense695')
plt.plot(range((len(avgs_val0))), avgs_val0, color='red')
plt.scatter(range((len(avgs_val1))), avgs_val1, s=10, color='blue', label='dense395')
plt.plot(range((len(avgs_val1))), avgs_val1,color='blue')
plt.scatter(range(len(avgs_val2)), avgs_val2, s=10, color='orange', label='dense100')
plt.plot(range(len(avgs_val2)), avgs_val2,color='orange')
plt.scatter(range(len(avgs_val10)), avgs_val10, s=10, color='black', label='dense10')
plt.plot(range(len(avgs_val10)), avgs_val10,color='black')
plt.legend()
plt.title('Compare Validation Between Models')
plt.xlabel('Epochs')
plt.ylabel('Model Loss')
# plt.savefig("ModelLoss_compare.jpg")
# Out:
# [0.2218, 0.2114, 0.2023, 0.1868, 0.2041, 0.1847, 0.1449, 0.1436, 0.1557, 0.1462, 0.1462, 0.1158, 0.1286, 0.1291, 0.1364, 0.1362, 0.1922, 0.157, 0.1695, 0.1786, 0.1745, 0.2117]
# 22
# [0.2652, 0.2188, 0.2132, 0.1818, 0.1671, 0.1678, 0.1484, 0.16, 0.172, 0.1255, 0.1177, 0.1187, 0.1155, 0.1225, 0.1422, 0.132, 0.1308, 0.1341, 0.1413, 0.1609, 0.1753, 0.1689, 0.1747]
# 23
# [0.2322, 0.212, 0.2014, 0.192, 0.1734, 0.1771, 0.1462, 0.1426, 0.1398, 0.1212, 0.1275, 0.1165, 0.1174, 0.13, 0.1046, 0.1057, 0.102, 0.1013, 0.1117, 0.1171, 0.1157, 0.1211, 0.1155, 0.1176, 0.1346, 0.1413, 0.1282, 0.1447]
# 28
# [0.2223, 0.2083, 0.2012, 0.1894, 0.1726, 0.1615, 0.1559, 0.1547, 0.1347, 0.1277, 0.2127, 0.1375, 0.1128, 0.1023, 0.1143, 0.0972, 0.0992, 0.1157, 0.0934, 0.1061, 0.0866, 0.1073, 0.0973, 0.0813, 0.0791, 0.0869, 0.0854, 0.0837, 0.0762, 0.0881, 0.0772, 0.0818, 0.0776, 0.1037, 0.0766, 0.0768, 0.0945, 0.084, 0.0936]
# 39
# Text(0, 0.5, 'Model Loss')

# %%
avgs_val.index(min(avgs_val))
# Out:
# 11

# %%
# test_out = '/Users/yibeijia/Downloads/data/test_copy.out'
# test_out = '/Users/yibeijia/Downloads/data/test_model2.out'
test_out = '/Users/yibeijia/Downloads/data/test_model2_REDUCED_dense10.out'
test_out = '/Users/yibeijia/Downloads/data/test_model3_removeLSTM.out'
test=readInputAsArray(test_out)

# %%
def getmetrics(test_out_fn):
    test=readInputAsArray(test_out_fn)    
    true = []
    pred = []

    for i in test:
        line = i.split()
        for k in line:
            score = k.split("=")
            if score[0]=="TrueLabel":
    #             print(score[1][1])
                true += [int(score[1][1])]
            if score[0]=="Predicted":
    #             print(score[0][1])
                if (float(score[1][1:len(score[1])-1]) > 0.5):
                    pred += [1]
                else:
                    pred += [0]
    from sklearn.metrics import accuracy_score
    acc = accuracy_score(true, pred) 
    from sklearn.metrics import precision_score
    prec = precision_score(true, pred)
    from sklearn.metrics import recall_score
    rec = recall_score(true, pred)
    out = [acc, prec, rec]
    return out

# %%
pred[:5]
# Out:
# [1, 0, 1, 0, 1]

# %%
true[:5]
# Out:
# [1, 0, 1, 0, 1]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(true, pred)
# Out:
# 0.9268085838462328

# %%
from sklearn.metrics import precision_score
precision_score(true, pred)
# Out:
# 0.9041144677246072

# %%
from sklearn.metrics import recall_score
recall_score(true, pred)
# Out:
# 0.9366320104140364

# %%
## Plot test output data
import numpy as np
import seaborn as sns

All_metrics = []
for i in range(1,11):
    test_out = '/home/yibei/Projects/nucleosome_occupancy/tbinet_stuff/test_dense10_kernel10_run'+ str(i) +'.out'
    out = getmetrics(test_out)
#     print(out)
    if len(All_metrics) == 0:
        if out[1] > 0.0 and out[2] > 0.0:
            All_metrics = [out]
    else:
        if out[1] > 0.0 and out[2] > 0.0:
            All_metrics = np.concatenate((All_metrics, [out]), axis=0)
print(len(All_metrics))
# Out:
# /home/yibei/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [0.5501509198002146, 0.0, 0.0]
# [0.977373609492122, 0.9721369096369097, 0.977725533265835]
# [0.9791105381390932, 0.9768962735371359, 0.9766615756868533]
# [0.9803611267649125, 0.9775488868703834, 0.9788238120570418]
# [0.9766633986675828, 0.9618792844006019, 0.9872496696583324]
# [0.9781301384139139, 0.9715087599931961, 0.9801280181216001]
# /home/yibei/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [0.5501509198002146, 0.0, 0.0]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(All_metrics, columns = ['accuracy_score','precision_score','recall_score'])
# df["model_id"] = list(range(0,9))
df.index.rename('model_id', inplace=True)
df["new_model_id"] = list(range(1,9))
# print(df)
fig, ax = plt.subplots()
g1 = sns.lineplot(x="new_model_id", y="accuracy_score",data=df, ax=ax)
g2 = sns.lineplot(x="new_model_id", y="precision_score",data=df, ax=ax)
g3 = sns.lineplot(x="new_model_id", y="recall_score",data=df, ax=ax)

ax.set_ylim(0.92, 1)
ax.set_xlabel('Model ID')
ax.set_ylabel('Metrics Score')
# ax.legend([g1, g2, g3], ['accuracy_score', 'label2', 'label3'])
ax.set_title("Metrics among Trained Models")
fig_path='/home/yibei/Projects/nucleosome_occupancy/figs/'
plt.legend(labels=['accuracy_score', 'precision_score', 'recall_score'])
plt.savefig( fig_path + 'metrics.png', dpi=200)

# %%
np.mean(df['accuracy_score'])
# Out:
# 0.9786975351052579

# %%
np.mean(df['precision_score'])
# Out:
# 0.9749379985421086

# %%
np.mean(df['recall_score'])
# Out:
# 0.9778563828874436
