# %%
import numpy as np
import scipy.io
from sklearn import metrics
import pandas as pd
import os
import scipy.io as sio
import os.path
import time
import random
import math

import tensorflow.keras as keras
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.layers import Embedding
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten, Layer, merge, Input, Concatenate, Reshape
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers.pooling import GlobalMaxPooling1D
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import backend as K
import tensorflow.keras as keras
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
# Library of Helper Functions

def readInputAsArray(fileName):
    with open(fileName, 'r') as myfile:
        data = myfile.readlines()

    # Strip newline
    for i in range(0, len(data)):
        data[i] = data[i].rstrip()
    # print(data)
    return data

def readInputAsString(fileName):
    with open(fileName, 'r') as myfile:
        data=myfile.read().replace('\n', ' ')
        # print 
    return data

def reverse_complement(seq):    
    complement = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A'}
    reverse_complement = ''.join(complement.get(base, base) for base in reversed(seq))
    return reverse_complement

def oneHotEncode(seq):
    import numpy as np
    seq2=list()
    mapping = {"A":[1., 0., 0., 0.], "C": [0., 1., 0., 0.], "G": [0., 0., 1., 0.], "T":[0., 0., 0., 1.]};
    for i in seq:
    	seq2.append(mapping[i]  if i in mapping.keys() else [0., 0., 0., 0.]);
    return seq2;

def ReverseOneHotEncode(arr):
    seq = ''
    nuc_map = ['A', 'C', 'G', 'T']
    for subarr in arr:
        nuc = nuc_map[np.argmax(subarr)]
        seq+=nuc
    return seq;

def writeSeqToFile(d,ones,zeros):
    fname = '/Users/yibeijia/Downloads/nucleosome_occupancy/data/SeqsForFeature.txt'
    fname='/home/yibei/Projects/nucleosome_occupancy/data/SeqsForFeature.txt'
    out = 'Enriched:\n'
    for i in ones:
        seq = ReverseOneHotEncode(d[i])
        out = out + str(1) + ' ' + seq + '\n'
    out += 'Depleted:\n'
    for i in zeros:
        seq = ReverseOneHotEncode(d[i])
        out = out + str(0) + ' ' + seq + '\n'
    with open(fname, 'w+') as f:
        f.write(out)      
        
def tokenize(str):
    out = []
    for i in range(len(str)-4):
        out.append(str[i:i+5])
    return out

# Normalize an array 
def min_max_norm(arr):
    new_arr = []
    min_v = min(arr)
    max_v = max(arr)
    for num in arr:
        new_arr=new_arr+[(num-min_v)/(max_v-min_v)]
    return(new_arr)

def read_SD_table(fileName):
    tb_data = readInputAsArray(fileName)
    tb = {}
    DNAshape = tb_data[0].split("\t")
    # print(DNAshape)
    for i in range(1, len(tb_data)):
        line = tb_data[i].split("\t")
        key = line[0]
        value = line[1:]
        for j in range(0, len(value)):
            value[j] = float(value[j])
        tb[key] = value
    # print(tb)
    return(tb)

# %%
# Helper function to plot data colored with attention weights
class CharVal(object):
    def __init__(self, char, val):
        self.char = char
        self.val = val

    def __str__(self):
        return self.char

def rgb_to_hex(rgb):
    return '#%02x%02x%02x' % rgb

def color_charvals(s):
    r = 255-int(s.val*255)
#     r = int(s.val*255)
#     print(r)
    color = rgb_to_hex((r, r, 255))
    return 'background-color: %s' % color

# a list of 5mers, token and a list of their attention values, currseq_attention_output
def plot_attention_from_seq(token, currseq_attention_output):

    vals_normalized = min_max_norm(currseq_attention_output)
#     print(vals_normalized)
    # match each 5mer with sum of the 320 dim array attention weight array
    char_vals = [CharVal(c, v) for c, v in zip(token, vals_normalized)]
    char_df = pd.DataFrame(char_vals).transpose()
    # apply coloring values
    char_df = char_df.style.applymap(color_charvals)
    return char_df


def plot_attention_from_map(map):

    # match each 5mer with sum of the 320 dim array attention weight array
    vals_normalized = min_max_norm(map.values())
    char_vals = [CharVal(c, v) for c, v in zip(map.keys(), vals_normalized)]
    char_df = pd.DataFrame(char_vals).transpose()
    # apply coloring values
    char_df = char_df.style.applymap(color_charvals)
    return char_df

# %%
data_folder = "/Users/yibeijia/Downloads/nucleosome_occupancy/tbinet_stuff/model2/"

data_folder = "/Users/yibeijia/Downloads/nucleosome_occupancy/tbinet_stuff/model2_reduced_dense10/"
data_folder = "/Users/yibeijia/Downloads/nucleosome_occupancy/tbinet_stuff/model3/"
data_folder = "/Users/yibeijia/Downloads/nucleosome_occupancy/tbinet_stuff/train_dense10_kernel10_run10/"
data_folder = "/home/yibei/Projects/nucleosome_occupancy/tbinet_stuff/train_dense10_kernel10_run3/"
model = load_model(data_folder+"tbinet.h5")

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-02-24 13:32:14.210896: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-24 13:32:14.212444: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 13:32:14.212698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 13:32:14.212880: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 13:32:14.533071: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 13:32:14.533227: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 13:32:14.533344: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 13:32:14.533452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13584 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:61:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 147, 4)]     0           []
#
#  conv1d (Conv1D)                (None, 147, 320)     13120       ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 143, 320)     0           ['conv1d[0][0]']
#
#  dropout (Dropout)              (None, 143, 320)     0           ['max_pooling1d[0][0]']
#
#  dense (Dense)                  (None, 143, 1)       321         ['dropout[0][0]']
#
#  permute (Permute)              (None, 1, 143)       0           ['dense[0][0]']
#
#  activation (Activation)        (None, 1, 143)       0           ['permute[0][0]']
#
#  permute_1 (Permute)            (None, 143, 1)       0           ['activation[0][0]']
#
#  attention2 (Lambda)            (None, 143)          0           ['permute_1[0][0]']
#
#  repeat_vector (RepeatVector)   (None, 320, 143)     0           ['attention2[0][0]']
#
#  permute_2 (Permute)            (None, 143, 320)     0           ['repeat_vector[0][0]']
#
#  multiply (Multiply)            (None, 143, 320)     0           ['dropout[0][0]',
#                                                                   'permute_2[0][0]']
#
#  bidirectional (Bidirectional)  (None, 143, 640)     1640960     ['multiply[0][0]']
#
#  dropout_1 (Dropout)            (None, 143, 640)     0           ['bidirectional[0][0]']
#
#  flatten (Flatten)              (None, 91520)        0           ['dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 10)           915210      ['flatten[0][0]']
#
#  activation_1 (Activation)      (None, 10)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            11          ['activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 1)            0           ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 2,569,622
# Trainable params: 2,569,622
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 1. Generate Attention weights for all data

# %%
def generateAttentionWeights(model):
    ## load model with its attention weights using the "Multiply layer" 
    attention_wt_model = tf.keras.models.Model(inputs=model.inputs, outputs=[model.output, model.get_layer('multiply').output])

    ## Set up a set of data for predict call, this case, taking every 10 data point
    data_folder = "/home/yibei/Projects/nucleosome_occupancy/data/train_test_data/"
    # data_folder = "/Users/yibeijia/Downloads/nucleosome_occupancy/data/train_test_data/"

    # load testmat from file
    testmat = scipy.io.loadmat(data_folder+'Test_data.mat')
    batches = 100
    batch_size = round(len(testmat['Test_data'])/batches)
    print(f"batch_size: {batch_size}; batches: {batches}")
    model_outputs=[]
    attention_outputs=[]
    model_outputs0=[]
    attention_outputs0=[]
    model_outputs1=[]
    attention_outputs1=[]

    for i in range(batches):
    # for i in range(2):
        start = i*batch_size
        end = (i+1)*batch_size
        print(f"start: {start}; end: {end}")
        d = testmat['Test_data'][start:end]
        labels = testmat['Test_labels']
        new_labels = labels[0][start:end]

        # get the index of data that is 0 or 1 
        ones = np.flatnonzero(new_labels == np.max(new_labels))
        zeros = np.flatnonzero(new_labels == np.min(new_labels))
    #     print(f'ones.shape {ones.shape}')
    #     print(f'zeros.shape {zeros.shape}')

        # # get all model output and attention weights
        attention_wt = attention_wt_model.predict(np.transpose(d,axes=(0,1,2)))
        model_out = attention_wt[0]
        attention_out = attention_wt[1]
        model_out0=[]
        model_out1=[]
        attention_out0=[]
        attention_out1=[]
    #     print(f'model.shape {len(model_out)}')

        # separate 0 and 1
        attention_out0 = [attention_out[i] for i in zeros]
        attention_out1 = [attention_out[i] for i in ones]
        model_out0 = [model_out[i] for i in zeros]
        model_out1 = [model_out[i] for i in ones]

        # Concatenate current batch with the rest of batches
        if len(attention_outputs) == 0: # if initialize
            model_outputs = model_out
            attention_outputs = attention_out

            model_outputs0 = model_out0
            attention_outputs0 = attention_out0

            model_outputs1 = model_out1
            attention_outputs1 = attention_out1

        else:
            model_outputs = np.concatenate((model_outputs, model_out), axis=0)
            attention_outputs = np.concatenate((attention_outputs, attention_out), axis=0)

            model_outputs0 = np.concatenate((model_outputs, model_out0), axis=0)
            attention_outputs0 = np.concatenate((attention_outputs0, attention_out0), axis=0)

            model_outputs1 = np.concatenate((model_outputs, model_out1), axis=0)
            attention_outputs1 = np.concatenate((attention_outputs1, attention_out1), axis=0)

    r = len(attention_outputs)
    c = len(attention_outputs[0])
    l = len(attention_outputs[0][0])
    print(f"The all attention_outputs Array is {r} x {c} x {l}")

    r = len(attention_outputs0)
    c = len(attention_outputs0[0])
    l = len(attention_outputs0[0][0])
    print(f"The 0 attention_outputs Array is {r} x {c} x {l}")

    r = len(attention_outputs1)
    c = len(attention_outputs1[0])
    l = len(attention_outputs1[0][0])
    print(f"The 1 attention_outputs Array is {r} x {c} x {l}")
    return attention_outputs, attention_outputs0, attention_outputs1
# Out:
# batch_size: 1295; batches: 100
# start: 0; end: 1295
# start: 1295; end: 2590
# start: 2590; end: 3885
# start: 3885; end: 5180
# start: 5180; end: 6475
# start: 6475; end: 7770
# start: 7770; end: 9065
# start: 9065; end: 10360
# start: 10360; end: 11655
# start: 11655; end: 12950
# start: 12950; end: 14245
# start: 14245; end: 15540
# start: 15540; end: 16835
# start: 16835; end: 18130
# start: 18130; end: 19425
# start: 19425; end: 20720
# start: 20720; end: 22015
# start: 22015; end: 23310
# start: 23310; end: 24605
# start: 24605; end: 25900
# start: 25900; end: 27195
# start: 27195; end: 28490
# start: 28490; end: 29785
# start: 29785; end: 31080
# start: 31080; end: 32375
# start: 32375; end: 33670
# start: 33670; end: 34965
# start: 34965; end: 36260
# start: 36260; end: 37555
# start: 37555; end: 38850
# start: 38850; end: 40145
# start: 40145; end: 41440
# start: 41440; end: 42735
# start: 42735; end: 44030
# start: 44030; end: 45325
# start: 45325; end: 46620
# start: 46620; end: 47915
# start: 47915; end: 49210
# start: 49210; end: 50505
# start: 50505; end: 51800
# start: 51800; end: 53095
# start: 53095; end: 54390
# start: 54390; end: 55685
# start: 55685; end: 56980
# start: 56980; end: 58275
# start: 58275; end: 59570
# start: 59570; end: 60865
# start: 60865; end: 62160
# start: 62160; end: 63455
# start: 63455; end: 64750
# start: 64750; end: 66045
# start: 66045; end: 67340
# start: 67340; end: 68635
# start: 68635; end: 69930
# start: 69930; end: 71225
# start: 71225; end: 72520
# start: 72520; end: 73815
# start: 73815; end: 75110
# start: 75110; end: 76405
# start: 76405; end: 77700
# start: 77700; end: 78995
# start: 78995; end: 80290
# start: 80290; end: 81585
# start: 81585; end: 82880
# start: 82880; end: 84175
# start: 84175; end: 85470
# start: 85470; end: 86765
# start: 86765; end: 88060
# start: 88060; end: 89355
# start: 89355; end: 90650
# start: 90650; end: 91945
# start: 91945; end: 93240
# start: 93240; end: 94535
# start: 94535; end: 95830
# start: 95830; end: 97125
# start: 97125; end: 98420
# start: 98420; end: 99715
# start: 99715; end: 101010
# start: 101010; end: 102305
# start: 102305; end: 103600
# start: 103600; end: 104895
# start: 104895; end: 106190
# start: 106190; end: 107485
# start: 107485; end: 108780
# start: 108780; end: 110075
# start: 110075; end: 111370
# start: 111370; end: 112665
# start: 112665; end: 113960
# start: 113960; end: 115255
# start: 115255; end: 116550
# start: 116550; end: 117845
# start: 117845; end: 119140
# start: 119140; end: 120435
# start: 120435; end: 121730
# start: 121730; end: 123025
# start: 123025; end: 124320
# start: 124320; end: 125615
# start: 125615; end: 126910
# start: 126910; end: 128205
# start: 128205; end: 129500
# The all attention_outputs Array is 129500 x 143 x 320
# The 0 attention_outputs Array is 71243 x 143 x 320
# The 1 attention_outputs Array is 58257 x 143 x 320

# %%
attention_outputs, attention_outputs0, attention_outputs1 = generateAttentionWeights(model)
# Out:
# array([[7.3748893e-08],
#        [9.5710639e-09],
#        [7.7675533e-05],
#        ...,
#        [7.9973825e-06],
#        [2.6583543e-01],
#        [9.9999571e-01]], dtype=float32)

# %%
print(len(attention_outputs))
print(len(attention_outputs0))
print(len(attention_outputs1))
# Out:
# 129500
# 71243
# 58257

# %% [markdown]
# # 1. Plot attention score from run10 model for all 5mers

# %%
# if you are using batches the outputs will be in batches
# get exact attentions of chars
i=0 #get attention map for ith sequence
currseq_attention_output = sum(attention_outputs[i])
token = tokenize(ReverseOneHotEncode(d[i]))
char_df = plot_attention_from_seq(token, currseq_attention_output)
(char_df)
# Out:
# <style  type="text/css" >
# #T_e72e8_row0_col0,#T_e72e8_row0_col120{
#             background-color:  #7575ff;
#         }#T_e72e8_row0_col1{
#             background-color:  #fcfcff;
#         }#T_e72e8_row0_col2{
#             background-color:  #c5c5ff;
#         }#T_e72e8_row0_col3,#T_e72e8_row0_col137{
#             background-color:  #7171ff;
#         }#T_e72e8_row0_col4{
#             background-color:  #b3b3ff;
#         }#T_e72e8_row0_col5{
#             background-color:  #2d2dff;
#         }#T_e72e8_row0_col6,#T_e72e8_row0_col42,#T_e72e8_row0_col123{
#             background-color:  #c2c2ff;
#         }#T_e72e8_row0_col7,#T_e72e8_row0_col142{
#             background-color:  #dfdfff;
#         }#T_e72e8_row0_col8,#T_e72e8_row0_col107,#T_e72e8_row0_col119{
#             background-color:  #c9c9ff;
#         }#T_e72e8_row0_col9,#T_e72e8_row0_col63{
#             background-color:  #7b7bff;
#         }#T_e72e8_row0_col10,#T_e72e8_row0_col71{
#             background-color:  #b7b7ff;
#         }#T_e72e8_row0_col11{
#             background-color:  #ceceff;
#         }#T_e72e8_row0_col12{
#             background-color:  #8080ff;
#         }#T_e72e8_row0_col13{
#             background-color:  #6868ff;
#         }#T_e72e8_row0_col14{
#             background-color:  #dedeff;
#         }#T_e72e8_row0_col15,#T_e72e8_row0_col67{
#             background-color:  #6f6fff;
#         }#T_e72e8_row0_col16{
#             background-color:  #f2f2ff;
#         }#T_e72e8_row0_col17,#T_e72e8_row0_col75{
#             background-color:  #cbcbff;
#         }#T_e72e8_row0_col18{
#             background-color:  #eaeaff;
#         }#T_e72e8_row0_col19,#T_e72e8_row0_col105{
#             background-color:  #adadff;
#         }#T_e72e8_row0_col20,#T_e72e8_row0_col35,#T_e72e8_row0_col116,#T_e72e8_row0_col121{
#             background-color:  #cfcfff;
#         }#T_e72e8_row0_col21{
#             background-color:  #ccccff;
#         }#T_e72e8_row0_col22{
#             background-color:  #4040ff;
#         }#T_e72e8_row0_col23{
#             background-color:  #bdbdff;
#         }#T_e72e8_row0_col24,#T_e72e8_row0_col29{
#             background-color:  #8e8eff;
#         }#T_e72e8_row0_col25{
#             background-color:  #d0d0ff;
#         }#T_e72e8_row0_col26{
#             background-color:  #5555ff;
#         }#T_e72e8_row0_col27{
#             background-color:  #8888ff;
#         }#T_e72e8_row0_col28,#T_e72e8_row0_col56,#T_e72e8_row0_col118{
#             background-color:  #b9b9ff;
#         }#T_e72e8_row0_col30{
#             background-color:  #f3f3ff;
#         }#T_e72e8_row0_col31,#T_e72e8_row0_col133{
#             background-color:  #6b6bff;
#         }#T_e72e8_row0_col32{
#             background-color:  #7878ff;
#         }#T_e72e8_row0_col33{
#             background-color:  #efefff;
#         }#T_e72e8_row0_col34{
#             background-color:  #eeeeff;
#         }#T_e72e8_row0_col36{
#             background-color:  #c6c6ff;
#         }#T_e72e8_row0_col37,#T_e72e8_row0_col53{
#             background-color:  #9191ff;
#         }#T_e72e8_row0_col38,#T_e72e8_row0_col138{
#             background-color:  #f0f0ff;
#         }#T_e72e8_row0_col39{
#             background-color:  #3131ff;
#         }#T_e72e8_row0_col40{
#             background-color:  #acacff;
#         }#T_e72e8_row0_col41,#T_e72e8_row0_col80{
#             background-color:  #bebeff;
#         }#T_e72e8_row0_col43{
#             background-color:  #a6a6ff;
#         }#T_e72e8_row0_col44{
#             background-color:  #b0b0ff;
#         }#T_e72e8_row0_col45{
#             background-color:  #9797ff;
#         }#T_e72e8_row0_col46{
#             background-color:  #a8a8ff;
#         }#T_e72e8_row0_col47{
#             background-color:  #e8e8ff;
#         }#T_e72e8_row0_col48,#T_e72e8_row0_col87{
#             background-color:  #8181ff;
#         }#T_e72e8_row0_col49{
#             background-color:  #a9a9ff;
#         }#T_e72e8_row0_col50{
#             background-color:  #7373ff;
#         }#T_e72e8_row0_col51{
#             background-color:  #dadaff;
#         }#T_e72e8_row0_col52,#T_e72e8_row0_col62{
#             background-color:  #6565ff;
#         }#T_e72e8_row0_col54,#T_e72e8_row0_col78,#T_e72e8_row0_col101,#T_e72e8_row0_col108{
#             background-color:  #e3e3ff;
#         }#T_e72e8_row0_col55{
#             background-color:  #f8f8ff;
#         }#T_e72e8_row0_col57,#T_e72e8_row0_col83{
#             background-color:  #c7c7ff;
#         }#T_e72e8_row0_col58{
#             background-color:  #ababff;
#         }#T_e72e8_row0_col59,#T_e72e8_row0_col103{
#             background-color:  #e9e9ff;
#         }#T_e72e8_row0_col60,#T_e72e8_row0_col140{
#             background-color:  #7474ff;
#         }#T_e72e8_row0_col61{
#             background-color:  #e4e4ff;
#         }#T_e72e8_row0_col64{
#             background-color:  #babaff;
#         }#T_e72e8_row0_col65{
#             background-color:  #d5d5ff;
#         }#T_e72e8_row0_col66{
#             background-color:  #ebebff;
#         }#T_e72e8_row0_col68{
#             background-color:  #afafff;
#         }#T_e72e8_row0_col69{
#             background-color:  #6262ff;
#         }#T_e72e8_row0_col70{
#             background-color:  #2929ff;
#         }#T_e72e8_row0_col72{
#             background-color:  #9696ff;
#         }#T_e72e8_row0_col73,#T_e72e8_row0_col136{
#             background-color:  #9a9aff;
#         }#T_e72e8_row0_col74,#T_e72e8_row0_col130{
#             background-color:  #e0e0ff;
#         }#T_e72e8_row0_col76,#T_e72e8_row0_col102{
#             background-color:  #a2a2ff;
#         }#T_e72e8_row0_col77{
#             background-color:  #a7a7ff;
#         }#T_e72e8_row0_col79,#T_e72e8_row0_col81{
#             background-color:  #a5a5ff;
#         }#T_e72e8_row0_col82{
#             background-color:  #7d7dff;
#         }#T_e72e8_row0_col84,#T_e72e8_row0_col124{
#             background-color:  #cdcdff;
#         }#T_e72e8_row0_col85,#T_e72e8_row0_col97{
#             background-color:  #8585ff;
#         }#T_e72e8_row0_col86{
#             background-color:  #e5e5ff;
#         }#T_e72e8_row0_col88{
#             background-color:  #4c4cff;
#         }#T_e72e8_row0_col89{
#             background-color:  #8b8bff;
#         }#T_e72e8_row0_col90{
#             background-color:  #9494ff;
#         }#T_e72e8_row0_col91{
#             background-color:  #bbbbff;
#         }#T_e72e8_row0_col92{
#             background-color:  #d6d6ff;
#         }#T_e72e8_row0_col93{
#             background-color:  #5858ff;
#         }#T_e72e8_row0_col94,#T_e72e8_row0_col117,#T_e72e8_row0_col141{
#             background-color:  #7777ff;
#         }#T_e72e8_row0_col95{
#             background-color:  #8f8fff;
#         }#T_e72e8_row0_col96{
#             background-color:  #d3d3ff;
#         }#T_e72e8_row0_col98{
#             background-color:  #e1e1ff;
#         }#T_e72e8_row0_col99{
#             background-color:  #0000ff;
#         }#T_e72e8_row0_col100{
#             background-color:  #7979ff;
#         }#T_e72e8_row0_col104{
#             background-color:  #c8c8ff;
#         }#T_e72e8_row0_col106,#T_e72e8_row0_col110{
#             background-color:  #9090ff;
#         }#T_e72e8_row0_col109{
#             background-color:  #bfbfff;
#         }#T_e72e8_row0_col111{
#             background-color:  #8787ff;
#         }#T_e72e8_row0_col112,#T_e72e8_row0_col132{
#             background-color:  #8686ff;
#         }#T_e72e8_row0_col113,#T_e72e8_row0_col122{
#             background-color:  #6e6eff;
#         }#T_e72e8_row0_col114{
#             background-color:  #5151ff;
#         }#T_e72e8_row0_col115{
#             background-color:  #4747ff;
#         }#T_e72e8_row0_col125{
#             background-color:  #bcbcff;
#         }#T_e72e8_row0_col126{
#             background-color:  #a3a3ff;
#         }#T_e72e8_row0_col127{
#             background-color:  #c4c4ff;
#         }#T_e72e8_row0_col128{
#             background-color:  #9595ff;
#         }#T_e72e8_row0_col129{
#             background-color:  #0808ff;
#         }#T_e72e8_row0_col131{
#             background-color:  #c3c3ff;
#         }#T_e72e8_row0_col134{
#             background-color:  #e2e2ff;
#         }#T_e72e8_row0_col135{
#             background-color:  #5757ff;
#         }#T_e72e8_row0_col139{
#             background-color:

# %%
mapped = dict(zip(token, currseq_attention_output))
print(mapped)
# Out:
# {'CATGC': 0.31830943, 'ATGCT': 0.016259491, 'TGCTA': 0.05800696, 'GCTAT': 0.19455113, 'CTATC': 0.18132968, 'TATCT': 0.47961965, 'ATCTT': 0.14670761, 'TCTTG': 0.08188573, 'CTTGT': 0.13063614, 'TTGTT': 0.30594188, 'TGTTT': 0.12208975, 'GTTTT': 0.2825193, 'TTTTT': 0.29415622, 'TTTTG': 0.34815067, 'TTTGT': 0.08404341, 'TTGTG': 0.331254, 'TGTGC': 0.040244393, 'GTGCT': 0.12662192, 'CTATG': 0.11822446, 'TATGT': 0.124241985, 'ATGTT': 0.13544737, 'TGTTA': 0.24178177, 'GTTAA': 0.26334694, 'TTAAA': 0.11507716, 'TAAAA': 0.3903092, 'AAAAG': 0.27615893, 'AAAGT': 0.16646147, 'AAGTG': 0.26397797, 'AGTGG': 0.036835663, 'GTGGA': 0.34128472, 'TGGAA': 0.312187, 'GGAAG': 0.045469657, 'GAAGA': 0.049688682, 'AAGAC': 0.117736265, 'AGACC': 0.13801822, 'GACCC': 0.25526172, 'ACCCA': 0.044001736, 'CCCAG': 0.4706448, 'CCAGA': 0.19629858, 'CAGAT': 0.1563096, 'AGATG': 0.21059515, 'GATGT': 0.30152336, 'GTTAT': 0.2057088, 'TTATC': 0.061627127, 'TATCA': 0.2909711, 'ATCAT': 0.2032266, 'TCATA': 0.3828196, 'CATAG': 0.3144778, 'ATAGG': 0.35543603, 'TAGGC': 0.25533557, 'AGGCC': 0.07261188, 'GGCCA': 0.025723899, 'GCCAT': 0.16586457, 'CCATC': 0.13678503, 'CATCG': 0.1977897, 'ATCGT': 0.06018271, 'TCGTT': 0.31385472, 'CGTTT': 0.08209, 'GTTTG': 0.35365313, 'TTTGC': 0.30609834, 'TTGCA': 0.16366245, 'TGCAA': 0.10420876, 'GCAAA': 0.055673867, 'CAAAA': 0.33274505, 'AAAAT': 0.18925326, 'AAATG': 0.3606358, 'AATGT': 0.4879652, 'ATGTC': 0.17140816, 'TGTCT': 0.24581088, 'GTCTA': 0.23517361, 'TCTAC': 0.08073196, 'CTACT': 0.1258971, 'TACTT': 0.21920086, 'ACTTA': 0.20608447, 'CTTAG': 0.07412242, 'TTAGA': 0.2106463, 'TAGAT': 0.15480414, 'TTTTA': 0.06815539, 'TTTAG': 0.29090536, 'TTAGC': 0.40929106, 'TAGCT': 0.2702267, 'AGCTC': 0.14319922, 'GCTCA': 0.16237357, 'CTCAT': 0.10226423, 'ATAGA': 0.26057434, 'TAGAA': 0.10939768, 'AGAAT': 0.28215048, 'GAATG': 0.078268275, 'AATGC': 0.5789598, 'ATGCA': 0.30977798, 'TGCAT': 0.07402541, 'GCATG': 0.21821591, 'CATGA': 0.06040638, 'ATGAT': 0.13287437, 'TGATC': 0.19304897, 'GATCT': 0.2588235, 'ATCTC': 0.13066626, 'TCTCA': 0.07247278, 'CTCAA': 0.15326086, 'TCAAC': 0.25884324, 'CAACA': 0.27908385, 'AACAT': 0.28068227, 'ACATT': 0.33510995, 'CATTC': 0.39924598, 'ATTCC': 0.42110956, 'TTCCA': 0.11775626, 'TCCAA': 0.31359178, 'CCAAC': 0.16711298, 'CAACG': 0.13144335, 'AACGT': 0.31799316, 'ACGTT': 0.11833865, 'CGTTC': 0.33527803, 'GTTCA': 0.14624673, 'TTCAG': 0.12284699, 'TCAGC': 0.16000076, 'CAGCT': 0.21508473, 'GCTCT': 0.24717063, 'CTCTA': 0.5614965, 'TCTAT': 0.08035732, 'CTATT': 0.1435266, 'TATTG': 0.28087068, 'ATTGG': 0.34091762, 'TTGGC': 0.07538087, 'TGGCC': 0.38496223, 'GGCCG': 0.23558873, 'GCCGT': 0.32799757, 'CCGTC': 0.04331973, 'CGTCG': 0.2955153, 'GTCGT': 0.32081452}

# %% [markdown]
# ## 1.1 Don't add reverse Complements scores and treat them separately

# %%
# Put all the 5mers and their added total attention scores across sequences in dictionary
def sumAttentionforAllKmers(attention_outputs):
    from IPython.display import display
    mapped = {}
    kmerCounts = {}

    print(f"Total Num SEq: {len(attention_outputs)}")
    d=testmat['Test_data'] # need to redefine d

    for seq in range(len(attention_outputs)):
    # for seq in range(1,500):

        # tokens are the 5mers in the current sequence
        tokens = tokenize(ReverseOneHotEncode(d[seq]))

        # for 147bp each sequence, there are 320 feature scores for each bp

        #     for i in range(len(attention_outputs[0])):
        for i in range(len(tokens)):
    #         print(token)
            token = tokens[i]
            if token in kmerCounts.keys():
                kmerCounts[token] = kmerCounts[token] + 1
            else:
                kmerCounts[token] = 1
            five_mer_attention_output = sum(attention_outputs[seq][i])
            if token in mapped.keys():  # if a 5mer is found
                mapped[token] = mapped[token] + five_mer_attention_output #increase value
            else: #if 5mer not seen yet
                mapped[token] = five_mer_attention_output
    #     char_df = plot_attention_from_seq(tokens, mapped[token])
    #     display(char_df)

    # Plot the mapped dictionary for each 5 mer; Darker means higher attention score
    import collections

    # char_df = plot_attention_from_map(mapped)
    # display(char_df)

    ordered_map = collections.OrderedDict(sorted(mapped.items()))
    return ordered_map, kmerCounts

# displayLength= 16
# print(len(list(ordered_map.items()))/displayLength)
# for i in range(int(len(list(ordered_map.items()))/displayLength)):
#     display_dict = dict(list(ordered_map.items())[i*displayLength:(i+1)*displayLength])
#     char_df = plot_attention_from_map(display_dict)
#     display(char_df)

# %%
# ordered_map, kmerCounts = sumAttentionforAllKmers(attention_outputs)
ordered_map0, kmerCounts0 = sumAttentionforAllKmers(attention_outputs0)
ordered_map1, kmerCounts1 = sumAttentionforAllKmers(attention_outputs1)
# Out:
# Total Num SEq: 71243
# Total Num SEq: 58257

# %%
# print(ordered_kmerCounts.keys())
# ordered_map = collections.OrderedDict(sorted(mapped.items()))
def normKmerCount(ordered_map, kmerCounts):
    ordered_map_norm = {}
    for k, _ in ordered_map.items():
        v = ordered_map[k] / kmerCounts[k]
        ordered_map_norm[k] = v
    return ordered_map_norm

# %%
# ordered_map_norm = normKmerCount(ordered_map, kmerCounts)
ordered_map_norm0 = normKmerCount(ordered_map0, kmerCounts0)
ordered_map_norm1 = normKmerCount(ordered_map1, kmerCounts1)

print(len(mapped))
print(len(ordered_map))
print(len(ordered_map_norm0))
print(len(ordered_map_norm1))
# Out:
# 129
# 1024
# 1024
# 1024

# %%
ordered_map0
# Out:
# OrderedDict([('AAAAA', 89147.10620040272),
#              ('AAAAC', 8842.302913689844),
#              ('AAAAG', 12107.4992863259),
#              ('AAAAT', 17484.47524334238),
#              ('AAACA', 8493.457465622289),
#              ('AAACC', 4640.756572673408),
#              ('AAACG', 3841.5161209276976),
#              ('AAACT', 7033.533415134097),
#              ('AAAGA', 11876.442254828173),
#              ('AAAGC', 5194.92584655021),
#              ('AAAGG', 6121.069099394799),
#              ('AAAGT', 7689.200883927082),
#              ('AAATA', 14208.046386460144),
#              ('AAATC', 7150.397572734042),
#              ('AAATG', 8657.96972656269),
#              ('AAATT', 13896.468224734734),
#              ('AACAA', 10604.958479273278),
#              ('AACAC', 4095.4189510071096),
#              ('AACAG', 5399.682589992344),
#              ('AACAT', 6589.6918845979135),
#              ('AACCA', 5425.369623080609),
#              ('AACCC', 2548.183313650303),
#              ('AACCG', 2103.070767106605),
#              ('AACCT', 3747.5302244281293),
#              ('AACGA', 4212.3710534507345),
#              ('AACGC', 2191.648840101492),
#              ('AACGG', 2682.208124531934),
#              ('AACGT', 3523.9239236397943),
#              ('AACTA', 4891.057835850662),
#              ('AACTC', 3447.4351573406075),
#              ('AACTG', 4464.199747370138),
#              ('AACTT', 7104.23368843555),
#              ('AAGAA', 14022.884874684392),
#              ('AAGAC', 4627.639096327509),
#              ('AAGAG', 5937.98049017126),
#              ('AAGAT', 7829.196559890967),
#              ('AAGCA', 5303.332484143167),
#              ('AAGCC', 2855.455682359513),
#  'GTGAA': 10855,
#  'TGAAC': 11091,
#  'GAACC': 7564,
#  'AACCA': 13308,
#  'ACCAG': 9327,
#  'CCAGA': 8593,
#  'CAGAC': 5725,
#  'AGACC': 6054,
#  'GACCA': 7669,
#  'ACCAA': 15897,
#  'CCAAG': 10890,
#  'CAAGG': 9854,
#  'AAGGG': 7937,
#  'AGGGA': 6405,
#  'GGGAT': 5239,
#  'GATAC': 8319,
#  'ATACA': 15089,
#  'TACAC': 7414,
#  'ACACG': 4288,
#  'CACGG': 3416,
#  'ACGGG': 3000,
#  'CGGGA': 2879,
#  'GGATT': 9366,
#  'GATTT': 17649,
#  'ATTTT': 42882,
#  'TTTTA': 32449,
#  'TTTAG': 13316,
#  'TTAGC': 8207,
#  'TAGCG': 5054,
#  'AGCGC': 3633,
#  'GCGCT': 3641,
#  'CGCTT': 5724,
#  'GCTTT': 12880,
#  'CTTTG': 15152,
#  'TTTGT': 20991,
#  'TTGTG': 10646,
#  'TGTGC': 6184,
#  'GTGCT': 7383,
#  'TGCTA': 9792,
#  'GCTAC': 6053,
#  'CTACA': 8576,
#  'TACAA': 15948,
#  'ACAAT': 17259,
#  'CAATA': 17454,
#  'AATAG': 14786,
#  'AGTGG': 7870,
#  'GTGGA': 7981,
#  'TGGAA': 16891,
#  'GGAAG': 11042,
#  'GAAGA': 21524,
#  'AAGAA': 34483,
#  'AGAAA': 31213,
#  'GAAAT': 21314,
#  'AAATC': 18026,
#  'AATCT': 15138,
#  'ATCTT': 18560,
#  'TTGTC': 11665,
#  'TGTCA': 10933,
#  'GTCAC': 6379,
#  'TCACC': 9008,
#  'CACCC': 4617,
#  'ACCCA': 7974,
#  'CCCAA': 8760,
#  'CCAAT': 12869,
#  'CAATG': 13978,
#  'AATGA': 20343,
#  'ATGAT': 18170,
#  'TGATC': 9251,
#  'GATCT': 8860,
#  'ATCTC': 9630,
#  'TCTCA': 10461,
#  'CTCAT': 9717,
#  'TCATA': 13473,
#  'CATAG': 6996,
#  'ATAGC': 8109,
#  'GCGCG': 1510,
#  'CGCGT': 2163,
#  'GCGTC': 3717,
#  'CGTCC': 3570,
#  'GTCCA': 6857,
#  'TCCAG': 8375,
#  'CCAGG': 4964,
#  'CAGGA': 7433,
#  'AGGAG': 7122,
#  'GGAGG': 5392,
#  'GAGGA': 9327,
#  'AGGAC': 5954,
#  'GGACC': 4006,
#  'ATGAA': 21882,
#  'TGAAT': 17549,
#  'GAATA': 16231,
#  'TAGTA': 12147,
#  'AGTAT': 12998,
#  'GTATT': 14886,
#  'TATTT': 34193,
#  'CATTA': 15150,
#  'ATTAG': 11075,
#  'TTAGA': 12618,
#  'TAGAA': 16150,
#  'AAATT': 34375,
#  'AATTT': 34192,
#  'TTTAA': 24600,
#  'TTAAA': 24642,
#  'TAAAA': 34453,
#  'AAAAG': 30185,
#  'AAAGA': 29116,
#  'AGAAG': 18087,
#  'GAAGC': 9182,
#  'AAGCT': 10925,
#  'AGCTT': 10726,
#  'CTTTA': 15547,
#  'TAAAC': 12377,
#  'AAACT': 17273,
#  'AACTA': 12410,
#  'ACTAC': 8914,
#  'ACAAA': 21171,
#  'CAAAG': 15410,
#  'AAAGT': 18802,
#  'AAGTG': 9978,
#  'GTGTT': 9776,
#  'TGTTC': 11762,
#  'GTTCT': 11630,
#  'TTCTT': 34067,
#  'TCTTC': 21347,
#  'CTTCT': 18586,
#  'TTCTG': 13925,
#  'TCTGA': 10077,
#  'CTGAA': 12378,
#  'GAATC': 9626,
#  'ATCTG': 10461,
#  'AATAA': 33789,
#  'ATAAG': 12195,
#  'TAAGG': 7992,
#  'AAGGT': 11447,
#  'AGGTC': 5209,
#  'GGTCA': 6966,
#  'TCACT': 9683,
#  'CACTT': 10151,
#  'ACTTA': 9566,
#  'CTTAC': 7956,
#  'TTACA': 13442,
#  'TACAT': 14025,
#  'ACATA': 13546,
#  'ATAGA': 13506,
#  'GAAAC': 12814,
#  'AAACC': 11393,
#  'AACCT': 9377,
#  'ACCTA': 6338,
#  'CCTAC': 4510,
#  'CTACT': 9350,
#  'TACTT': 14948,
#  'TTACC': 10999,
#  'TACCT': 8695,
#  'ACCTC': 6527,
#  'CCTCA': 7156,
#  'CTCAA': 11445,
#  'TCAAA': 24432,
#  'CAAAA': 28741,
#  'AAAGC': 12984,
#  'AAGCG': 5702,
#  'AGCGT': 5715,
#  'GCGTA': 4271,
#  'CGTAA': 6604,
#  'GTAAT': 13238,
#  'TAATT': 21583,
#  'AATTC': 17229,
#  'ATTCC': 10930,
#  'TTCCG': 6083,
#  'TCCGA': 4297,
#  'CCGAA': 5545,
#  'CGAAA': 10333,
#  'GAAAG': 15024,
#  'AAAGG': 15251,
#  'AAGGC': 8596,
#  'AGGCA': 7470,
#  'GGCAA': 9248,
#  'GCAAA': 14305,
#  'GAAAA': 35483,
#  'AAAAA': 226065,
#  'AAAAC': 21638,
#  'AACTT': 17360,
#  'ACTTT': 18682,
#  'CTTTT': 29504,
#  'TTTTG': 26925,
#  'TTGTA': 15770,
#  'TGTAG': 8688,
#  'GTAGA': 9132,
#  'AGAAT': 18409,
#  'CTTCA': 15963,
#  'TTCAG': 12026,
#  'TCAGC': 7733,
#  'CAGCT': 7607,
#  'AGCTG': 8022,
#  'GCTGC': 8139,
#  'CTGCT': 10469,
#  'GCTAG': 4918,
#  'CTAGA': 7232,
#  'GAAGT': 12058,
#  'AAGTT': 17424,
#  'GGCAT': 6742,
#  'GCATC': 7748,
#  'CATCC': 8437,
#  'ATCCT': 9983,
#  'TCCTC': 9644,
#  'CCTCT': 8870,
#  'CTCTC': 6822,
#  'TCTCT': 13038,
#  'CTCTG': 7483,
#  'TCTGT': 10442,
#  'CTGTT': 12525,
#  'TGTTG': 16784,
#  'GTTGC': 8790,
#  'TTGCT': 14145,
#  'TGCTT': 13005,
#  'GCTTA': 6943,
#  'ACACC': 7737,
#  'CACCA': 12786,
#  'ACCAT': 12193,
#  'CCATC': 9693,
#  'CATCA': 15743,
#  'ATCAA': 21005,
#  'TCAAC': 12638,
#  'CAACA': 18112,
#  'AACAT': 16285,
#  'ACATC': 10647,
#  'CTCTT': 14948,
#  'TCTTT': 28715,
#  'TTAAG': 10286,
#  'TAAGT': 9636,
#  'AAGTC': 8850,
#  'AGTCA': 8521,
#  'GTCAG': 5435,
#  'TCAGG': 5905,
#  'CAGGT': 6727,
#  'AGGTT': 9526,
#  'GGTTG': 7698,
#  'CAAAT': 20689,
#  'AAATA': 35031,
#  'AATAC': 14857,
#  'ATACT': 12676,
#  'TACTA': 12401,
#  'ACTAA': 10952,
#  'CTAAT': 11134,
#  'TAATG': 14968,
#  'AATGT': 15194,
#  'ATGTA': 13828,
#  'TGTAC': 8551,
#  'GTACA': 8934,
#  'TACAG': 8639,
#  'ACAGA': 11323,
#  'AGACG': 5637,
#  'GACGA': 7305,
#  'ACGAG': 5260,
#  'CGAGT': 3473,
#  'GAGTT': 8572,
#  'AGTTT': 17145,
#  'GTTTA': 12618,
#  'TTAAC': 11574,
#  'TAACA': 14142,
#  'AACAA': 26464,
#  'ACAAC': 13763,
#  'CAACG': 7787,
#  'AACGG': 6598,
#  'ACGGA': 5186,
#  'CGGAA': 6120,
#  'GGAAT': 10765,
#  'AATCG': 6852,
#  'TCGAC': 4833,
#  'CGACG': 3704,
#  'ACGAC': 5605,
#  'CGACC': 2971,
#  'GACCG': 2901,
#  'ACCGT': 6372,
#  'CCGTT': 6434,
#  'CGTTT': 9393,
#  'GTTTT': 21455,
#  'AGAAC': 12051,
#  'AACGA': 10457,
#  'CGACT': 3771,
#  'GACTA': 5739,
#  'CTAAC': 6868,
#  'AACAG': 13263,
#  'ACAGT': 9808,
#  'CAGTT': 10585,
#  'AGTTC': 9589,
#  'GTTCC': 7172,
#  'TTCCA': 16462,
#  'CCAGT': 7839,
#  'CAGTA': 10400,
#  'AGTAC': 8789,
#  'GTACG': 4571,
#  'TACGT': 6730,
#  'ACGTT': 8871,
#  'TTAGT': 10587,
#  'TAGTC': 5527,
#  'AGTCT': 7014,
#  'GTCTG': 5484,
#  'TCTGG': 8594,
#  'CTGGT': 9433,
#  'GCATT': 10531,
#  'CATTT': 21154,
#  'ATTTG': 19453,
#  'TTTGC': 13765,
#  'CTTAA': 10279,
#  'TAAGC': 6436,
#  'AAGCA': 13132,
#  'AGCAA': 14373,
#  'GCAAG': 8308,
#  'AAGGA': 15323,
#  'AGGAT': 10207,
#  'ATACC': 9650,
#  'TACCG': 6375,
#  'ACCGA': 5630,
#  'AAATG': 21548,
#  'ATGTC': 9324,
#  'CAGGG': 3979,
#  'AGGGG': 3219,
#  'GGGGT': 3339,
#  'GGGTT': 5948,
#  'GGTTC': 7010,
#  'GTTCG': 4690,
#  'TTCGA': 9485,
#  'TCGAG': 4958,
#  'CGAGC': 3099,
#  'GAGCC': 4302,
#  'AGCCC': 3897,
#  'GCCCC': 2633,
#  'CCCCC': 2443,
#  'CCCCT': 3432,
#  'CCCTA': 3736,
#  'CCTAT': 6310,
#  'CTATG': 7069,
#  'TATGA': 13285,
#  'ATGAG': 9966,
#  'TGAGG': 7068,
#  'GGAGT': 5244,
#  'TTTAT': 30991,
#  'TTATT': 33567,
#  'TTTTT': 80416,
#  'TCAGT': 8983,
#  'AGTAA': 14033,
#  'GTAAC': 8302,
#  'TAACT': 11323,
#  'ACTAT': 12520,
#  'CTATT': 14206,
#  'TATTC': 16234,
#  'ATTCG': 7488,
#  'TTCGG': 5358,
#  'TCGGG': 2283,
#  'CGGGT': 2766,
#  'GGGTA': 5646,
#  'GGTAC': 6831,
#  'GTACC': 6765,
#  'TACCA': 13602,
#  'TTTTC': 34639,
#  'TTTCT': 30065,
#  'TTTCC': 17150,
#  'TTCCC': 8175,
#  'TCCCC': 3743,
#  'CCCCA': 4835,
#  'CCCAC': 4553,
#  'CCACT': 7787,
#  'CACTA': 8446,
#  'TATAA': 21712,
#  'ATAAA': 31954,
#  'AAACG': 9540,
#  'GAGTC': 4548,
#  'CTATC': 8447,
#  'TATCA': 17390,
#  'TCAAT': 19074,
#  'CAATT': 19015,
#  'TCCCT': 6543,
#  'CCCTT': 7669,
#  'CCTTC': 10200,
#  'TTCAA': 25591,
#  'TCAAG': 13526,
#  'CAAGC': 8248,
#  'GGGTC': 3551,
#  'GGTCG': 2941,
#  'GTCGT': 5832,
#  'TCGTA': 6668,
#  'CGTAT': 7123,
#  'ATTTA': 23917,
#  'TAAGA': 12499,
#  'GTTCA': 10932,
#  'CAGGC': 4433,
#  'AGGCG': 3858,
#  'GGCGA': 4023,
#  'GCGAG': 2756,
#  'GAGTA': 7057,
#  'GTAAG': 7669,
#  'AGCTC': 6069,
#  'GCTCC': 4475,
#  'CTCCA': 9517,
#  'TCCAA': 15838,
#  'CCAAC': 9736,
#  'CAGTG': 7560,
#  'AGTGA': 9523,
#  'GTGAC': 5885,
#  'TGACT': 8258,
#  'GACTG': 5165,
#  'ACTGA': 8970,
#  'CTGAG': 5217,
#  'TGAGA': 10262,
#  'GAGAA': 14353,
#  'AAGTA': 15262,
#  'AGTAG': 9099,
#  'GTAGC': 6228,
#  'TAGCA': 9956,
#  'AAGAG': 14806,
#  'AGAGC': 7218,
#  'AGCCA': 8197,
#  'GCCAA': 10188,
#  'CCAAA': 17205,
#  'CAAAC': 12275,
#  'AAACA': 20946,
#  'CAACC': 7956,
#  'AACCC': 6230,
#  'ACCCC': 3685,
#  'CCCAT': 7627,
#  'CCATA': 9476,
#  'CATAA': 13306,
#  'GAGCT': 6221,
#  'CTTTC': 15307,
#  'CTGAC': 5539,
#  'TGACG': 7101,
#  'GACGC': 3588,
#  'ACGCT': 5270,
#  'CGCTG': 5010,
#  'GCTGA': 7794,
#  'ACGAA': 10182,
#  'CGAAT': 7126,
#  'CGAGA': 4958,
#  'GAGAT': 9497,
#  'AGATT': 15151,
#  'GATTG': 9753,
#  'ATTGG': 12699,
#  'TTGGC': 10195,
#  'TGGCG': 5118,
#  'CGAGG': 3890,
#  'GAGGT': 6325,
#  'AGGTA': 8780,
#  'GGTAT': 9865,
#  'GTATG': 8493,
#  'TGATG': 15576,
#  'GATGG': 9315,
#  'ATGGG': 7286,
#  'TGGGA': 7393,
#  'GGGAG': 3893,
#  'GAGGG': 4211,
#  'GGGGC': 2443,
#  'GGGCG': 2289,
#  'GAGCA': 7108,
#  'AGCAC': 7382,
#  'GCACA': 6624,
#  'CACAA': 10838,
#  'CTGAT': 9881,
#  'ATGGT': 12304,
#  'TGGTG': 12301,
#  'GGTGG': 7658,
#  'GTGGT': 9785,
#  'GGTGT': 7624,
#  'ACATT': 15709,
#  'CATTG': 14283,
#  'TTGGT': 15069,
#  'TGGTC': 7747,
#  'GTCAT': 10418,
#  'CATAT': 15942,
#  'ATATT': 30766,
#  'TATTA': 25350,
#  'ATTAT': 27399,
#  'ATTAC': 13360,
#  'TTTGG': 15594,
#  'TGGCT': 8360,
#  'GGCTC': 4183,
#  'GCTCT': 7028,
#  'CTTGG': 10493,
#  'TGGTT': 12915,
#  'TTCTA': 15958,
#  'TCTAC': 9611,
#  'TACTG': 10130,
#  'ACTGT': 9189,
#  'TTATG': 12748,
#  'TGGGT': 7652,
#  'GGGTG': 4530,
#  'TGGTA': 13620,
#  'ATGTT': 15519,
#  'GTTGG': 9750,
#  'TGGCC': 6121,
#  'GGCCG': 2223,
#  'GCCGG': 2482,
#  'CCGGT': 4251,
#  'CGGTA': 6448,
#  'GTACT': 8277,
#  'CTACC': 6692,
#  'AATCA': 16617,
#  'ATCAC': 9591,
#  'AGGTG': 7403,
#  'GGTGA': 8636,
#  'AATAT': 30624,
#  'ATATC': 15767,
#  'TATCT': 14193,
#  'CTCTA': 8405,
#  'CAAGA': 16771,
#  'AAGAT': 19158,
#  'AGATG': 12409,
#  'GGTAA': 11153,
#  'GTAAA': 15924,
#  'ATTGA': 18923,
#  'TTGAA': 25743,
#  'TGAAG': 16443,
#  'GAAGG': 10116,
#  'GGATC': 5804,
#  'ATCTA': 11919,
#  'TCTAA': 12417,
#  'CTAAA': 13337,
#  'TAAAT': 23489,
#  'ATCAT': 18405,
#  'TCATC': 16392,
#  'CATCG': 7946,
#  'CGATG': 8067,
#  'GATGT': 10115,
#  'GAACA': 12668,
#  'AACAC': 9963,
#  'ACACA': 9254,
#  'CACAT': 9169,
#  'TCACG': 4702,
#  'CACGC': 3224,
#  'GCTGG': 6554,
#  'CTGGA': 8437,
#  'ATCGT': 8714,
#  'CGTCG': 3731,
#  'CTTCG': 7296,
#  'TTCGT': 9864,
#  'TAATC': 10412,
#  'CTGTG': 6723,
#  'GTGCC': 4838,
#  'TGCCA': 10384,
#  'CTAAG': 6389,
#  'AGCTA': 7303,
#  'GCTAT': 8124,
#  'TCTAG': 7020,
#  'CTAGT': 6577,
#  'AGTGC': 5786,
#  'TGCCC': 4693,
#  'GCCCT': 4364,
#  'CCCTC': 4461,
#  'ATTCT': 18127,
#  'TTCAT': 21661,
#  'ATCCG': 4932,
#  'TCCGT': 5001,
#  'CCGTG': 3374,
#  'CGTGT': 4310,
#  'CAGCA': 12564,
#  'AGCAT': 10280,
#  'TCGTG': 5032,
#  'CGTGG': 4145,
#  'GTGGG': 4615,
#  'GGGAC': 3173,
#  'TGTTT': 21005,
#  'TTTCG': 10567,
#  'TCGGC': 3221,
#  'CGGCT': 3403,
#  'GGCTT': 7445,
#  'GCTTG': 7896,
#  'CTTGA': 13247,
#  'GCAAT': 11288,
#  'TTTGA': 23510,
#  'GAACT': 9428,
#  'CTGGG': 4750,
#  'GGGAA': 8070,
#  'GGAAA': 17321,
#  'TCACA': 9035,
#  'CACAG': 7165,
#  'CAGAT': 10456,
#  'GATTC': 9897,
#  'TCTTA': 12143,
#  'CTTAT': 11827,
#  'TGAAA': 25774,
#  'GATAA': 16070,
#  'TAAAG': 15533,
#  'TTCGC': 5307,
#  'TCGCA': 4899,
#  'CGCAG': 4164,
#  'GCAGT': 7190,
#  'CGATT': 7150,
#  'GATTA': 10782,
#  'ATTAA': 21311,
#  'TTAAT': 20689,
#  'TCATT': 20512,
#  'ATTTC': 21051,
#  'TGGCA': 10143,
#  'GGCAC': 5119,
#  'GCTAA': 8188,
#  'ATAAT': 27158,
#  'TAATA': 25274,
#  'AATCC': 9560,
#  'ATCCA': 12174,
#  'TCCAC': 8173,
#  'CCACC': 8153,
#  'AATGC': 10994,
#  'ATGCA': 11064,
#  'TGCAC': 6337,
#  'GCACT': 5684,
#  'AAGCC': 7128,
#  'CAACT': 11257,
#  'TTTAC': 15663,
#  'TACCC': 5441,
#  'ACCCG': 2864,
#  'CCCGT': 3168,
#  'CCGTA': 4792,
#  'GTATC': 8283,
#  'ATAGG': 6639,
#  'TAGGA': 6630,
#  'TTTCA': 25997,
#  'CTGGC': 5262,
#  'GGCCA': 6399,
#  'CAATC': 10100,
#  'CTTCC': 10786,
#  'CGTAG': 4417,
#  'GATGA': 17201,
#  'TGATA': 16884,
#  'TGATT': 16422,
#  'GCATA': 8236,
#  'TAGGT': 6404,
#  'GGTTT': 11529,
#  'ATCGC': 5193,
#  'CAGTC': 5278,
#  'GTCGG': 2904,
#  'CGGCA': 4839,
#  'CCAGC': 6395,
#  'GCTCA': 6347,
#  'CTCAG': 5322,
#  'AGTTG': 11458,
#  'ATATA': 34506,
#  'TATAC': 12715,
#  'ATACG': 6980,
#  'TACGA': 7090,
#  'ACGAT': 9061,
#  'CGTAC': 4399,
#  'ACCTG': 6863,
#  'CCTGA': 6121,
#  'CTAGC': 4708,
#  'AGCAG': 10713,
#  'GCAGG': 5179,
#  'GGACT': 4742,
#  'ACTGG': 7917,
#  'GTAGT': 8944,
#  'GGTTA': 7233,
#  'GTTAG': 6874,
#  'TTAGG': 6229,
#  'TAGGG': 3752,
#  'AGGGT': 5929,
#  'GTTGT': 12741,
#  'TCAGA': 10014,
#  'ATTGT': 17440,
#  'TATCC': 8844,
#  'ATCCC': 5527,
#  'CCTTT': 15191,
#  'GACGT': 5256,
#  'ACGTA': 6816,
#  'CCTAA': 6180,
#  'TCCTT': 15072,
#  'CCTTG': 9387,
#  'TGTAA': 13328,
#  'GACTT': 8616,
#  'ACTTG': 10968,
#  'TGCTC': 7291,
#  'CTCCC': 4127,
#  'GGATG': 8314,
#  'ATTCA': 17584,
#  'TTCAC': 11228,
#  'GGTCC': 3638,
#  'GTTTC': 12759,
#  'TTCCT': 15355,
#  'AAGAC': 11506,
#  'AGACA': 10454,
#  'GACAA': 12043,
#  'GGTAG': 6669,
#  'TAGCT': 7353,
#  'CTGTC': 6460,
#  'GTCAA': 11635,
#  'CCCCG': 1807,
#  'AACGC': 5412,
#  'ACGCA': 4918,
#  'CGCAA': 5917,
#  'AACTC': 8536,
#  'ACTCA': 7741,
#  'ATCGG': 4671,
#  'GAGTG': 4894,
#  'TGTCC': 6484,
#  'GTCCT': 5756,
#  'AGGAA': 15446,
#  'GGAAC': 7424,
#  'ACCCT': 5766,
#  'CCCTG': 4254,
#  'CCTGT': 6661,
#  'CGTGA': 4715,
#  'GTGAT': 9503,
#  'TTGAC': 10846,
#  'CAAGT': 11001,
#  'CTTGC': 8440,
#  'TTGCA': 13144,
#  'TGCAA': 13331,
#  'TAGAT': 11489,
#  'TCCAT': 12662,
#  'CCATT': 14562,
#  'AGATA': 14246,
#  'AATTG': 18849,
#  'ATTGC': 11483,
#  'GCTTC': 9177,
#  'TCGTT': 10170,
#  'CGTTA': 7762,
#  'TTATA': 21398,
#  'TATAG': 10606,
#  'TAGAC': 6337,
#  'AGACT': 7225,
#  'TGACA': 10973,
#  'GACAT': 9335,
#  'TATGC': 8154,
#  'TGCAG': 8567,
#  'AAAAT': 43543,
#  'CATAC': 8491,
#  'ACTTC': 11939,
#  'CATCT': 12360,
#  'CTTAG': 6387,
#  'AATTA': 21814,
#  'ATGGC': 8777,
#  'CCCAG': 4865,
#  'GATGC': 7702,
#  'ATGCG': 4697,
#  'TGCGG': 3897,
#  'GCGGA': 3595,
#  'CGGAG': 3288,
#  'GTCCC': 3205,
#  'TCTGC': 8254,
#  'TGCTG': 12138,
#  'CATTC': 10767,
#  'TGGGC': 5170,
#  'GGGCA': 4679,
#  'TCCCA': 7819,
#  'CACGA': 5241,
#  'GAGAG': 7041,
#  'AGAGA': 13590,
#  'AGTTA': 10665,
#  'TGGAC': 7077,
#  'GGACA': 6361,
#  'GACAG': 6636,
#  'ACAGC': 8034,
#  'GCGTT': 5493,
#  'GTGTG': 5687,
#  'TGTGT': 9116,
#  'GTGTA': 7230,
#  'AACCG': 5220,
#  'ACCGG': 4123,
#  'CCGGC': 2437,
#  'CGGCC': 2506,
#  'TTGCC': 9611,
#  'GCCAG': 5234,
#  'TAACC': 7211,
#  'CCTAG': 3342,
#  'AGATC': 8830,
#  'GATCA': 9057,
#  'GTATA': 13149,
#  'TGTAT': 14820,
#  'TAGGC': 4053,
#  'AGGCT': 6322,
#  'GGCTG': 5292,
#  'CTGCA': 8745,
#  'GCAGA': 8788,
#  'CAGAA': 14810,
#  'GAATT': 17079,
#  'TTCTC': 14509,
#  'TCTCC': 8574,
#  'CTCCT': 7257,
#  'TAGTT': 12254,
#  'TGCCT': 7374,
#  'GCCTA': 3896,
#  'TCCCG': 2947,
#  'CCGTC': 3885,
#  'GTCTC': 6042,
#  'AACTG': 11009,
#  'TCCTG': 7258,
#  'CCTGC': 5308,
#  'GGTGC': 5834,
#  'GTGCG': 2655,
#  'GCGGT': 3820,
#  'CGGTG': 5503,
#  'ACAAG': 13098,
#  'TATTG': 17664,
#  'TGACC': 6729,
#  'GACCT': 5231,
#  'TTGGG': 8249,
#  'TGGGG': 4665,
#  'CCTCC': 5666,
#  'CCACA': 8225,
#  'ATCAG': 9851,
#  'CAGAG': 7736,
#  'AGAGG': 8624,
#  'GAGGC': 5097,
#  'GGCTA': 5097,
#  'CACAC': 5945,
#  'CACCT': 7684,
#  'CTGCC': 5952,
#  'GCCAT': 9043,
#  'TGCAT': 10835,
#  'TAGAG': 8510,
#  'ACATG': 8967,
#  'CATGT': 8847,
#  'ACCTT': 11292,
#  'GCTCG': 2704,
#  'CTCGC': 2722,
#  'TCGCG': 2175,
#  'GCGTG': 3206,
#  'GTGGC': 5526,
#  'GGCGT': 3643,
#  'AATGG': 14930,
#  'GCAAC': 8938,
#  'ACGCG': 2117,
#  'GACCC': 3965,
#  'GTGAG': 5024,
#  'TGAGT': 7679,
#  'TTGGA': 15047,
#  'TGGAG': 8457,
#  'GGAGA': 7863,
#  'TGAGC': 6209,
#  'GAGCG': 3159,
#  'AGCGA': 5365,
#  'GCGAC': 3187,
#  'TTGAT': 20543,
#  'TTACG': 6669,
#  'TACGC': 3988,
#  'ACGCC': 3916,
#  'CGCCC': 2308,
#  'TTGCG': 5624,
#  'TGCGT': 5160,
#  'TTACT': 14298,
#  'TTGAG': 11006,
#  'AGCGG': 4391,
#  'GCGGG': 2164,
#  'TAACG': 7608,
#  'GAATG': 10955,
#  'CACTC': 5184,
#  'ACTCG': 3416,
#  'CTCGG': 2290,
#  'CGGGC': 1949,
#  'GGGCC': 2991,
#  'TCATG': 9880,
#  'CATGA': 10039,
#  'ATGAC': 10835,
#  'ACTGC': 7490,
#  'CTGCG': 4018,
#  'TGCGC': 3471,
#  'GCGCC': 2907,
#  'CGCCA': 5266,
#  'GACGG': 3893,
#  'ACGGT': 6625,
#  'CGGTC': 3020,
#  'GGTCT': 6003,
#  'CTACG': 4485,
#  'GGCAG': 6013,
#  'GAGAC': 5778,
#  'CCTTA': 7766,
#  'ATGCT': 10227,
#  'GGGGA': 3700,
#  'ACGGC': 4045,
#  'ACCAC': 9963,
#  'CCGGA': 3463,
#  'CCGAT': 4796,
#  'GTTAA': 10949,
#  'GACAC': 5777,
#  'GAACG': 6339,
#  'GCCAC': 5806,
#  'AGGCC': 4537,
#  'TACTC': 7145,
#  'GCTGT': 7978,
#  'ACTCT': 8669,
#  'CGGTT': 5047,
#  'CTCAC': 5240,
#  'CATGG': 7842,
#  'GTCGC': 3310,
#  'TCGCT': 5301,
#  'CGCTC': 2971,
#  'TCTCG': 4915,
#  'CTCGA': 4960,
#  'CGATC': 3996,
#  'AGAGT': 8665,
#  'GATCC': 5772,
#  'CACTG': 7241,
#  'GGCGC': 2899,
#  'TGTGG': 8218,
#  'GGCCT': 4358,
#  'GCCTC': 4754,
#  'CCTCG': 3724,
#  'CTCGT': 4767,
#  'CGTCA': 7456,
#  'CAGCC': 5148,
#  'AGCCT': 5941,
#  'GCCTT': 8506,
#  'CACCG': 5649,
#  'ACCGC': 4028,
#  'CCGCT': 4555,
#  'TCGGT': 5313,
#  'GTTAC': 8394,
#  'GTCGA': 4843,
#  'TGCCG': 4927,
#  'TCGAA': 9457,
#  'ACAGG': 6536,
#  'CGAAG': 7272,
#  'AACGT': 8804,
#  'ACGTC': 5404,
#  'TCCTA': 6343,
#  'CGTTC': 6040,
#  'AGTCC': 4389,
#  'GGACG': 3590,
#  'GTTTG': 12295,
#  'GCCTG': 4482,
#  'GTTGA': 12415,
#  'ATGCC': 6954,
#  'CGTTG': 7762,
#  'GGCGG': 3138,
#  'CGGAT': 4730,
#  'ACGTG': 4748,
#  'GTAGG': 4574,
#  'CTAGG': 3396,
#  'CGTGC': 3188,
#  'CCATG': 7780,
#  'ACACT': 7836,
#  'CCGAG': 2428,
#  'GCGAA': 4942,
#  'GCATG': 6107,
#  'CTGTA': 8574,
#  'TCGGA': 4423,
#  'GGAGC': 4253,
#  'CCCGC': 2174,
#  'CCGCC': 3202,
#  'CGCCT': 3959,
#  'CCTGG': 4799,
#  'CGGAC': 2489,
#  'CCACG': 4378,
#  'CGCAC': 2792,
#  'AGGGC': 4322,
#  'GGCCC': 3170,
#  'GCACG': 3521,
#  'CGCTA': 5068,
#  'TAGCC': 4921,
#  'CATGC': 6045,
#  'CGAAC': 5413,
#  'TGCGA': 4448,
#  'CCCGG': 1772,
#  'CCGGG': 1756,
#  'CGCGA': 2135,
#  'GCGAT': 5069,
#  'ATAAC': 13573,
#  'AGCCG': 3490,
#  'GCCGA': 3229,
#  'GCCGC': 3633,
#  'CCGCA': 4135,
#  'CGCAT': 4751,
#  'CGACA': 5983,
#  'CCGAC': 2816,
#  'GGGCT': 3954,
#  'GTGCA': 6131,
#  'GTCCG': 2276,
#  'TCCGC': 3849,
#  'GCAGC': 8316,
#  'GCGCA': 3655,
#  'GACTC': 4455,
#  ...}

# %%
ordered_map_norm0
# Out:
# {'AAAAA': 0.3943428049472617,
#  'AAAAC': 0.40864695968619297,
#  'AAAAG': 0.4011097991163127,
#  'AAAAT': 0.40154503004713454,
#  'AAACA': 0.40549305192505913,
#  'AAACC': 0.40733402726879736,
#  'AAACG': 0.40267464579954904,
#  'AAACT': 0.4071981366950788,
#  'AAAGA': 0.4079008879938238,
#  'AAAGC': 0.4001021138747851,
#  'AAAGG': 0.40135526191035337,
#  'AAAGT': 0.4089565410023977,
#  'AAATA': 0.40558495008592804,
#  'AAATC': 0.3966713398831711,
#  'AAATG': 0.4017992262187994,
#  'AAATT': 0.404260893810465,
#  'AACAA': 0.4007315023909189,
#  'AACAC': 0.4110628275626929,
#  'AACAG': 0.4071237721475039,
#  'AACAT': 0.4046479511573788,
#  'AACCA': 0.4076773086174188,
#  'AACCC': 0.40901818838688647,
#  'AACCG': 0.402887120135365,
#  'AACCT': 0.39965129832869034,
#  'AACGA': 0.40282787161238737,
#  'AACGC': 0.4049609830194923,
#  'AACGG': 0.40651835776476725,
#  'AACGT': 0.4002639622489544,
#  'AACTA': 0.3941223074819228,
#  'AACTC': 0.4038700980951977,
#  'AACTG': 0.4055045642083875,
#  'AACTT': 0.40923005117716305,
#  'AAGAA': 0.4066608147401442,
#  'AAGAC': 0.40219355956262026,
#  'AAGAG': 0.4010523092105403,
#  'AAGAT': 0.40866460799096815,
#  'AAGCA': 0.403848041741027,
#  'AAGCC': 0.4005970373680574,
#  'AAGCG': 0.40762021763693534,
#  'AAGCT': 0.4110140171230058,
#  'AAGGA': 0.4049590410312161,
#  'AAGGC': 0.40326516837850174,
#  'AAGGG': 0.40346034590867363,
#  'AAGGT': 0.4155220158698429,
#  'AAGTA': 0.4025839573363166,
#  'AAGTC': 0.4110904580459447,
#  'AAGTG': 0.4137209311816417,
#  'AAGTT': 0.4043103399399408,
#  'AATAA': 0.40267853204366066,
#  'AATAC': 0.4020537264542762,
#  'AATAG': 0.40657541792441854,
#  'AATAT': 0.4060063536156928,
#  'AATCA': 0.40453622835582026,
#  'AATCC': 0.405317080858653,
#  'AATCG': 0.40444998424466055,
#  'AATCT': 0.4007967788635933,
#  'AATGA': 0.40613460524288436,
#  'AATGC': 0.3991980863595672,
#  'AATGG': 0.3988559653025672,
#  'AATGT': 0.40563581801882154,
#  'AATTA': 0.4059485422941167,
#  'AATTC': 0.40434080111098614,
#  'AATTG': 0.4033567349590102,
#  'AATTT': 0.40207669756528214,
#  'ACAAA': 0.40399889066161065,
#  'ACAAC': 0.4036588220235324,
#  'ACAAG': 0.39960732501783763,
#  'ACAAT': 0.4040622196695164,
#  'ACACA': 0.3930493001683211,
#  'ACACC': 0.39987857875884925,
#  'ACACG': 0.401856413810315,
#  'ACACT': 0.4079329637550948,
#  'ACAGA': 0.39872468712350023,
#  'ACAGC': 0.400382327042866,
#  'ACAGG': 0.4106941184495158,
#  'ACAGT': 0.41453318369764514,
#  'ACATA': 0.4074316452581495,
#  'ACATC': 0.40897133213091963,
#  'ACATG': 0.40849469612754,
#  'ACATT': 0.40437149719799104,
#  'ACCAA': 0.4066911500302391,
#  'ACCAC': 0.3993267367157127,
#  'ACCAG': 0.4029658112121869,
#  'ACCAT': 0.40360587854063545,
#  'ACCCA': 0.40730886316781645,
#  'ACCCC': 0.41727128311989226,
#  'ACCCG': 0.38991366666930016,
#  'ACCCT': 0.424350507928976,
#  'ACCGA': 0.40312727862703873,
#  'ACCGC': 0.40629295985739283,
#  'ACCGG': 0.4064601506289018,
#  'ACCGT': 0.40459321055986763,
#  'ACCTA': 0.3939053974992748,
#  'ACCTC': 0.39529064618359977,
#  'ACCTG': 0.39756775658891447,
#  'ACCTT': 0.41502518986878284,
#  'ACGAA': 0.40416624120695743,
#  'ACGAC': 0.4080691191949625,
#  'ACGAG': 0.42062533441594663,
#  'ACGAT': 0.41304133736977666,
#  'ACGCA': 0.40776188150240983,
#  'ACGCC': 0.39864633570537106,
#  'ACGCG': 0.4262369480195536,
#  'ACGCT': 0.4023062091411989,
#  'ACGGA': 0.3908425932555622,
#  'ACGGC': 0.4158027185238405,
#  'ACGGG': 0.41031642412316677,
#  'ACGGT': 0.4042327586456445,
#  'ACGTA': 0.40142484497862735,
#  'ACGTC': 0.39587128539271815,
#  'ACGTG': 0.404116592159271,
#  'ACGTT': 0.4104742206380584,
#  'ACTAA': 0.3974544409007091,
#  'ACTAC': 0.4017784047690167,
#  'ACTAG': 0.4065853811228756,
#  'ACTAT': 0.4045779641298259,
#  'ACTCA': 0.4057218137296928,
#  'ACTCC': 0.40730241299825853,
#  'ACTCG': 0.3985151935529761,
#  'ACTCT': 0.4065716108322757,
#  'ACTGA': 0.39757505076118016,
#  'ACTGC': 0.4074131352637349,
#  'ACTGG': 0.41134938331830007,
#  'ACTGT': 0.4083846380792701,
#  'ACTTA': 0.41128127831977684,
#  'ACTTC': 0.410770948465471,
#  'ACTTG': 0.404275499535491,
#  'ACTTT': 0.40011239683932787,
#  'AGAAA': 0.407699692677677,
#  'AGAAC': 0.4002846509137222,
#  'AGAAG': 0.4082385382167007,
#  'AGAAT': 0.4012323277860886,
#  'AGACA': 0.397099571976387,
#  'AGACC': 0.4028847949744251,
#  'AGACG': 0.401163409612808,
#  'AGACT': 0.4144237231439468,
#  'AGAGA': 0.40157947613851097,
#  'AGAGC': 0.3957376421354027,
#  'AGAGG': 0.3945059772445202,
#  'AGAGT': 0.39983007386711017,
#  'AGATA': 0.409473147886975,
#  'AGATC': 0.40968818567323967,
#  'AGATG': 0.41044438360621044,
#  'AGATT': 0.405400180821653,
#  'AGCAA': 0.3993664696780632,
#  'AGCAC': 0.4051001523072335,
#  'AGCAG': 0.39777172435369024,
#  'AGCAT': 0.40557271903767395,
#  'AGCCA': 0.3948484132754792,
#  'AGCCC': 0.38957925465275683,
#  'AGCCG': 0.40379858930381196,
#  'AGCCT': 0.3986004521888222,
#  'AGCGA': 0.40788855928540446,
#  'AGCGC': 0.40413579305397046,
#  'AGCGG': 0.4179463867112518,
#  'AGCGT': 0.4005896128404828,
#  'AGCTA': 0.3967779496213904,
#  'AGCTC': 0.41140262436362135,
#  'AGCTG': 0.40530795963019833,
#  'AGCTT': 0.4084923521207,
#  'AGGAA': 0.39796979505859614,
#  'AGGAC': 0.4034667505356285,
#  'AGGAG': 0.41782344514569203,
#  'AGGAT': 0.3926526000473699,
#  'AGGCA': 0.4053138149819578,
#  'AGGCC': 0.40763030503907677,
#  'AGGCG': 0.3982337794878445,
#  'AGGCT': 0.4069372227489802,
#  'AGGGA': 0.40549209218136156,
#  'AGGGC': 0.39701049969845426,
#  'AGGGG': 0.3969104331127184,
#  'AGGGT': 0.3852595898902845,
#  'AGGTA': 0.40447869453995267,
#  'AGGTC': 0.3943123746545714,
#  'AGGTG': 0.4095308408041443,
#  'AGGTT': 0.4137164768036149,
#  'AGTAA': 0.404575440676282,
#  'AGTAC': 0.40785933201348273,
#  'AGTAG': 0.39884614029797544,
#  'AGTAT': 0.40286169145794354,
#  'AGTCA': 0.407459575966201,
#  'AGTCC': 0.39534653710604717,
#  'AGTCG': 0.4018962920438749,
#  'AGTCT': 0.40296326553644957,
#  'AGTGA': 0.40708266188180986,
#  'AGTGC': 0.402956490227484,
#  'AGTGG': 0.4083732846670292,
#  'AGTGT': 0.4027306097787603,
#  'AGTTA': 0.4043918495515779,
#  'AGTTC': 0.40719051846140036,
#  'AGTTG': 0.40766190207266795,
#  'AGTTT': 0.4057162864334508,
#  'ATAAA': 0.40473143072795054,
#  'ATAAC': 0.4095966247064103,
#  'ATAAG': 0.4020932476054016,
#  'ATAAT': 0.4004911290148211,
#  'ATACA': 0.4085815462060431,
#  'ATACC': 0.4068662197404228,
#  'ATACG': 0.40041649827493786,
#  'ATACT': 0.4048757940377658,
#  'ATAGA': 0.40664303371000665,
#  'ATAGC': 0.4072695555966831,
#  'ATAGG': 0.41597294188058476,
#  'ATAGT': 0.4049328377931705,
#  'ATATA': 0.40455578963087224,
#  'ATATC': 0.4010758714030784,
#  'ATATG': 0.3967113191128462,
#  'ATATT': 0.40188041429588117,
#  'ATCAA': 0.4054556502015101,
#  'ATCAC': 0.39349585223737593,
#  'ATCAG': 0.41471682901536683,
#  'ATCAT': 0.4055764223285391,
#  'ATCCA': 0.4047367604604734,
#  'ATCCC': 0.41243181945433094,
#  'ATCCG': 0.41019616352636407,
#  'ATCCT': 0.4063739505278047,
#  'ATCGA': 0.4019055493011926,
#  'ATCGC': 0.4086300483954091,
#  'ATCGG': 0.4200179488146071,
#  'ATCGT': 0.4035029364015809,
#  'ATCTA': 0.4031245529270463,
#  'ATCTC': 0.40041128066337883,
#  'ATCTG': 0.4044216315396643,
#  'ATCTT': 0.39808635261658837,
#  'ATGAA': 0.4040157353713613,
#  'ATGAC': 0.4092469070714088,
#  'ATGAG': 0.4016848652389988,
#  'ATGAT': 0.40621439026370787,
#  'ATGCA': 0.40755038633839197,
#  'ATGCC': 0.4089099008517762,
#  'ATGCG': 0.4004421040211078,
#  'ATGCT': 0.40441350013020094,
#  'ATGGA': 0.4020333145855955,
#  'ATGGC': 0.40511928262027025,
#  'ATGGG': 0.4046793268922783,
#  'ATGGT': 0.39497970825225875,
#  'ATGTA': 0.40486228034106375,
#  'ATGTC': 0.39837401476728745,
#  'ATGTG': 0.40281706392047123,
#  'ATGTT': 0.40538021073551045,
#  'ATTAA': 0.40389586885370615,
#  'ATTAC': 0.4131000821064404,
#  'ATTAG': 0.3993994137553177,
#  'ATTAT': 0.4084533246687169,
#  'ATTCA': 0.3972263157039277,
#  'ATTCC': 0.3995996770984658,
#  'ATTCG': 0.392716394829758,
#  'ATTCT': 0.40576023033883324,
#  'ATTGA': 0.39969280401322915,
#  'ATTGC': 0.39843436935709853,
#  'ATTGG': 0.4015282629758829,
#  'ATTGT': 0.40282119866902344,
#  'ATTTA': 0.4030581918053444,
#  'ATTTC': 0.40267477932518275,
#  'ATTTG': 0.4030264709333019,
#  'ATTTT': 0.4076397045970388,
#  'CAAAA': 0.4053240950712231,
#  'CAAAC': 0.40711419778029756,
#  'CAAAG': 0.40053459789927154,
#  'CAAAT': 0.39803012832086493,
#  'CAACA': 0.40661274219366267,
#  'CAACC': 0.39144695976576566,
#  'CAACG': 0.39537845948506145,
#  'CAACT': 0.40015351459710974,
#  'CAAGA': 0.4026432581615065,
#  'CAAGC': 0.4015318569553183,
#  'CAAGG': 0.4036264351536201,
#  'CAAGT': 0.39664170178174424,
#  'CAATA': 0.39854862004061165,
#  'CAATC': 0.41004727712154504,
#  'CAATG': 0.40737842378402955,
#  'CAATT': 0.41234583390105667,
#  'CACAA': 0.4102375266267281,
#  'CACAC': 0.38394169409723483,
#  'CACAG': 0.4004030633897976,
#  'CACAT': 0.4019398009711005,
#  'CACCA': 0.38818188252303226,
#  'CACCC': 0.415809412089444,
#  'CACCG': 0.4164421948510189,
#  'CACCT': 0.39936659161549704,
#  'CACGA': 0.40320655216801204,
#  'CACGC': 0.40316104451509793,
#  'CACGG': 0.4061565189844474,
#  'CACGT': 0.42050725175818615,
#  'CACTA': 0.41218022988394276,
#  'CACTC': 0.41349468118618776,
#  'CACTG': 0.3989812284932003,
#  'CACTT': 0.40919489818763094,
#  'CAGAA': 0.4084158605282884,
#  'CAGAC': 0.3897573576320589,
#  'CAGAG': 0.40153301713396183,
#  'CAGAT': 0.4108312509860915,
#  'CAGCA': 0.40244021444177935,
#  'CAGCC': 0.3875106085943185,
#  'CAGCG': 0.4086646872913837,
#  'CAGCT': 0.41322477338903074,
#  'CAGGA': 0.3991128081314057,
#  'CAGGC': 0.3978068925658217,
#  'CAGGG': 0.400819175204963,
#  'CAGGT': 0.4126913663808534,
#  'CAGTA': 0.4087068166526256,
#  'CAGTC': 0.39517852202856835,
#  'CAGTG': 0.407636771019246,
#  'CAGTT': 0.4001036479197064,
#  'CATAA': 0.4022228916282188,
#  'CATAC': 0.40397553157549193,
#  'CATAG': 0.3962591759541938,
#  'CATAT': 0.40641528207832783,
#  'CATCA': 0.4070136907908738,
#  'CATCC': 0.4030620225362897,
#  'CATCG': 0.4090114444970542,
#  'CATCT': 0.4070689459155328,
#  'CATGA': 0.4088511998670565,
#  'CATGC': 0.40917734759522933,
#  'CATGG': 0.40831690002956916,
#  'CATGT': 0.4145086958773207,
#  'CATTA': 0.4102872195743816,
#  'CATTC': 0.4018968459869148,
#  'CATTG': 0.3927826681983679,
#  'CATTT': 0.40978475212710774,
#  'CCAAA': 0.403402415480731,
#  'CCAAC': 0.4064015466308551,
#  'CCAAG': 0.40152011728712333,
#  'CCAAT': 0.40265026169067525,
#  'CCACA': 0.4011776835410818,
#  'CCACC': 0.4037048739456063,
#  'CCACG': 0.39947965889419795,
#  'CCACT': 0.4062170293419435,
#  'CCAGA': 0.40601307105414575,
#  'CCAGC': 0.4000816587538021,
#  'CCAGG': 0.38714309770136146,
#  'CCAGT': 0.40448118799360944,
#  'CCATA': 0.3972713199388997,
#  'CCATC': 0.41545568321789356,
#  'CCATG': 0.4164043525073226,
#  'CCATT': 0.40360591360723985,
#  'CCCAA': 0.40227425199550343,
#  'CCCAC': 0.4072837121472181,
#  'CCCAG': 0.4085690105001192,
#  'CCCAT': 0.4080906019427342,
#  'CCCCA': 0.39047227898922293,
#  'CCCCC': 0.3975578559637723,
#  'CCCCG': 0.39999136431891896,
#  'CCCCT': 0.40803813333373,
#  'CCCGA': 0.4152666850347891,
#  'CCCGC': 0.41104556619694493,
#  'CCCGG': 0.4080880536503354,
#  'CCCGT': 0.40957200193754595,
#  'CCCTA': 0.4105989036199282,
#  'CCCTC': 0.4036100111333648,
#  'CCCTG': 0.4151074576821035,
#  'CCCTT': 0.4032419568495666,
#  'CCGAA': 0.41794280704501,
#  'CCGAC': 0.3913353666716672,
#  'CCGAG': 0.41113251378736765,
#  'CCGAT': 0.4147221271975749,
#  'CCGCA': 0.41132805222896496,
#  'CCGCC': 0.3839665849942175,
#  'CCGCG': 0.4087059984336805,
#  'CCGCT': 0.42364310090125357,
#  'CCGGA': 0.4020562879472547,
#  'CCGGC': 0.3797350597647592,
#  'CCGGG': 0.39617065122663714,
#  'CCGGT': 0.3923812583557574,
#  'CCGTA': 0.4016783521118265,
#  'CCGTC': 0.40947677116616843,
#  'CCGTG': 0.38913518883248593,
#  'CCGTT': 0.41610166748903477,
#  'CCTAA': 0.39429995842843213,
#  'CCTAC': 0.3974288324693875,
#  'CCTAG': 0.4045061536897144,
#  'CCTAT': 0.4020571666207149,
#  'CCTCA': 0.40247255755896383,
#  'CCTCC': 0.4023757841029641,
#  'CCTCG': 0.4101011637073987,
#  'CCTCT': 0.40246318283541777,
#  'CCTGA': 0.40165994648608344,
#  'CCTGC': 0.4091804438533297,
#  'CCTGG': 0.40811926818109817,
#  'CCTGT': 0.39059972867889337,
#  'CCTTA': 0.39869233210847627,
#  'CCTTC': 0.4147281517049505,
#  'CCTTG': 0.4141168602596593,
#  'CCTTT': 0.408411865808347,
#  'CGAAA': 0.41022250829609186,
#  'CGAAC': 0.4054141365192868,
#  'CGAAG': 0.4108041049498625,
#  'CGAAT': 0.4104845483130514,
#  'CGACA': 0.39926546613694636,
#  'CGACC': 0.4034385528654025,
#  'CGACG': 0.394903329549337,
#  'CGACT': 0.4085864081960992,
#  'CGAGA': 0.3982135951352128,
#  'CGAGC': 0.4086541291676199,
#  'CGAGG': 0.398393791611602,
#  'CGAGT': 0.4068075689092618,
#  'CGATA': 0.40233965677546607,
#  'CGATC': 0.40712300260634915,
#  'CGATG': 0.4084922991085972,
#  'CGATT': 0.4011698080394588,
#  'CGCAA': 0.40376589422207043,
#  'CGCAC': 0.399751495150022,
#  'CGCAG': 0.3911005012321997,
#  'CGCAT': 0.41358805047728414,
#  'CGCCA': 0.4005750213549954,
#  'CGCCC': 0.38081568814770933,
#  'CGCCG': 0.40727211152102033,
#  'CGCCT': 0.4171642652757377,
#  'CGCGA': 0.3969912531839571,
#  'CGCGC': 0.41925688537996403,
#  'CGCGG': 0.40555980822616716,
#  'CGCGT': 0.4346251343191666,
#  'CGCTA': 0.3968749948611768,
#  'CGCTC': 0.4075006146870688,
#  'CGCTG': 0.4118964520018745,
#  'CGCTT': 0.40666513169981877,
#  'CGGAA': 0.4106597465852499,
#  'CGGAC': 0.4233783279949516,
#  'CGGAG': 0.4193002058929448,
#  'CGGAT': 0.39218023283750614,
#  'CGGCA': 0.4124633371381594,
#  'CGGCC': 0.38777161857599596,
#  'CGGCG': 0.3839938833500288,
#  'CGGCT': 0.3993590883612528,
#  'CGGGA': 0.41478560259880226,
#  'CGGGC': 0.40834642018832684,
#  'CGGGG': 0.44085368603552005,
#  'CGGGT': 0.40304298015324475,
#  'CGGTA': 0.4047216988326712,
#  'CGGTC': 0.39919084776952507,
#  'CGGTG': 0.4102516472296986,
#  'CGGTT': 0.400895889462878,
#  'CGTAA': 0.41203783639339886,
#  'CGTAC': 0.40235637437091337,
#  'CGTAG': 0.41415892047265235,
#  'CGTAT': 0.4020504778430519,
#  'CGTCA': 0.3968981315104078,
#  'CGTCC': 0.3879666598818919,
#  'CGTCG': 0.4141623678599824,
#  'CGTCT': 0.41999304432017853,
#  'CGTGA': 0.4033742022609466,
#  'CGTGC': 0.3936326761051542,
#  'CGTGG': 0.38857025410364454,
#  'CGTGT': 0.4183934174906227,
#  'CGTTA': 0.4070280314638608,
#  'CGTTC': 0.4054123852527513,
#  'CGTTG': 0.4004180449844563,
#  'CGTTT': 0.41325198873843677,
#  'CTAAA': 0.4014714951402149,
#  'CTAAC': 0.40924033287125977,
#  'CTAAG': 0.40645849713094273,
#  'CTAAT': 0.40000554489353407,
#  'CTACA': 0.3913848849916103,
#  'CTACC': 0.4123534110492033,
#  'CTACG': 0.40197945353882175,
#  'CTACT': 0.3977401901794143,
#  'CTAGA': 0.40533534447674674,
#  'CTAGC': 0.39125068507025407,
#  'CTAGG': 0.3901697990333066,
#  'CTAGT': 0.4005340591853776,
#  'CTATA': 0.3970983768307589,
#  'CTATC': 0.40896851769473697,
#  'CTATG': 0.3991169401733667,
#  'CTATT': 0.4025606559749818,
#  'CTCAA': 0.40271197260425856,
#  'CTCAC': 0.40920218571299377,
#  'CTCAG': 0.3925670371107743,
#  'CTCAT': 0.4098324576298697,
#  'CTCCA': 0.4037866817990409,
#  'CTCCC': 0.40699192630421616,
#  'CTCCG': 0.3948914281720545,
#  'CTCCT': 0.40577056689089713,
#  'CTCGA': 0.39468172586413325,
#  'CTCGC': 0.41603476068978934,
#  'CTCGG': 0.4128477241059244,
#  'CTCGT': 0.4180950174742798,
#  'CTCTA': 0.4093826468017413,
#  'CTCTC': 0.4045741965598948,
#  'CTCTG': 0.40791996672664804,
#  'CTCTT': 0.39817662867892895,
#  'CTGAA': 0.4036561628342052,
#  'CTGAC': 0.39112285794744117,
#  'CTGAG': 0.4124672682571179,
#  'CTGAT': 0.4052905746561662,
#  'CTGCA': 0.40227253924931017,
#  'CTGCC': 0.3981556125656904,
#  'CTGCG': 0.40034741995408,
#  'CTGCT': 0.40508946053145717,
#  'CTGGA': 0.41142903947109727,
#  'CTGGC': 0.4096469286136903,
#  'CTGGG': 0.3951086457586671,
#  'CTGGT': 0.41449026544743117,
#  'CTGTA': 0.39972928381114925,
#  'CTGTC': 0.40716391472928976,
#  'CTGTG': 0.4102135016600183,
#  'CTGTT': 0.4128093185630165,
#  'CTTAA': 0.3972079482243292,
#  'CTTAC': 0.40418020709837965,
#  'CTTAG': 0.4023212724321472,
#  'CTTAT': 0.40642336150697533,
#  'CTTCA': 0.40906030064192644,
#  'CTTCC': 0.40393240138543884,
#  'CTTCG': 0.39369562908046773,
#  'CTTCT': 0.4088870910896561,
#  'CTTGA': 0.4085750293752249,
#  'CTTGC': 0.4061994743271994,
#  'CTTGG': 0.39563814842608497,
#  'CTTGT': 0.4016324910088623,
#  'CTTTA': 0.4002676076357618,
#  'CTTTC': 0.40542862977814154,
#  'CTTTG': 0.40195488604841173,
#  'CTTTT': 0.402074865345739,
#  'GAAAA': 0.4030394037977314,
#  'GAAAC': 0.4043107467151474,
#  'GAAAG': 0.4104219796620631,
#  'GAAAT': 0.410753586561421,
#  'GAACA': 0.40704261859927404,
#  'GAACC': 0.41051786487217307,
#  'GAACG': 0.4118663462291467,
#  'GAACT': 0.40198901785760566,
#  'GAAGA': 0.4087982247445622,
#  'GAAGC': 0.417104938127486,
#  'GAAGG': 0.4125027097456384,
#  'GAAGT': 0.40799174168454283,
#  'GAATA': 0.4035317840612355,
#  'GAATC': 0.3980313533495677,
#  'GAATG': 0.4056376293899549,
#  'GAATT': 0.40398682955020726,
#  'GACAA': 0.3972117560964023,
#  'GACAC': 0.4020998246241432,
#  'GACAG': 0.3976982105506263,
#  'GACAT': 0.40054236455598835,
#  'GACCA': 0.40370817692478994,
#  'GACCC': 0.4096529242850514,
#  'GACCG': 0.41845700707679206,
#  'GACCT': 0.4063090625441755,
#  'GACGA': 0.40594519096719855,
#  'GACGC': 0.40485754048194883,
#  'GACGG': 0.40922859236912495,
#  'GACGT': 0.4007580691947575,
#  'GACTA': 0.4111244757659082,
#  'GACTC': 0.4078582916092697,
#  'GACTG': 0.3933887851326836,
#  'GACTT': 0.4083219657526873,
#  'GAGAA': 0.4033063558360361,
#  'GAGAC': 0.4052607267928369,
#  'GAGAG': 0.39750704962878003,
#  'GAGAT': 0.40700564287257157,
#  'GAGCA': 0.3954047135734238,
#  'GAGCC': 0.40387887548366713,
#  'GAGCG': 0.40430957059925515,
#  'GAGCT': 0.4080834232614682,
#  'GAGGA': 0.38444532495361283,
#  'GAGGC': 0.39122171051352694,
#  'GAGGG': 0.39655893101224404,
#  'GAGGT': 0.40349343891072453,
#  'GAGTA': 0.4075259067036255,
#  'GAGTC': 0.39873981468536757,
#  'GAGTG': 0.403298120338013,
#  'GAGTT': 0.4001086076040724,
#  'GATAA': 0.4052845748965754,
#  'GATAC': 0.4136166239704258,
#  'GATAG': 0.41283388435359125,
#  'GATAT': 0.40568117606196663,
#  'GATCA': 0.41040956681227947,
#  'GATCC': 0.4106128142598946,
#  'GATCG': 0.40542420377715066,
#  'GATCT': 0.40708062864563077,
#  'GATGA': 0.4075204804725977,
#  'GATGC': 0.4084076544539158,
#  'GATGG': 0.40143084758963665,
#  'GATGT': 0.4002942498956986,
#  'GATTA': 0.4054945456329458,
#  'GATTC': 0.39575683730870814,
#  'GATTG': 0.3905508406649521,
#  'GATTT': 0.4046230629666302,
#  'GCAAA': 0.40829183057968743,
#  'GCAAC': 0.3913078231048574,
#  'GCAAG': 0.396703897050475,
#  'GCAAT': 0.4136642549248453,
#  'GCACA': 0.40509133802373676,
#  'GCACC': 0.40185489962966087,
#  'GCACG': 0.43240902216923527,
#  'GCACT': 0.4032744613463721,
#  'GCAGA': 0.41273890719954465,
#  'GCAGC': 0.40392002804877686,
#  'GCAGG': 0.41070144245979073,
#  'GCAGT': 0.39538820115718304,
#  'GCATA': 0.4052763898623757,
#  'GCATC': 0.3912083888710235,
#  'GCATG': 0.40173317970305644,
#  'GCATT': 0.4018987351360647,
#  'GCCAA': 0.4033293774540165,
#  'GCCAC': 0.40550616927072697,
#  'GCCAG': 0.40368108528832763,
#  'GCCAT': 0.4034139698098138,
#  'GCCCA': 0.39636402112606745,
#  'GCCCC': 0.3822838382868982,
#  'GCCCG': 0.38641340204884833,
#  'GCCCT': 0.40668083891547285,
#  'GCCGA': 0.39274290669355855,
#  'GCCGC': 0.4092938415131939,
#  'GCCGG': 0.38598513026261205,
#  'GCCGT': 0.40310706574524613,
#  'GCCTA': 0.39046327126672725,
#  'GCCTC': 0.39199460359822363,
#  'GCCTG': 0.401146936212415,
#  'GCCTT': 0.4062855131033584,
#  'GCGAA': 0.41172999373886354,
#  'GCGAC': 0.40646249797056655,
#  'GCGAG': 0.4047724568667564,
#  'GCGAT': 0.40547032087803275,
#  'GCGCA': 0.39860449584309027,
#  'GCGCC': 0.42819327006505953,
#  'GCGCG': 0.40203790409955353,
#  'GCGCT': 0.39191949588300246,
#  'GCGGA': 0.4228368397336091,
#  'GCGGC': 0.39633661473864895,
#  'GCGGG': 0.4183817115266452,
#  'GCGGT': 0.4146382269040277,
#  'GCGTA': 0.40516510777945935,
#  'GCGTC': 0.405734333438328,
#  'GCGTG': 0.4200648643419435,
#  'GCGTT': 0.4000897587595208,
#  'GCTAA': 0.3925775006758807,
#  'GCTAC': 0.4051463129941095,
#  'GCTAG': 0.40238080586222574,
#  'GCTAT': 0.4086816686133286,
#  'GCTCA': 0.39801977019053014,
#  'GCTCC': 0.4104596126024732,
#  'GCTCG': 0.4271764946173893,
#  'GCTCT': 0.39743808885978865,
#  'GCTGA': 0.3985750394731752,
#  'GCTGC': 0.4015238506297351,
#  'GCTGG': 0.4042152957106359,
#  'GCTGT': 0.4119251374462215,
#  'GCTTA': 0.40186417331351526,
#  'GCTTC': 0.39632578629947424,
#  'GCTTG': 0.40099769218443476,
#  'GCTTT': 0.4056146000337378,
#  'GGAAA': 0.406308830495982,
#  'GGAAC': 0.3989462900404623,
#  'GGAAG': 0.4056818341242616,
#  'GGAAT': 0.3994566017283123,
#  'GGACA': 0.4043400336603865,
#  'GGACC': 0.41284291884967805,
#  'GGACG': 0.3894479185022749,
#  'GGACT': 0.3964584372378737,
#  'GGAGA': 0.4089082368308426,
#  'GGAGC': 0.4088130161691017,
#  'GGAGG': 0.398460115029147,
#  'GGAGT': 0.40081230949647295,
#  'GGATA': 0.4050971169801252,
#  'GGATC': 0.3989024449527936,
#  'GGATG': 0.4089804136789467,
#  'GGATT': 0.39888464656589345,
#  'GGCAA': 0.4074989549814678,
#  'GGCAC': 0.42009525240989826,
#  'GGCAG': 0.4168923889138291,
#  'GGCAT': 0.3968207705064861,
#  'GGCCA': 0.401262341465536,
#  'GGCCC': 0.41469919716138764,
#  'GGCCG': 0.39292421579602077,
#  'GGCCT': 0.39732146839712823,
#  'GGCGA': 0.3992789600777499,
#  'GGCGC': 0.3889471242009965,
#  'GGCGG': 0.40375161792363135,
#  'GGCGT': 0.40855983444863075,
#  'GGCTA': 0.413854960038891,
#  'GGCTC': 0.40409559715447824,
#  'GGCTG': 0.3980384015313324,
#  'GGCTT': 0.4118564163471271,
#  'GGGAA': 0.4089812733496601,
#  'GGGAC': 0.39673140446596356,
#  'GGGAG': 0.3899300147637721,
#  'GGGAT': 0.4170539274461846,
#  'GGGCA': 0.3945339966083327,
#  'GGGCC': 0.408400343416774,
#  'GGGCG': 0.4230955713222449,
#  'GGGCT': 0.4121821923583659,
#  'GGGGA': 0.41440146323339444,
#  'GGGGC': 0.40615216068202464,
#  'GGGGG': 0.4075531153462588,
#  'GGGGT': 0.4005588010829494,
#  'GGGTA': 0.3920722505309249,
#  'GGGTC': 0.407106048079146,
#  'GGGTG': 0.4025913672213474,
#  'GGGTT': 0.3990885548127473,
#  'GGTAA': 0.4009353638567304,
#  'GGTAC': 0.4064529140717849,
#  'GGTAG': 0.40471629406601584,
#  'GGTAT': 0.4020197860142139,
#  'GGTCA': 0.40341473234747754,
#  'GGTCC': 0.39924816050208983,
#  'GGTCG': 0.4012982110506268,
#  'GGTCT': 0.39469920558455285,
#  'GGTGA': 0.4019847373336576,
#  'GGTGC': 0.39344740851259263,
#  'GGTGG': 0.41836588665074725,
#  'GGTGT': 0.4239391592850301,
#  'GGTTA': 0.40863591977125624,
#  'GGTTC': 0.3949261752188855,
#  'GGTTG': 0.4087533198819523,
#  'GGTTT': 0.412981819102619,
#  'GTAAA': 0.4037466539061368,
#  'GTAAC': 0.3915525129566821,
#  'GTAAG': 0.4033877368502277,
#  'GTAAT': 0.4022163579939253,
#  'GTACA': 0.40493833464369855,
#  'GTACC': 0.4061929144135548,
#  'GTACG': 0.40260886793842526,
#  'GTACT': 0.4068917297001634,
#  'GTAGA': 0.40597398390903927,
#  'GTAGC': 0.4058990392609314,
#  'GTAGG': 0.40913229530627654,
#  'GTAGT': 0.40428081922232545,
#  'GTATA': 0.4049485691470595,
#  'GTATC': 0.4047624090194703,
#  'GTATG': 0.40959851702888855,
#  'GTATT': 0.40265334033776007,
#  'GTCAA': 0.40481871316019796,
#  'GTCAC': 0.4025214747312559,
#  'GTCAG': 0.40987388021851956,
#  'GTCAT': 0.40065613304743336,
#  'GTCCA': 0.4121807640815919,
#  'GTCCC': 0.39350853230574373,
#  'GTCCG': 0.3813692710913261,
#  'GTCCT': 0.3970542222503508,
#  'GTCGA': 0.4010389753103064,
#  'GTCGC': 0.4087674702785983,
#  'GTCGG': 0.41195528840647544,
#  'GTCGT': 0.4022047111252484,
#  'GTCTA': 0.40412837671677826,
#  'GTCTC': 0.4147393975839568,
#  'GTCTG': 0.40216165210295574,
#  'GTCTT': 0.398139218361215,
#  'GTGAA': 0.40848159473001283,
#  'GTGAC': 0.40150766908506863,
#  'GTGAG': 0.38535845378623607,
#  'GTGAT': 0.40767878164105165,
#  'GTGCA': 0.4174739305756153,
#  'GTGCC': 0.39224875970379064,
#  'GTGCG': 0.41004282457267843,
#  'GTGCT': 0.3925528639824137,
#  'GTGGA': 0.4023924760353754,
#  'GTGGC': 0.4120176151840654,
#  'GTGGG': 0.4119989783166263,
#  'GTGGT': 0.4048744307881627,
#  'GTGTA': 0.4122278930533535,
#  'GTGTC': 0.41983249700700204,
#  'GTGTG': 0.40736696313309906,
#  'GTGTT': 0.4088722693494772,
#  'GTTAA': 0.4039315456243686,
#  'GTTAC': 0.4018090498159511,
#  'GTTAG': 0.4166456355794424,
#  'GTTAT': 0.40418017469634643,
#  'GTTCA': 0.4050711765667386,
#  'GTTCC': 0.40166397679064425,
#  'GTTCG': 0.39471411832500536,
#  'GTTCT': 0.3989842765467105,
#  'GTTGA': 0.39905875418796277,
#  'GTTGC': 0.4009276426325427,
#  'GTTGG': 0.40570955358762545,
#  'GTTGT': 0.4026385788395407,
#  'GTTTA': 0.40490450639275066,
#  'GTTTC': 0.4105015043105023,
#  'GTTTG': 0.4031732814984568,
#  'GTTTT': 0.40585883247611615,
#  'TAAAA': 0.4056426871400353,
#  'TAAAC': 0.4070138668734279,
#  'TAAAG': 0.40368396663903516,
#  'TAAAT': 0.39924799395332544,
#  'TAACA': 0.4068493218681452,
#  'TAACC': 0.4072478339563979,
#  'TAACG': 0.39505231714457784,
#  'TAACT': 0.4006563507121515,
#  'TAAGA': 0.3989730649701106,
#  'TAAGC': 0.40530673807478,
#  'TAAGG': 0.4061286741915164,
#  'TAAGT': 0.4008329411981633,
#  'TAATA': 0.4047250438374694,
#  'TAATC': 0.4025429276906518,
#  'TAATG': 0.4015760789739285,
#  'TAATT': 0.39454497883703,
#  'TACAA': 0.40399822584878287,
#  'TACAC': 0.3952223527121643,
#  'TACAG': 0.40488813774449667,
#  'TACAT': 0.4192776321589546,
#  'TACCA': 0.4102919378771731,
#  'TACCC': 0.40212710424436693,
#  'TACCG': 0.4005597463870634,
#  'TACCT': 0.4026842332433129,
#  'TACGA': 0.4113658619431663,
#  'TACGC': 0.40545117846710366,
#  'TACGG': 0.40636097737511934,
#  'TACGT': 0.39911682743892263,
#  'TACTA': 0.39315770600097194,
#  'TACTC': 0.39855665480199687,
#  'TACTG': 0.4056503599269939,
#  'TACTT': 0.40308025143194026,
#  'TAGAA': 0.4046639410501997,
#  'TAGAC': 0.4092895506423668,
#  'TAGAG': 0.39571576450325774,
#  'TAGAT': 0.4058259699018201,
#  'TAGCA': 0.4039016995221502,
#  'TAGCC': 0.4038509855267384,
#  'TAGCG': 0.40683807277376366,
#  'TAGCT': 0.40601388271014616,
#  'TAGGA': 0.41230427673746245,
#  'TAGGC': 0.410262509530989,
#  'TAGGG': 0.3978333961141363,
#  'TAGGT': 0.4060447911435331,
#  'TAGTA': 0.3947607769442951,
#  'TAGTC': 0.41190269732384505,
#  'TAGTG': 0.40699282175845064,
#  'TAGTT': 0.40486772489970957,
#  'TATAA': 0.41100693954672307,
#  'TATAC': 0.39869314371820036,
#  'TATAG': 0.4046087096031886,
#  'TATAT': 0.3990485354900636,
#  'TATCA': 0.3925057524861254,
#  'TATCC': 0.417802085469798,
#  'TATCG': 0.408955786989472,
#  'TATCT': 0.39824727100826995,
#  'TATGA': 0.3990647227958606,
#  'TATGC': 0.4107524920599502,
#  'TATGG': 0.4060188046731078,
#  'TATGT': 0.4035735235869837,
#  'TATTA': 0.40800948284972616,
#  'TATTC': 0.3997240483787156,
#  'TATTG': 0.39917505741585674,
#  'TATTT': 0.4059067993650406,
#  'TCAAA': 0.3996978831591424,
#  'TCAAC': 0.409380527768079,
#  'TCAAG': 0.39937237833708,
#  'TCAAT': 0.40453195654970087,
#  'TCACA': 0.4041726473091903,
#  'TCACC': 0.4066620389025387,
#  'TCACG': 0.4041718324962688,
#  'TCACT': 0.4004889953257264,
#  'TCAGA': 0.4001029275970981,
#  'TCAGC': 0.41333009090319517,
#  'TCAGG': 0.4063843787724312,
#  'TCAGT': 0.40598163323495984,
#  'TCATA': 0.41067353762582615,
#  'TCATC': 0.4048929712425434,
#  'TCATG': 0.3987639655612392,
#  'TCATT': 0.405256765457423,
#  'TCCAA': 0.4008702445385214,
#  'TCCAC': 0.39951487729884055,
#  'TCCAG': 0.4047178900816611,
#  'TCCAT': 0.40555689686352403,
#  'TCCCA': 0.4112346131017553,
#  'TCCCC': 0.4040152852803562,
#  'TCCCG': 0.416002890933092,
#  'TCCCT': 0.4050028629951701,
#  'TCCGA': 0.41629278289029015,
#  'TCCGC': 0.4089497761742509,
#  'TCCGG': 0.3787498396553898,
#  'TCCGT': 0.4119742970920481,
#  'TCCTA': 0.39582826711030006,
#  'TCCTC': 0.4101145943263073,
#  'TCCTG': 0.4041263198597286,
#  'TCCTT': 0.40518089570105764,
#  'TCGAA': 0.3985908786370303,
#  'TCGAC': 0.4011061576368146,
#  'TCGAG': 0.4097148571807056,
#  'TCGAT': 0.402875912974327,
#  'TCGCA': 0.40342494487210706,
#  'TCGCC': 0.407315545628756,
#  'TCGCG': 0.4106396700022421,
#  'TCGCT': 0.4049759107662408,
#  'TCGGA': 0.4214985437778646,
#  'TCGGC': 0.40896735487068603,
#  'TCGGG': 0.4072910880984383,
#  'TCGGT': 0.41234034544390763,
#  'TCGTA': 0.40110690270434746,
#  'TCGTC': 0.406435846306658,
#  'GGATA': 7050,
#  'GATAG': 6596,
#  'ATAGT': 10014,
#  'TAGTG': 6850,
#  'AGTGT': 6299,
#  'GTGTC': 4865,
#  'TGTCT': 8249,
#  'GTCTA': 5010,
#  'TCTAT': 11036,
#  'CTATA': 8773,
#  'TATAT': 28452,
#  'TATGT': 11013,
#  'ATGTG': 7248,
#  'TGTGA': 6901,
#  'GTGAA': 8896,
#  'TGAAC': 9089,
#  'GAACC': 6179,
#  'AACCA': 10811,
#  'ACCAG': 7666,
#  'CCAGA': 7079,
#  'CAGAC': 4676,
#  'AGACC': 4985,
#  'GACCA': 6344,
#  'ACCAA': 13058,
#  'CCAAG': 8974,
#  'CAAGG': 8086,
#  'AAGGG': 6484,
#  'AGGGA': 5211,
#  'GGGAT': 4287,
#  'GATAC': 6786,
#  'ATACA': 12366,
#  'TACAC': 6021,
#  'ACACG': 3498,
#  'CACGG': 2759,
#  'ACGGG': 2475,
#  'CGGGA': 2314,
#  'GGATT': 7696,
#  'GATTT': 14431,
#  'ATTTT': 35042,
#  'TTTTA': 26602,
#  'TTTAG': 10906,
#  'TTAGC': 6670,
#  'TAGCG': 4151,
#  'AGCGC': 2968,
#  'GCGCT': 2977,
#  'CGCTT': 4681,
#  'GCTTT': 10613,
#  'CTTTG': 12390,
#  'TTTGT': 17164,
#  'TTGTG': 8792,
#  'TGTGC': 5065,
#  'GTGCT': 6084,
#  'TGCTA': 8001,
#  'GCTAC': 4955,
#  'CTACA': 6991,
#  'TACAA': 13032,
#  'ACAAT': 14078,
#  'CAATA': 14238,
#  'AATAG': 12046,
#  'AGTGG': 6398,
#  'GTGGA': 6466,
#  'TGGAA': 13797,
#  'GGAAG': 8977,
#  'GAAGA': 17572,
#  'AAGAA': 28214,
#  'AGAAA': 25526,
#  'GAAAT': 17335,
#  'AAATC': 14675,
#  'AATCT': 12403,
#  'ATCTT': 15165,
#  'TTGTC': 9537,
#  'TGTCA': 8939,
#  'GTCAC': 5200,
#  'TCACC': 7416,
#  'CACCC': 3752,
#  'ACCCA': 6514,
#  'CCCAA': 7195,
#  'CCAAT': 10630,
#  'CAATG': 11426,
#  'AATGA': 16651,
#  'ATGAT': 14765,
#  'TGATC': 7570,
#  'GATCT': 7276,
#  'ATCTC': 7878,
#  'TCTCA': 8588,
#  'CTCAT': 8015,
#  'TCATA': 10964,
#  'CATAG': 5704,
#  'ATAGC': 6633,
#  'GCGCG': 1223,
#  'CGCGT': 1746,
#  'GCGTC': 3044,
#  'CGTCC': 2924,
#  'GTCCA': 5617,
#  'TCCAG': 6876,
#  'CCAGG': 4085,
#  'CAGGA': 6087,
#  'AGGAG': 5782,
#  'GGAGG': 4377,
#  'GAGGA': 7551,
#  'AGGAC': 4825,
#  'GGACC': 3241,
#  'ATGAA': 17907,
#  'TGAAT': 14354,
#  'GAATA': 13271,
#  'TAGTA': 9880,
#  'AGTAT': 10512,
#  'GTATT': 12161,
#  'TATTT': 28036,
#  'CATTA': 12333,
#  'ATTAG': 8998,
#  'TTAGA': 10299,
#  'TAGAA': 13175,
#  'AAATT': 28125,
#  'AATTT': 27880,
#  'TTTAA': 20192,
#  'TTAAA': 20135,
#  'TAAAA': 28253,
#  'AAAAG': 24672,
#  'AAAGA': 23873,
#  'AGAAG': 14762,
#  'GAAGC': 7525,
#  'AAGCT': 8890,
#  'AGCTT': 8754,
#  'CTTTA': 12712,
#  'TAAAC': 10159,
#  'AAACT': 14159,
#  'AACTA': 10137,
#  'ACTAC': 7334,
#  'ACAAA': 17403,
#  'CAAAG': 12649,
#  'AAAGT': 15429,
#  'AAGTG': 8205,
#  'GTGTT': 7948,
#  'TGTTC': 9605,
#  'GTTCT': 9491,
#  'TTCTT': 27801,
#  'TCTTC': 17397,
#  'CTTCT': 15136,
#  'TTCTG': 11372,
#  'TCTGA': 8173,
#  'CTGAA': 10090,
#  'GAATC': 7834,
#  'ATCTG': 8551,
#  'AATAA': 27630,
#  'ATAAG': 9956,
#  'TAAGG': 6572,
#  'AAGGT': 9382,
#  'AGGTC': 4281,
#  'GGTCA': 5667,
#  'TCACT': 7909,
#  'CACTT': 8290,
#  'ACTTA': 7867,
#  'CTTAC': 6464,
#  'TTACA': 10956,
#  'TACAT': 11532,
#  'ACATA': 11126,
#  'ATAGA': 10999,
#  'GAAAC': 10444,
#  'AAACC': 9277,
#  'AACCT': 7661,
#  'ACCTA': 5209,
#  'CCTAC': 3718,
#  'CTACT': 7684,
#  'TACTT': 12290,
#  'TTACC': 9005,
#  'TACCT': 7145,
#  'ACCTC': 5370,
#  'CCTCA': 5874,
#  'CTCAA': 9354,
#  'TCAAA': 19960,
#  'CAAAA': 23559,
#  'AAAGC': 10640,
#  'AAGCG': 4684,
#  'AGCGT': 4679,
#  'GCGTA': 3472,
#  'CGTAA': 5426,
#  'GTAAT': 10835,
#  'TAATT': 17658,
#  'AATTC': 14170,
#  'ATTCC': 8979,
#  'TTCCG': 5013,
#  'TCCGA': 3535,
#  'CCGAA': 4520,
#  'CGAAA': 8359,
#  'GAAAG': 12229,
#  'AAAGG': 12414,
#  'AAGGC': 7097,
#  'AGGCA': 6161,
#  'GGCAA': 7578,
#  'GCAAA': 11707,
#  'GAAAA': 29042,
#  'AAAAA': 184020,
#  'AAAAC': 17735,
#  'AACTT': 14202,
#  'ACTTT': 15300,
#  'CTTTT': 24215,
#  'TTTTG': 22045,
#  'TTGTA': 12873,
#  'TGTAG': 7087,
#  'GTAGA': 7454,
#  'AGAAT': 15042,
#  'CTTCA': 12980,
#  'TTCAG': 9855,
#  'TCAGC': 6328,
#  'CAGCT': 6214,
#  'AGCTG': 6540,
#  'GCTGC': 6599,
#  'CTGCT': 8552,
#  'GCTAG': 4028,
#  'CTAGA': 5906,
#  'GAAGT': 9832,
#  'AAGTT': 14308,
#  'GGCAT': 5535,
#  'GCATC': 6375,
#  'CATCC': 6943,
#  'ATCCT': 8159,
#  'TCCTC': 7836,
#  'CCTCT': 7216,
#  'CTCTC': 5560,
#  'TCTCT': 10719,
#  'CTCTG': 6121,
#  'TCTGT': 8548,
#  'CTGTT': 10276,
#  'TGTTG': 13729,
#  'GTTGC': 7190,
#  'TTGCT': 11532,
#  'TGCTT': 10676,
#  'GCTTA': 5702,
#  'ACACC': 6297,
#  'CACCA': 10519,
#  'ACCAT': 10009,
#  'CCATC': 7872,
#  'CATCA': 12903,
#  'ATCAA': 17090,
#  'TCAAC': 10352,
#  'CAACA': 14818,
#  'AACAT': 13401,
#  'ACATC': 8738,
#  'CTCTT': 12289,
#  'TCTTT': 23522,
#  'TTAAG': 8431,
#  'TAAGT': 7896,
#  'AAGTC': 7283,
#  'AGTCA': 6974,
#  'GTCAG': 4480,
#  'TCAGG': 4836,
#  'CAGGT': 5536,
#  'AGGTT': 7852,
#  'GGTTG': 6316,
#  'CAAAT': 16915,
#  'AAATA': 28642,
#  'AATAC': 12180,
#  'ATACT': 10336,
#  'TACTA': 10136,
#  'ACTAA': 8908,
#  'CTAAT': 9082,
#  'TAATG': 12287,
#  'AATGT': 12418,
#  'ATGTA': 11332,
#  'TGTAC': 7040,
#  'GTACA': 7300,
#  'TACAG': 7031,
#  'ACAGA': 9255,
#  'AGACG': 4596,
#  'GACGA': 6011,
#  'ACGAG': 4338,
#  'CGAGT': 2824,
#  'GAGTT': 7006,
#  'AGTTT': 14037,
#  'GTTTA': 10374,
#  'TTAAC': 9424,
#  'TAACA': 11636,
#  'AACAA': 21682,
#  'ACAAC': 11259,
#  'CAACG': 6335,
#  'AACGG': 5445,
#  'ACGGA': 4206,
#  'CGGAA': 4950,
#  'GGAAT': 8777,
#  'AATCG': 5621,
#  'TCGAC': 3961,
#  'CGACG': 3025,
#  'ACGAC': 4592,
#  'CGACC': 2468,
#  'GACCG': 2367,
#  'ACCGT': 5172,
#  'CCGTT': 5298,
#  'CGTTT': 7704,
#  'GTTTT': 17539,
#  'AGAAC': 9837,
#  'AACGA': 8529,
#  'CGACT': 3126,
#  'GACTA': 4729,
#  'CTAAC': 5601,
#  'AACAG': 10851,
#  'ACAGT': 7997,
#  'CAGTT': 8666,
#  'AGTTC': 7843,
#  'GTTCC': 5817,
#  'TTCCA': 13518,
#  'CCAGT': 6437,
#  'CAGTA': 8547,
#  'AGTAC': 7247,
#  'GTACG': 3769,
#  'TACGT': 5511,
#  'ACGTT': 7248,
#  'TTAGT': 8656,
#  'TAGTC': 4530,
#  'AGTCT': 5786,
#  'GTCTG': 4535,
#  'TCTGG': 7094,
#  'CTGGT': 7713,
#  'GCATT': 8583,
#  'CATTT': 17291,
#  'ATTTG': 15869,
#  'TTTGC': 11236,
#  'CTTAA': 8430,
#  'TAAGC': 5248,
#  'AAGCA': 10740,
#  'AGCAA': 11748,
#  'GCAAG': 6818,
#  'AAGGA': 12479,
#  'AGGAT': 8307,
#  'ATACC': 7926,
#  'TACCG': 5173,
#  'ACCGA': 4575,
#  'AAATG': 17630,
#  'ATGTC': 7641,
#  'CAGGG': 3254,
#  'AGGGG': 2630,
#  'GGGGT': 2755,
#  'GGGTT': 4867,
#  'GGTTC': 5787,
#  'GTTCG': 3838,
#  'TTCGA': 7782,
#  'TCGAG': 4053,
#  'CGAGC': 2537,
#  'GAGCC': 3514,
#  'AGCCC': 3198,
#  'GCCCC': 2138,
#  'CCCCC': 1976,
#  'CCCCT': 2819,
#  'CCCTA': 3043,
#  'CCTAT': 5193,
#  'CTATG': 5806,
#  'TATGA': 10862,
#  'ATGAG': 8140,
#  'TGAGG': 5806,
#  'GGAGT': 4269,
#  'TTTAT': 25359,
#  'TTATT': 27538,
#  'TTTTT': 65836,
#  'TCAGT': 7424,
#  'AGTAA': 11500,
#  'GTAAC': 6787,
#  'TAACT': 9216,
#  'ACTAT': 10282,
#  'CTATT': 11618,
#  'TATTC': 13299,
#  'ATTCG': 6144,
#  'TTCGG': 4355,
#  'TCGGG': 1848,
#  'CGGGT': 2256,
#  'GGGTA': 4604,
#  'GGTAC': 5575,
#  'GTACC': 5514,
#  'TACCA': 11233,
#  'TTTTC': 28304,
#  'TTTCT': 24619,
#  'TTTCC': 14023,
#  'TTCCC': 6670,
#  'TCCCC': 3070,
#  'CCCCA': 3952,
#  'CCCAC': 3718,
#  'CCACT': 6357,
#  'CACTA': 6895,
#  'TATAA': 17732,
#  'ATAAA': 26208,
#  'AAACG': 7757,
#  'GAGTC': 3696,
#  'CTATC': 6860,
#  'TATCA': 14177,
#  'TCAAT': 15523,
#  'CAATT': 15521,
#  'TCCCT': 5344,
#  'CCCTT': 6267,
#  'CCTTC': 8377,
#  'TTCAA': 20919,
#  'TCAAG': 11054,
#  'CAAGC': 6747,
#  'GGGTC': 2896,
#  'GGTCG': 2399,
#  'GTCGT': 4781,
#  'TCGTA': 5529,
#  'CGTAT': 5825,
#  'ATTTA': 19562,
#  'TAAGA': 10193,
#  'GTTCA': 9051,
#  'CAGGC': 3659,
#  'AGGCG': 3172,
#  'GGCGA': 3309,
#  'GCGAG': 2230,
#  'GAGTA': 5806,
#  'GTAAG': 6264,
#  'AGCTC': 4978,
#  'GCTCC': 3641,
#  'CTCCA': 7817,
#  'TCCAA': 13007,
#  'CCAAC': 7998,
#  'CAGTG': 6207,
#  'AGTGA': 7872,
#  'GTGAC': 4877,
#  'TGACT': 6755,
#  'GACTG': 4228,
#  'ACTGA': 7305,
#  'CTGAG': 4274,
#  'TGAGA': 8335,
#  'GAGAA': 11604,
#  'AAGTA': 12443,
#  'AGTAG': 7463,
#  'GTAGC': 5188,
#  'TAGCA': 8137,
#  'AAGAG': 12088,
#  'AGAGC': 5877,
#  'AGCCA': 6751,
#  'GCCAA': 8395,
#  'CCAAA': 14075,
#  'CAAAC': 10006,
#  'AAACA': 17198,
#  'CAACC': 6547,
#  'AACCC': 5114,
#  'ACCCC': 3004,
#  'CCCAT': 6202,
#  'CCATA': 7747,
#  'CATAA': 10967,
#  'GAGCT': 5113,
#  'CTTTC': 12607,
#  'CTGAC': 4516,
#  'TGACG': 5852,
#  'GACGC': 2923,
#  'ACGCT': 4279,
#  'CGCTG': 4104,
#  'GCTGA': 6367,
#  'ACGAA': 8273,
#  'CGAAT': 5798,
#  'CGAGA': 4064,
#  'GAGAT': 7805,
#  'AGATT': 12352,
#  'GATTG': 7972,
#  'ATTGG': 10368,
#  'TTGGC': 8272,
#  'TGGCG': 4190,
#  'CGAGG': 3169,
#  'GAGGT': 5153,
#  'AGGTA': 7184,
#  'GGTAT': 8023,
#  'GTATG': 6867,
#  'TGATG': 12696,
#  'GATGG': 7622,
#  'ATGGG': 5918,
#  'TGGGA': 6059,
#  'GGGAG': 3182,
#  'GAGGG': 3454,
#  'GGGGC': 2012,
#  'GGGCG': 1876,
#  'GAGCA': 5826,
#  'AGCAC': 6063,
#  'GCACA': 5424,
#  'CACAA': 8881,
#  'CTGAT': 7997,
#  'ATGGT': 10005,
#  'TGGTG': 9991,
#  'GGTGG': 6202,
#  'GTGGT': 7956,
#  'GGTGT': 6195,
#  'ACATT': 12847,
#  'CATTG': 11647,
#  'TTGGT': 12262,
#  'TGGTC': 6267,
#  'GTCAT': 8485,
#  'CATAT': 12933,
#  'ATATT': 25098,
#  'TATTA': 20706,
#  'ATTAT': 22438,
#  'ATTAC': 10876,
#  'TTTGG': 12689,
#  'TGGCT': 6839,
#  'GGCTC': 3408,
#  'GCTCT': 5740,
#  'CTTGG': 8515,
#  'TGGTT': 10554,
#  'TTCTA': 13125,
#  'TCTAC': 7871,
#  'TACTG': 8262,
#  'ACTGT': 7556,
#  'TTATG': 10353,
#  'TGGGT': 6229,
#  'GGGTG': 3726,
#  'TGGTA': 11115,
#  'ATGTT': 12729,
#  'GTTGG': 7967,
#  'TGGCC': 4968,
#  'GGCCG': 1842,
#  'GCCGG': 2026,
#  'CCGGT': 3476,
#  'CGGTA': 5230,
#  'GTACT': 6800,
#  'CTACC': 5543,
#  'AATCA': 13563,
#  'ATCAC': 7872,
#  'AGGTG': 5981,
#  'GGTGA': 7110,
#  'AATAT': 25024,
#  'ATATC': 12850,
#  'TATCT': 11545,
#  'CTCTA': 6865,
#  'CAAGA': 13695,
#  'AAGAT': 15623,
#  'AGATG': 10160,
#  'GGTAA': 9108,
#  'GTAAA': 13056,
#  'ATTGA': 15495,
#  'TTGAA': 21123,
#  'TGAAG': 13558,
#  'GAAGG': 8292,
#  'GGATC': 4758,
#  'ATCTA': 9729,
#  'TCTAA': 10120,
#  'CTAAA': 10938,
#  'TAAAT': 19150,
#  'ATCAT': 15058,
#  'TCATC': 13470,
#  'CATCG': 6523,
#  'CGATG': 6603,
#  'GATGT': 8267,
#  'GAACA': 10358,
#  'AACAC': 8164,
#  'ACACA': 7567,
#  'CACAT': 7422,
#  'TCACG': 3794,
#  'CACGC': 2666,
#  'GCTGG': 5368,
#  'CTGGA': 6877,
#  'ATCGT': 7197,
#  'CGTCG': 3034,
#  'CTTCG': 6020,
#  'TTCGT': 8147,
#  'TAATC': 8573,
#  'CTGTG': 5436,
#  'GTGCC': 3924,
#  'TGCCA': 8505,
#  'CTAAG': 5230,
#  'AGCTA': 5967,
#  'GCTAT': 6555,
#  'TCTAG': 5714,
#  'CTAGT': 5312,
#  'AGTGC': 4745,
#  'TGCCC': 3778,
#  'GCCCT': 3574,
#  'CCCTC': 3642,
#  'ATTCT': 14971,
#  'TTCAT': 17721,
#  'ATCCG': 4015,
#  'TCCGT': 4063,
#  'CCGTG': 2718,
#  'CGTGT': 3500,
#  'CAGCA': 10289,
#  'AGCAT': 8385,
#  'TCGTG': 4106,
#  'CGTGG': 3373,
#  'GTGGG': 3777,
#  'GGGAC': 2574,
#  'TGTTT': 17234,
#  'TTTCG': 8632,
#  'TCGGC': 2619,
#  'CGGCT': 2783,
#  'GGCTT': 6104,
#  'GCTTG': 6396,
#  'CTTGA': 10811,
#  'GCAAT': 9150,
#  'TTTGA': 19309,
#  'GAACT': 7725,
#  'CTGGG': 3953,
#  'GGGAA': 6559,
#  'GGAAA': 14163,
#  'TCACA': 7407,
#  'CACAG': 5885,
#  'CAGAT': 8553,
#  'GATTC': 8087,
#  'TCTTA': 9950,
#  'CTTAT': 9734,
#  'TGAAA': 21025,
#  'GATAA': 13147,
#  'TAAAG': 12780,
#  'TTCGC': 4324,
#  'TCGCA': 3968,
#  'CGCAG': 3401,
#  'GCAGT': 5892,
#  'CGATT': 5856,
#  'GATTA': 8798,
#  'ATTAA': 17380,
#  'TTAAT': 17037,
#  'TCATT': 16748,
#  'ATTTC': 17265,
#  'TGGCA': 8300,
#  'GGCAC': 4203,
#  'GCTAA': 6751,
#  'ATAAT': 22230,
#  'TAATA': 20689,
#  'AATCC': 7735,
#  'ATCCA': 9928,
#  'TCCAC': 6648,
#  'CCACC': 6712,
#  'AATGC': 9057,
#  'ATGCA': 9095,
#  'TGCAC': 5154,
#  'GCACT': 4605,
#  'AAGCC': 5874,
#  'CAACT': 9255,
#  'TTTAC': 12835,
#  'TACCC': 4441,
#  'ACCCG': 2363,
#  'CCCGT': 2596,
#  'CCGTA': 3875,
#  'GTATC': 6758,
#  'ATAGG': 5399,
#  'TAGGA': 5378,
#  'TTTCA': 21366,
#  'CTGGC': 4356,
#  'GGCCA': 5234,
#  'CAATC': 8253,
#  'CTTCC': 8875,
#  'CGTAG': 3613,
#  'GATGA': 14027,
#  'TGATA': 13800,
#  'TGATT': 13389,
#  'GCATA': 6754,
#  'TAGGT': 5201,
#  'GGTTT': 9397,
#  'ATCGC': 4261,
#  'CAGTC': 4338,
#  'GTCGG': 2361,
#  'CGGCA': 3944,
#  'CCAGC': 5221,
#  'GCTCA': 5227,
#  'CTCAG': 4410,
#  'AGTTG': 9403,
#  'ATATA': 28173,
#  'TATAC': 10343,
#  'ATACG': 5676,
#  'TACGA': 5769,
#  'ACGAT': 7386,
#  'CGTAC': 3539,
#  'ACCTG': 5571,
#  'CCTGA': 4999,
#  'CTAGC': 3818,
#  'AGCAG': 8780,
#  'GCAGG': 4257,
#  'GGACT': 3821,
#  'ACTGG': 6474,
#  'GTAGT': 7301,
#  'GGTTA': 5934,
#  'GTTAG': 5579,
#  'TTAGG': 5045,
#  'TAGGG': 3065,
#  'AGGGT': 4868,
#  'GTTGT': 10463,
#  'TCAGA': 8213,
#  'ATTGT': 14240,
#  'TATCC': 7236,
#  'ATCCC': 4537,
#  'CCTTT': 12441,
#  'GACGT': 4283,
#  'ACGTA': 5540,
#  'CCTAA': 5079,
#  'TCCTT': 12301,
#  'CCTTG': 7629,
#  'TGTAA': 10897,
#  'GACTT': 7047,
#  'ACTTG': 8954,
#  'TGCTC': 5958,
#  'CTCCC': 3376,
#  'GGATG': 6719,
#  'ATTCA': 14285,
#  'TTCAC': 9205,
#  'GGTCC': 2932,
#  'GTTTC': 10452,
#  'TTCCT': 12517,
#  'AAGAC': 9420,
#  'AGACA': 8508,
#  'GACAA': 9825,
#  'GGTAG': 5453,
#  'TAGCT': 6012,
#  'CTGTC': 5337,
#  'GTCAA': 9523,
#  'CCCCG': 1461,
#  'AACGC': 4352,
#  'ACGCA': 4016,
#  'CGCAA': 4834,
#  'AACTC': 7024,
#  'ACTCA': 6327,
#  'ATCGG': 3790,
#  'GAGTG': 4049,
#  'TGTCC': 5345,
#  'GTCCT': 4667,
#  'AGGAA': 12606,
#  'GGAAC': 6012,
#  'ACCCT': 4681,
#  'CCCTG': 3482,
#  'CCTGT': 5412,
#  'CGTGA': 3841,
#  'GTGAT': 7826,
#  'TTGAC': 8946,
#  'CAAGT': 9049,
#  'CTTGC': 6822,
#  'TTGCA': 10701,
#  'TGCAA': 10864,
#  'TAGAT': 9342,
#  'TCCAT': 10375,
#  'CCATT': 11895,
#  'AGATA': 11641,
#  'AATTG': 15419,
#  'ATTGC': 9340,
#  'GCTTC': 7500,
#  'TCGTT': 8382,
#  'CGTTA': 6356,
#  'TTATA': 17567,
#  'TATAG': 8691,
#  'TAGAC': 5202,
#  'AGACT': 5918,
#  'TGACA': 9038,
#  'GACAT': 7628,
#  'TATGC': 6635,
#  'TGCAG': 7064,
#  'AAAAT': 35716,
#  'CATAC': 6994,
#  'ACTTC': 9767,
#  'CATCT': 10076,
#  'CTTAG': 5193,
#  'AATTA': 17816,
#  'ATGGC': 7195,
#  'CCCAG': 3963,
#  'GATGC': 6249,
#  'ATGCG': 3823,
#  'TGCGG': 3202,
#  'GCGGA': 2884,
#  'CGGAG': 2691,
#  'GTCCC': 2632,
#  'TCTGC': 6772,
#  'TGCTG': 9907,
#  'CATTC': 8826,
#  'TGGGC': 4255,
#  'GGGCA': 3890,
#  'TCCCA': 6425,
#  'CACGA': 4251,
#  'GAGAG': 5669,
#  'AGAGA': 10969,
#  'AGTTA': 8727,
#  'TGGAC': 5737,
#  'GGACA': 5146,
#  'GACAG': 5401,
#  'ACAGC': 6547,
#  'GCGTT': 4478,
#  'GTGTG': 4679,
#  'TGTGT': 7453,
#  'GTGTA': 5936,
#  'AACCG': 4246,
#  'ACCGG': 3389,
#  'CCGGC': 2001,
#  'CGGCC': 2064,
#  'TTGCC': 7792,
#  'GCCAG': 4321,
#  'TAACC': 5822,
#  'CCTAG': 2707,
#  'AGATC': 7196,
#  'GATCA': 7398,
#  'GTATA': 10707,
#  'TGTAT': 12137,
#  'TAGGC': 3274,
#  'AGGCT': 5158,
#  'GGCTG': 4316,
#  'CTGCA': 7155,
#  'GCAGA': 7228,
#  'CAGAA': 12192,
#  'GAATT': 13963,
#  'TTCTC': 11944,
#  'TCTCC': 7009,
#  'CTCCT': 5917,
#  'TAGTT': 10019,
#  'TGCCT': 6016,
#  'GCCTA': 3244,
#  'TCCCG': 2391,
#  'CCGTC': 3167,
#  'GTCTC': 4953,
#  'AACTG': 9010,
#  'TCCTG': 5907,
#  'CCTGC': 4299,
#  'GGTGC': 4745,
#  'GTGCG': 2150,
#  'GCGGT': 3130,
#  'CGGTG': 4518,
#  'ACAAG': 10693,
#  'TATTG': 14394,
#  'TGACC': 5515,
#  'GACCT': 4285,
#  'TTGGG': 6721,
#  'TGGGG': 3807,
#  'CCTCC': 4643,
#  'CCACA': 6719,
#  'ATCAG': 8067,
#  'CAGAG': 6351,
#  'AGAGG': 7018,
#  'GAGGC': 4203,
#  'GGCTA': 4172,
#  'CACAC': 4903,
#  'CACCT': 6307,
#  'CTGCC': 4819,
#  'GCCAT': 7349,
#  'TGCAT': 8848,
#  'TAGAG': 6918,
#  'ACATG': 7330,
#  'CATGT': 7275,
#  'ACCTT': 9277,
#  'GCTCG': 2205,
#  'CTCGC': 2235,
#  'TCGCG': 1745,
#  'GCGTG': 2617,
#  'GTGGC': 4489,
#  'GGCGT': 3013,
#  'AATGG': 12160,
#  'GCAAC': 7330,
#  'ACGCG': 1747,
#  'GACCC': 3219,
#  'GTGAG': 4146,
#  'TGAGT': 6300,
#  'TTGGA': 12312,
#  'TGGAG': 6904,
#  'GGAGA': 6409,
#  'TGAGC': 5106,
#  'GAGCG': 2585,
#  'AGCGA': 4380,
#  'GCGAC': 2640,
#  'TTGAT': 16838,
#  'TTACG': 5425,
#  'TACGC': 3293,
#  'ACGCC': 3190,
#  'CGCCC': 1893,
#  'TTGCG': 4597,
#  'TGCGT': 4175,
#  'TTACT': 11732,
#  'TTGAG': 8979,
#  'AGCGG': 3635,
#  'GCGGG': 1788,
#  'TAACG': 6231,
#  'GAATG': 8933,
#  'CACTC': 4258,
#  'ACTCG': 2808,
#  'CTCGG': 1868,
#  'CGGGC': 1627,
#  'GGGCC': 2454,
#  'TCATG': 8154,
#  'CATGA': 8158,
#  'ATGAC': 8873,
#  'ACTGC': 6119,
#  'CTGCG': 3251,
#  'TGCGC': 2862,
#  'GCGCC': 2412,
#  'CGCCA': 4333,
#  'GACGG': 3166,
#  'ACGGT': 5395,
#  'CGGTC': 2463,
#  'GGTCT': 4928,
#  'CTACG': 3658,
#  'GGCAG': 4980,
#  'GAGAC': 4694,
#  'CCTTA': 6294,
#  'ATGCT': 8380,
#  'GGGGA': 3018,
#  'ACGGC': 3303,
#  'ACCAC': 8185,
#  'CCGGA': 2845,
#  'CCGAT': 3898,
#  'GTTAA': 8980,
#  'GACAC': 4722,
#  'GAACG': 5138,
#  'GCCAC': 4768,
#  'AGGCC': 3747,
#  'TACTC': 5869,
#  'GCTGT': 6535,
#  'ACTCT': 7119,
#  'CGGTT': 4127,
#  'CTCAC': 4256,
#  'CATGG': 6436,
#  'GTCGC': 2697,
#  'TCGCT': 4365,
#  'CGCTC': 2426,
#  'TCTCG': 4000,
#  'CTCGA': 4047,
#  'CGATC': 3305,
#  'AGAGT': 7162,
#  'GATCC': 4724,
#  'CACTG': 5923,
#  'GGCGC': 2387,
#  'TGTGG': 6710,
#  'GGCCT': 3561,
#  'GCCTC': 3936,
#  'CCTCG': 3067,
#  'CTCGT': 3916,
#  'CGTCA': 6126,
#  'CAGCC': 4229,
#  'AGCCT': 4885,
#  'GCCTT': 6899,
#  'CACCG': 4637,
#  'ACCGC': 3288,
#  'CCGCT': 3714,
#  'TCGGT': 4325,
#  'GTTAC': 6908,
#  'GTCGA': 3940,
#  'TGCCG': 3964,
#  'TCGAA': 7707,
#  'ACAGG': 5366,
#  'CGAAG': 5913,
#  'AACGT': 7131,
#  'ACGTC': 4374,
#  'TCCTA': 5186,
#  'CGTTC': 4944,
#  'AGTCC': 3582,
#  'GGACG': 2908,
#  'GTTTG': 10055,
#  'GCCTG': 3664,
#  'GTTGA': 10206,
#  'ATGCC': 5703,
#  'CGTTG': 6387,
#  'GGCGG': 2533,
#  'CGGAT': 3869,
#  'ACGTG': 3864,
#  'GTAGG': 3680,
#  'CTAGG': 2785,
#  'CGTGC': 2574,
#  'CCATG': 6422,
#  'ACACT': 6453,
#  'CCGAG': 1957,
#  'GCGAA': 3974,
#  'GCATG': 4934,
#  'CTGTA': 7019,
#  'TCGGA': 3595,
#  'GGAGC': 3504,
#  'CCCGC': 1800,
#  'CCGCC': 2645,
#  'CGCCT': 3282,
#  'CCTGG': 3935,
#  'CGGAC': 1983,
#  'CCACG': 3558,
#  'CGCAC': 2269,
#  'AGGGC': 3540,
#  'GGCCC': 2596,
#  'GCACG': 2902,
#  'CGCTA': 4134,
#  'TAGCC': 4030,
#  'CATGC': 5002,
#  'CGAAC': 4435,
#  'TGCGA': 3564,
#  'CCCGG': 1444,
#  'CCGGG': 1441,
#  'CGCGA': 1760,
#  'GCGAT': 4158,
#  'ATAAC': 11116,
#  'AGCCG': 2846,
#  'GCCGA': 2611,
#  'GCCGC': 2978,
#  'CCGCA': 3375,
#  'CGCAT': 3878,
#  'CGACA': 4881,
#  'CCGAC': 2320,
#  'GGGCT': 3235,
#  'GTGCA': 4984,
#  'GTCCG': 1874,
#  'TCCGC': 3152,
#  'GCAGC': 6858,
#  'GCGCA': 3016,
#  'GACTC': 3599,
#  ...}

# %%
# Out:
# {'AAAAA': 0.3943428049472617,
#  'AAAAC': 0.40864695968619297,
#  'AAAAG': 0.4011097991163127,
#  'AAAAT': 0.40154503004713454,
#  'AAACA': 0.40549305192505913,
#  'AAACC': 0.40733402726879736,
#  'AAACG': 0.40267464579954904,
#  'AAACT': 0.4071981366950788,
#  'AAAGA': 0.4079008879938238,
#  'AAAGC': 0.4001021138747851,
#  'AAAGG': 0.40135526191035337,
#  'AAAGT': 0.4089565410023977,
#  'AAATA': 0.40558495008592804,
#  'AAATC': 0.3966713398831711,
#  'AAATG': 0.4017992262187994,
#  'AAATT': 0.404260893810465,
#  'AACAA': 0.4007315023909189,
#  'AACAC': 0.4110628275626929,
#  'AACAG': 0.4071237721475039,
#  'AACAT': 0.4046479511573788,
#  'AACCA': 0.4076773086174188,
#  'AACCC': 0.40901818838688647,
#  'AACCG': 0.402887120135365,
#  'AACCT': 0.39965129832869034,
#  'AACGA': 0.40282787161238737,
#  'AACGC': 0.4049609830194923,
#  'AACGG': 0.40651835776476725,
#  'AACGT': 0.4002639622489544,
#  'AACTA': 0.3941223074819228,
#  'AACTC': 0.4038700980951977,
#  'AACTG': 0.4055045642083875,
#  'AACTT': 0.40923005117716305,
#  'AAGAA': 0.4066608147401442,
#  'AAGAC': 0.40219355956262026,
#  'AAGAG': 0.4010523092105403,
#  'AAGAT': 0.40866460799096815,
#  'AAGCA': 0.403848041741027,
#  'AAGCC': 0.4005970373680574,
#  'AAGCG': 0.40762021763693534,
#  'AAGCT': 0.4110140171230058,
#  'AAGGA': 0.4049590410312161,
#  'AAGGC': 0.40326516837850174,
#  'AAGGG': 0.40346034590867363,
#  'AAGGT': 0.4155220158698429,
#  'AAGTA': 0.4025839573363166,
#  'AAGTC': 0.4110904580459447,
#  'AAGTG': 0.4137209311816417,
#  'AAGTT': 0.4043103399399408,
#  'AATAA': 0.40267853204366066,
#  'AATAC': 0.4020537264542762,
#  'AATAG': 0.40657541792441854,
#  'AATAT': 0.4060063536156928,
#  'AATCA': 0.40453622835582026,
#  'AATCC': 0.405317080858653,
#  'AATCG': 0.40444998424466055,
#  'AATCT': 0.4007967788635933,
#  'AATGA': 0.40613460524288436,
#  'AATGC': 0.3991980863595672,
#  'AATGG': 0.3988559653025672,
#  'AATGT': 0.40563581801882154,
#  'AATTA': 0.4059485422941167,
#  'AATTC': 0.40434080111098614,
#  'AATTG': 0.4033567349590102,
#  'AATTT': 0.40207669756528214,
#  'ACAAA': 0.40399889066161065,
#  'ACAAC': 0.4036588220235324,
#  'ACAAG': 0.39960732501783763,
#  'ACAAT': 0.4040622196695164,
#  'ACACA': 0.3930493001683211,
#  'ACACC': 0.39987857875884925,
#  'ACACG': 0.401856413810315,
#  'ACACT': 0.4079329637550948,
#  'ACAGA': 0.39872468712350023,
#  'ACAGC': 0.400382327042866,
#  'ACAGG': 0.4106941184495158,
#  'ACAGT': 0.41453318369764514,
#  'ACATA': 0.4074316452581495,
#  'ACATC': 0.40897133213091963,
#  'ACATG': 0.40849469612754,
#  'ACATT': 0.40437149719799104,
#  'ACCAA': 0.4066911500302391,
#  'ACCAC': 0.3993267367157127,
#  'ACCAG': 0.4029658112121869,
#  'ACCAT': 0.40360587854063545,
#  'ACCCA': 0.40730886316781645,
#  'ACCCC': 0.41727128311989226,
#  'ACCCG': 0.38991366666930016,
#  'ACCCT': 0.424350507928976,
#  'ACCGA': 0.40312727862703873,
#  'ACCGC': 0.40629295985739283,
#  'ACCGG': 0.4064601506289018,
#  'ACCGT': 0.40459321055986763,
#  'ACCTA': 0.3939053974992748,
#  'ACCTC': 0.39529064618359977,
#  'ACCTG': 0.39756775658891447,
#  'ACCTT': 0.41502518986878284,
#  'ACGAA': 0.40416624120695743,
#  'ACGAC': 0.4080691191949625,
#  'ACGAG': 0.42062533441594663,
#  'ACGAT': 0.41304133736977666,
#  'ACGCA': 0.40776188150240983,
#  'ACGCC': 0.39864633570537106,
#  'ACGCG': 0.4262369480195536,
#  'ACGCT': 0.4023062091411989,
#  'ACGGA': 0.3908425932555622,
#  'ACGGC': 0.4158027185238405,
#  'ACGGG': 0.41031642412316677,
#  'ACGGT': 0.4042327586456445,
#  'ACGTA': 0.40142484497862735,
#  'ACGTC': 0.39587128539271815,
#  'ACGTG': 0.404116592159271,
#  'ACGTT': 0.4104742206380584,
#  'ACTAA': 0.3974544409007091,
#  'ACTAC': 0.4017784047690167,
#  'ACTAG': 0.4065853811228756,
#  'ACTAT': 0.4045779641298259,
#  'ACTCA': 0.4057218137296928,
#  'ACTCC': 0.40730241299825853,
#  'ACTCG': 0.3985151935529761,
#  'ACTCT': 0.4065716108322757,
#  'ACTGA': 0.39757505076118016,
#  'ACTGC': 0.4074131352637349,
#  'ACTGG': 0.41134938331830007,
#  'ACTGT': 0.4083846380792701,
#  'ACTTA': 0.41128127831977684,
#  'ACTTC': 0.410770948465471,
#  'ACTTG': 0.404275499535491,
#  'ACTTT': 0.40011239683932787,
#  'AGAAA': 0.407699692677677,
#  'AGAAC': 0.4002846509137222,
#  'AGAAG': 0.4082385382167007,
#  'AGAAT': 0.4012323277860886,
#  'AGACA': 0.397099571976387,
#  'AGACC': 0.4028847949744251,
#  'AGACG': 0.401163409612808,
#  'AGACT': 0.4144237231439468,
#  'AGAGA': 0.40157947613851097,
#  'AGAGC': 0.3957376421354027,
#  'AGAGG': 0.3945059772445202,
#  'AGAGT': 0.39983007386711017,
#  'AGATA': 0.409473147886975,
#  'AGATC': 0.40968818567323967,
#  'AGATG': 0.41044438360621044,
#  'AGATT': 0.405400180821653,
#  'AGCAA': 0.3993664696780632,
#  'AGCAC': 0.4051001523072335,
#  'AGCAG': 0.39777172435369024,
#  'AGCAT': 0.40557271903767395,
#  'AGCCA': 0.3948484132754792,
#  'AGCCC': 0.38957925465275683,
#  'AGCCG': 0.40379858930381196,
#  'AGCCT': 0.3986004521888222,
#  'AGCGA': 0.40788855928540446,
#  'AGCGC': 0.40413579305397046,
#  'AGCGG': 0.4179463867112518,
#  'AGCGT': 0.4005896128404828,
#  'AGCTA': 0.3967779496213904,
#  'AGCTC': 0.41140262436362135,
#  'AGCTG': 0.40530795963019833,
#  'AGCTT': 0.4084923521207,
#  'AGGAA': 0.39796979505859614,
#  'AGGAC': 0.4034667505356285,
#  'AGGAG': 0.41782344514569203,
#  'AGGAT': 0.3926526000473699,
#  'AGGCA': 0.4053138149819578,
#  'AGGCC': 0.40763030503907677,
#  'AGGCG': 0.3982337794878445,
#  'AGGCT': 0.4069372227489802,
#  'AGGGA': 0.40549209218136156,
#  'AGGGC': 0.39701049969845426,
#  'AGGGG': 0.3969104331127184,
#  'AGGGT': 0.3852595898902845,
#  'AGGTA': 0.40447869453995267,
#  'AGGTC': 0.3943123746545714,
#  'AGGTG': 0.4095308408041443,
#  'AGGTT': 0.4137164768036149,
#  'AGTAA': 0.404575440676282,
#  'AGTAC': 0.40785933201348273,
#  'AGTAG': 0.39884614029797544,
#  'AGTAT': 0.40286169145794354,
#  'AGTCA': 0.407459575966201,
#  'AGTCC': 0.39534653710604717,
#  'AGTCG': 0.4018962920438749,
#  'AGTCT': 0.40296326553644957,
#  'AGTGA': 0.40708266188180986,
#  'AGTGC': 0.402956490227484,
#  'AGTGG': 0.4083732846670292,
#  'AGTGT': 0.4027306097787603,
#  'AGTTA': 0.4043918495515779,
#  'AGTTC': 0.40719051846140036,
#  'AGTTG': 0.40766190207266795,
#  'AGTTT': 0.4057162864334508,
#  'ATAAA': 0.40473143072795054,
#  'ATAAC': 0.4095966247064103,
#  'ATAAG': 0.4020932476054016,
#  'ATAAT': 0.4004911290148211,
#  'ATACA': 0.4085815462060431,
#  'ATACC': 0.4068662197404228,
#  'ATACG': 0.40041649827493786,
#  'ATACT': 0.4048757940377658,
#  'ATAGA': 0.40664303371000665,
#  'ATAGC': 0.4072695555966831,
#  'ATAGG': 0.41597294188058476,
#  'ATAGT': 0.4049328377931705,
#  'ATATA': 0.40455578963087224,
#  'ATATC': 0.4010758714030784,
#  'ATATG': 0.3967113191128462,
#  'ATATT': 0.40188041429588117,
#  'ATCAA': 0.4054556502015101,
#  'ATCAC': 0.39349585223737593,
#  'ATCAG': 0.41471682901536683,
#  'ATCAT': 0.4055764223285391,
#  'ATCCA': 0.4047367604604734,
#  'ATCCC': 0.41243181945433094,
#  'ATCCG': 0.41019616352636407,
#  'ATCCT': 0.4063739505278047,
#  'ATCGA': 0.4019055493011926,
#  'ATCGC': 0.4086300483954091,
#  'ATCGG': 0.4200179488146071,
#  'ATCGT': 0.4035029364015809,
#  'ATCTA': 0.4031245529270463,
#  'ATCTC': 0.40041128066337883,
#  'ATCTG': 0.4044216315396643,
#  'ATCTT': 0.39808635261658837,
#  'ATGAA': 0.4040157353713613,
#  'ATGAC': 0.4092469070714088,
#  'ATGAG': 0.4016848652389988,
#  'ATGAT': 0.40621439026370787,
#  'ATGCA': 0.40755038633839197,
#  'ATGCC': 0.4089099008517762,
#  'ATGCG': 0.4004421040211078,
#  'ATGCT': 0.40441350013020094,
#  'ATGGA': 0.4020333145855955,
#  'ATGGC': 0.40511928262027025,
#  'ATGGG': 0.4046793268922783,
#  'ATGGT': 0.39497970825225875,
#  'ATGTA': 0.40486228034106375,
#  'ATGTC': 0.39837401476728745,
#  'ATGTG': 0.40281706392047123,
#  'ATGTT': 0.40538021073551045,
#  'ATTAA': 0.40389586885370615,
#  'ATTAC': 0.4131000821064404,
#  'ATTAG': 0.3993994137553177,
#  'ATTAT': 0.4084533246687169,
#  'ATTCA': 0.3972263157039277,
#  'ATTCC': 0.3995996770984658,
#  'ATTCG': 0.392716394829758,
#  'ATTCT': 0.40576023033883324,
#  'ATTGA': 0.39969280401322915,
#  'ATTGC': 0.39843436935709853,
#  'ATTGG': 0.4015282629758829,
#  'ATTGT': 0.40282119866902344,
#  'ATTTA': 0.4030581918053444,
#  'ATTTC': 0.40267477932518275,
#  'ATTTG': 0.4030264709333019,
#  'ATTTT': 0.4076397045970388,
#  'CAAAA': 0.4053240950712231,
#  'CAAAC': 0.40711419778029756,
#  'CAAAG': 0.40053459789927154,
#  'CAAAT': 0.39803012832086493,
#  'CAACA': 0.40661274219366267,
#  'CAACC': 0.39144695976576566,
#  'CAACG': 0.39537845948506145,
#  'CAACT': 0.40015351459710974,
#  'CAAGA': 0.4026432581615065,
#  'CAAGC': 0.4015318569553183,
#  'CAAGG': 0.4036264351536201,
#  'CAAGT': 0.39664170178174424,
#  'CAATA': 0.39854862004061165,
#  'CAATC': 0.41004727712154504,
#  'CAATG': 0.40737842378402955,
#  'CAATT': 0.41234583390105667,
#  'CACAA': 0.4102375266267281,
#  'CACAC': 0.38394169409723483,
#  'CACAG': 0.4004030633897976,
#  'CACAT': 0.4019398009711005,
#  'CACCA': 0.38818188252303226,
#  'CACCC': 0.415809412089444,
#  'CACCG': 0.4164421948510189,
#  'CACCT': 0.39936659161549704,
#  'CACGA': 0.40320655216801204,
#  'CACGC': 0.40316104451509793,
#  'CACGG': 0.4061565189844474,
#  'CACGT': 0.42050725175818615,
#  'CACTA': 0.41218022988394276,
#  'CACTC': 0.41349468118618776,
#  'CACTG': 0.3989812284932003,
#  'CACTT': 0.40919489818763094,
#  'CAGAA': 0.4084158605282884,
#  'CAGAC': 0.3897573576320589,
#  'CAGAG': 0.40153301713396183,
#  'CAGAT': 0.4108312509860915,
#  'CAGCA': 0.40244021444177935,
#  'CAGCC': 0.3875106085943185,
#  'CAGCG': 0.4086646872913837,
#  'CAGCT': 0.41322477338903074,
#  'CAGGA': 0.3991128081314057,
#  'CAGGC': 0.3978068925658217,
#  'CAGGG': 0.400819175204963,
#  'CAGGT': 0.4126913663808534,
#  'CAGTA': 0.4087068166526256,
#  'CAGTC': 0.39517852202856835,
#  'CAGTG': 0.407636771019246,
#  'CAGTT': 0.4001036479197064,
#  'CATAA': 0.4022228916282188,
#  'CATAC': 0.40397553157549193,
#  'CATAG': 0.3962591759541938,
#  'CATAT': 0.40641528207832783,
#  'CATCA': 0.4070136907908738,
#  'CATCC': 0.4030620225362897,
#  'CATCG': 0.4090114444970542,
#  'CATCT': 0.4070689459155328,
#  'CATGA': 0.4088511998670565,
#  'CATGC': 0.40917734759522933,
#  'CATGG': 0.40831690002956916,
#  'CATGT': 0.4145086958773207,
#  'CATTA': 0.4102872195743816,
#  'CATTC': 0.4018968459869148,
#  'CATTG': 0.3927826681983679,
#  'CATTT': 0.40978475212710774,
#  'CCAAA': 0.403402415480731,
#  'CCAAC': 0.4064015466308551,
#  'CCAAG': 0.40152011728712333,
#  'CCAAT': 0.40265026169067525,
#  'CCACA': 0.4011776835410818,
#  'CCACC': 0.4037048739456063,
#  'CCACG': 0.39947965889419795,
#  'CCACT': 0.4062170293419435,
#  'CCAGA': 0.40601307105414575,
#  'CCAGC': 0.4000816587538021,
#  'CCAGG': 0.38714309770136146,
#  'CCAGT': 0.40448118799360944,
#  'CCATA': 0.3972713199388997,
#  'CCATC': 0.41545568321789356,
#  'CCATG': 0.4164043525073226,
#  'CCATT': 0.40360591360723985,
#  'CCCAA': 0.40227425199550343,
#  'CCCAC': 0.4072837121472181,
#  'CCCAG': 0.4085690105001192,
#  'CCCAT': 0.4080906019427342,
#  'CCCCA': 0.39047227898922293,
#  'CCCCC': 0.3975578559637723,
#  'CCCCG': 0.39999136431891896,
#  'CCCCT': 0.40803813333373,
#  'CCCGA': 0.4152666850347891,
#  'CCCGC': 0.41104556619694493,
#  'CCCGG': 0.4080880536503354,
#  'CCCGT': 0.40957200193754595,
#  'CCCTA': 0.4105989036199282,
#  'CCCTC': 0.4036100111333648,
#  'CCCTG': 0.4151074576821035,
#  'CCCTT': 0.4032419568495666,
#  'CCGAA': 0.41794280704501,
#  'CCGAC': 0.3913353666716672,
#  'CCGAG': 0.41113251378736765,
#  'CCGAT': 0.4147221271975749,
#  'CCGCA': 0.41132805222896496,
#  'CCGCC': 0.3839665849942175,
#  'CCGCG': 0.4087059984336805,
#  'CCGCT': 0.42364310090125357,
#  'CCGGA': 0.4020562879472547,
#  'CCGGC': 0.3797350597647592,
#  'CCGGG': 0.39617065122663714,
#  'CCGGT': 0.3923812583557574,
#  'CCGTA': 0.4016783521118265,
#  'CCGTC': 0.40947677116616843,
#  'CCGTG': 0.38913518883248593,
#  'CCGTT': 0.41610166748903477,
#  'CCTAA': 0.39429995842843213,
#  'CCTAC': 0.3974288324693875,
#  'CCTAG': 0.4045061536897144,
#  'CCTAT': 0.4020571666207149,
#  'CCTCA': 0.40247255755896383,
#  'CCTCC': 0.4023757841029641,
#  'CCTCG': 0.4101011637073987,
#  'CCTCT': 0.40246318283541777,
#  'CCTGA': 0.40165994648608344,
#  'CCTGC': 0.4091804438533297,
#  'CCTGG': 0.40811926818109817,
#  'CCTGT': 0.39059972867889337,
#  'CCTTA': 0.39869233210847627,
#  'CCTTC': 0.4147281517049505,
#  'CCTTG': 0.4141168602596593,
#  'CCTTT': 0.408411865808347,
#  'CGAAA': 0.41022250829609186,
#  'CGAAC': 0.4054141365192868,
#  'CGAAG': 0.4108041049498625,
#  'CGAAT': 0.4104845483130514,
#  'CGACA': 0.39926546613694636,
#  'CGACC': 0.4034385528654025,
#  'CGACG': 0.394903329549337,
#  'CGACT': 0.4085864081960992,
#  'CGAGA': 0.3982135951352128,
#  'CGAGC': 0.4086541291676199,
#  'CGAGG': 0.398393791611602,
#  'CGAGT': 0.4068075689092618,
#  'CGATA': 0.40233965677546607,
#  'CGATC': 0.40712300260634915,
#  'CGATG': 0.4084922991085972,
#  'CGATT': 0.4011698080394588,
#  'CGCAA': 0.40376589422207043,
#  'CGCAC': 0.399751495150022,
#  'CGCAG': 0.3911005012321997,
#  'CGCAT': 0.41358805047728414,
#  'CGCCA': 0.4005750213549954,
#  'CGCCC': 0.38081568814770933,
#  'CGCCG': 0.40727211152102033,
#  'CGCCT': 0.4171642652757377,
#  'CGCGA': 0.3969912531839571,
#  'CGCGC': 0.41925688537996403,
#  'CGCGG': 0.40555980822616716,
#  'CGCGT': 0.4346251343191666,
#  'CGCTA': 0.3968749948611768,
#  'CGCTC': 0.4075006146870688,
#  'CGCTG': 0.4118964520018745,
#  'CGCTT': 0.40666513169981877,
#  'CGGAA': 0.4106597465852499,
#  'CGGAC': 0.4233783279949516,
#  'CGGAG': 0.4193002058929448,
#  'CGGAT': 0.39218023283750614,
#  'CGGCA': 0.4124633371381594,
#  'CGGCC': 0.38777161857599596,
#  'CGGCG': 0.3839938833500288,
#  'CGGCT': 0.3993590883612528,
#  'CGGGA': 0.41478560259880226,
#  'CGGGC': 0.40834642018832684,
#  'CGGGG': 0.44085368603552005,
#  'CGGGT': 0.40304298015324475,
#  'CGGTA': 0.4047216988326712,
#  'CGGTC': 0.39919084776952507,
#  'CGGTG': 0.4102516472296986,
#  'CGGTT': 0.400895889462878,
#  'CGTAA': 0.41203783639339886,
#  'CGTAC': 0.40235637437091337,
#  'CGTAG': 0.41415892047265235,
#  'CGTAT': 0.4020504778430519,
#  'CGTCA': 0.3968981315104078,
#  'CGTCC': 0.3879666598818919,
#  'CGTCG': 0.4141623678599824,
#  'CGTCT': 0.41999304432017853,
#  'CGTGA': 0.4033742022609466,
#  'CGTGC': 0.3936326761051542,
#  'CGTGG': 0.38857025410364454,
#  'CGTGT': 0.4183934174906227,
#  'CGTTA': 0.4070280314638608,
#  'CGTTC': 0.4054123852527513,
#  'CGTTG': 0.4004180449844563,
#  'CGTTT': 0.41325198873843677,
#  'CTAAA': 0.4014714951402149,
#  'CTAAC': 0.40924033287125977,
#  'CTAAG': 0.40645849713094273,
#  'CTAAT': 0.40000554489353407,
#  'CTACA': 0.3913848849916103,
#  'CTACC': 0.4123534110492033,
#  'CTACG': 0.40197945353882175,
#  'CTACT': 0.3977401901794143,
#  'CTAGA': 0.40533534447674674,
#  'CTAGC': 0.39125068507025407,
#  'CTAGG': 0.3901697990333066,
#  'CTAGT': 0.4005340591853776,
#  'CTATA': 0.3970983768307589,
#  'CTATC': 0.40896851769473697,
#  'CTATG': 0.3991169401733667,
#  'CTATT': 0.4025606559749818,
#  'CTCAA': 0.40271197260425856,
#  'CTCAC': 0.40920218571299377,
#  'CTCAG': 0.3925670371107743,
#  'CTCAT': 0.4098324576298697,
#  'CTCCA': 0.4037866817990409,
#  'CTCCC': 0.40699192630421616,
#  'CTCCG': 0.3948914281720545,
#  'CTCCT': 0.40577056689089713,
#  'CTCGA': 0.39468172586413325,
#  'CTCGC': 0.41603476068978934,
#  'CTCGG': 0.4128477241059244,
#  'CTCGT': 0.4180950174742798,
#  'CTCTA': 0.4093826468017413,
#  'CTCTC': 0.4045741965598948,
#  'CTCTG': 0.40791996672664804,
#  'CTCTT': 0.39817662867892895,
#  'CTGAA': 0.4036561628342052,
#  'CTGAC': 0.39112285794744117,
#  'CTGAG': 0.4124672682571179,
#  'CTGAT': 0.4052905746561662,
#  'CTGCA': 0.40227253924931017,
#  'CTGCC': 0.3981556125656904,
#  'CTGCG': 0.40034741995408,
#  'CTGCT': 0.40508946053145717,
#  'CTGGA': 0.41142903947109727,
#  'CTGGC': 0.4096469286136903,
#  'CTGGG': 0.3951086457586671,
#  'CTGGT': 0.41449026544743117,
#  'CTGTA': 0.39972928381114925,
#  'CTGTC': 0.40716391472928976,
#  'CTGTG': 0.4102135016600183,
#  'CTGTT': 0.4128093185630165,
#  'CTTAA': 0.3972079482243292,
#  'CTTAC': 0.40418020709837965,
#  'CTTAG': 0.4023212724321472,
#  'CTTAT': 0.40642336150697533,
#  'CTTCA': 0.40906030064192644,
#  'CTTCC': 0.40393240138543884,
#  'CTTCG': 0.39369562908046773,
#  'CTTCT': 0.4088870910896561,
#  'CTTGA': 0.4085750293752249,
#  'CTTGC': 0.4061994743271994,
#  'CTTGG': 0.39563814842608497,
#  'CTTGT': 0.4016324910088623,
#  'CTTTA': 0.4002676076357618,
#  'CTTTC': 0.40542862977814154,
#  'CTTTG': 0.40195488604841173,
#  'CTTTT': 0.402074865345739,
#  'GAAAA': 0.4030394037977314,
#  'GAAAC': 0.4043107467151474,
#  'GAAAG': 0.4104219796620631,
#  'GAAAT': 0.410753586561421,
#  'GAACA': 0.40704261859927404,
#  'GAACC': 0.41051786487217307,
#  'GAACG': 0.4118663462291467,
#  'GAACT': 0.40198901785760566,
#  'GAAGA': 0.4087982247445622,
#  'GAAGC': 0.417104938127486,
#  'GAAGG': 0.4125027097456384,
#  'GAAGT': 0.40799174168454283,
#  'GAATA': 0.4035317840612355,
#  'GAATC': 0.3980313533495677,
#  'GAATG': 0.4056376293899549,
#  'GAATT': 0.40398682955020726,
#  'GACAA': 0.3972117560964023,
#  'GACAC': 0.4020998246241432,
#  'GACAG': 0.3976982105506263,
#  'GACAT': 0.40054236455598835,
#  'GACCA': 0.40370817692478994,
#  'GACCC': 0.4096529242850514,
#  'GACCG': 0.41845700707679206,
#  'GACCT': 0.4063090625441755,
#  'GACGA': 0.40594519096719855,
#  'GACGC': 0.40485754048194883,
#  'GACGG': 0.40922859236912495,
#  'GACGT': 0.4007580691947575,
#  'GACTA': 0.4111244757659082,
#  'GACTC': 0.4078582916092697,
#  'GACTG': 0.3933887851326836,
#  'GACTT': 0.4083219657526873,
#  'GAGAA': 0.4033063558360361,
#  'GAGAC': 0.4052607267928369,
#  'GAGAG': 0.39750704962878003,
#  'GAGAT': 0.40700564287257157,
#  'GAGCA': 0.3954047135734238,
#  'GAGCC': 0.40387887548366713,
#  'GAGCG': 0.40430957059925515,
#  'GAGCT': 0.4080834232614682,
#  'GAGGA': 0.38444532495361283,
#  'GAGGC': 0.39122171051352694,
#  'GAGGG': 0.39655893101224404,
#  'GAGGT': 0.40349343891072453,
#  'GAGTA': 0.4075259067036255,
#  'GAGTC': 0.39873981468536757,
#  'GAGTG': 0.403298120338013,
#  'GAGTT': 0.4001086076040724,
#  'GATAA': 0.4052845748965754,
#  'GATAC': 0.4136166239704258,
#  'GATAG': 0.41283388435359125,
#  'GATAT': 0.40568117606196663,
#  'GATCA': 0.41040956681227947,
#  'GATCC': 0.4106128142598946,
#  'GATCG': 0.40542420377715066,
#  'GATCT': 0.40708062864563077,
#  'GATGA': 0.4075204804725977,
#  'GATGC': 0.4084076544539158,
#  'GATGG': 0.40143084758963665,
#  'GATGT': 0.4002942498956986,
#  'GATTA': 0.4054945456329458,
#  'GATTC': 0.39575683730870814,
#  'GATTG': 0.3905508406649521,
#  'GATTT': 0.4046230629666302,
#  'GCAAA': 0.40829183057968743,
#  'GCAAC': 0.3913078231048574,
#  'GCAAG': 0.396703897050475,
#  'GCAAT': 0.4136642549248453,
#  'GCACA': 0.40509133802373676,
#  'GCACC': 0.40185489962966087,
#  'GCACG': 0.43240902216923527,
#  'GCACT': 0.4032744613463721,
#  'GCAGA': 0.41273890719954465,
#  'GCAGC': 0.40392002804877686,
#  'GCAGG': 0.41070144245979073,
#  'GCAGT': 0.39538820115718304,
#  'GCATA': 0.4052763898623757,
#  'GCATC': 0.3912083888710235,
#  'GCATG': 0.40173317970305644,
#  'GCATT': 0.4018987351360647,
#  'GCCAA': 0.4033293774540165,
#  'GCCAC': 0.40550616927072697,
#  'GCCAG': 0.40368108528832763,
#  'GCCAT': 0.4034139698098138,
#  'GCCCA': 0.39636402112606745,
#  'GCCCC': 0.3822838382868982,
#  'GCCCG': 0.38641340204884833,
#  'GCCCT': 0.40668083891547285,
#  'GCCGA': 0.39274290669355855,
#  'GCCGC': 0.4092938415131939,
#  'GCCGG': 0.38598513026261205,
#  'GCCGT': 0.40310706574524613,
#  'GCCTA': 0.39046327126672725,
#  'GCCTC': 0.39199460359822363,
#  'GCCTG': 0.401146936212415,
#  'GCCTT': 0.4062855131033584,
#  'GCGAA': 0.41172999373886354,
#  'GCGAC': 0.40646249797056655,
#  'GCGAG': 0.4047724568667564,
#  'GCGAT': 0.40547032087803275,
#  'GCGCA': 0.39860449584309027,
#  'GCGCC': 0.42819327006505953,
#  'GCGCG': 0.40203790409955353,
#  'GCGCT': 0.39191949588300246,
#  'GCGGA': 0.4228368397336091,
#  'GCGGC': 0.39633661473864895,
#  'GCGGG': 0.4183817115266452,
#  'GCGGT': 0.4146382269040277,
#  'GCGTA': 0.40516510777945935,
#  'GCGTC': 0.405734333438328,
#  'GCGTG': 0.4200648643419435,
#  'GCGTT': 0.4000897587595208,
#  'GCTAA': 0.3925775006758807,
#  'GCTAC': 0.4051463129941095,
#  'GCTAG': 0.40238080586222574,
#  'GCTAT': 0.4086816686133286,
#  'GCTCA': 0.39801977019053014,
#  'GCTCC': 0.4104596126024732,
#  'GCTCG': 0.4271764946173893,
#  'GCTCT': 0.39743808885978865,
#  'GCTGA': 0.3985750394731752,
#  'GCTGC': 0.4015238506297351,
#  'GCTGG': 0.4042152957106359,
#  'GCTGT': 0.4119251374462215,
#  'GCTTA': 0.40186417331351526,
#  'GCTTC': 0.39632578629947424,
#  'GCTTG': 0.40099769218443476,
#  'GCTTT': 0.4056146000337378,
#  'GGAAA': 0.406308830495982,
#  'GGAAC': 0.3989462900404623,
#  'GGAAG': 0.4056818341242616,
#  'GGAAT': 0.3994566017283123,
#  'GGACA': 0.4043400336603865,
#  'GGACC': 0.41284291884967805,
#  'GGACG': 0.3894479185022749,
#  'GGACT': 0.3964584372378737,
#  'GGAGA': 0.4089082368308426,
#  'GGAGC': 0.4088130161691017,
#  'GGAGG': 0.398460115029147,
#  'GGAGT': 0.40081230949647295,
#  'GGATA': 0.4050971169801252,
#  'GGATC': 0.3989024449527936,
#  'GGATG': 0.4089804136789467,
#  'GGATT': 0.39888464656589345,
#  'GGCAA': 0.4074989549814678,
#  'GGCAC': 0.42009525240989826,
#  'GGCAG': 0.4168923889138291,
#  'GGCAT': 0.3968207705064861,
#  'GGCCA': 0.401262341465536,
#  'GGCCC': 0.41469919716138764,
#  'GGCCG': 0.39292421579602077,
#  'GGCCT': 0.39732146839712823,
#  'GGCGA': 0.3992789600777499,
#  'GGCGC': 0.3889471242009965,
#  'GGCGG': 0.40375161792363135,
#  'GGCGT': 0.40855983444863075,
#  'GGCTA': 0.413854960038891,
#  'GGCTC': 0.40409559715447824,
#  'GGCTG': 0.3980384015313324,
#  'GGCTT': 0.4118564163471271,
#  'GGGAA': 0.4089812733496601,
#  'GGGAC': 0.39673140446596356,
#  'GGGAG': 0.3899300147637721,
#  'GGGAT': 0.4170539274461846,
#  'GGGCA': 0.3945339966083327,
#  'GGGCC': 0.408400343416774,
#  'GGGCG': 0.4230955713222449,
#  'GGGCT': 0.4121821923583659,
#  'GGGGA': 0.41440146323339444,
#  'GGGGC': 0.40615216068202464,
#  'GGGGG': 0.4075531153462588,
#  'GGGGT': 0.4005588010829494,
#  'GGGTA': 0.3920722505309249,
#  'GGGTC': 0.407106048079146,
#  'GGGTG': 0.4025913672213474,
#  'GGGTT': 0.3990885548127473,
#  'GGTAA': 0.4009353638567304,
#  'GGTAC': 0.4064529140717849,
#  'GGTAG': 0.40471629406601584,
#  'GGTAT': 0.4020197860142139,
#  'GGTCA': 0.40341473234747754,
#  'GGTCC': 0.39924816050208983,
#  'GGTCG': 0.4012982110506268,
#  'GGTCT': 0.39469920558455285,
#  'GGTGA': 0.4019847373336576,
#  'GGTGC': 0.39344740851259263,
#  'GGTGG': 0.41836588665074725,
#  'GGTGT': 0.4239391592850301,
#  'GGTTA': 0.40863591977125624,
#  'GGTTC': 0.3949261752188855,
#  'GGTTG': 0.4087533198819523,
#  'GGTTT': 0.412981819102619,
#  'GTAAA': 0.4037466539061368,
#  'GTAAC': 0.3915525129566821,
#  'GTAAG': 0.4033877368502277,
#  'GTAAT': 0.4022163579939253,
#  'GTACA': 0.40493833464369855,
#  'GTACC': 0.4061929144135548,
#  'GTACG': 0.40260886793842526,
#  'GTACT': 0.4068917297001634,
#  'GTAGA': 0.40597398390903927,
#  'GTAGC': 0.4058990392609314,
#  'GTAGG': 0.40913229530627654,
#  'GTAGT': 0.40428081922232545,
#  'GTATA': 0.4049485691470595,
#  'GTATC': 0.4047624090194703,
#  'GTATG': 0.40959851702888855,
#  'GTATT': 0.40265334033776007,
#  'GTCAA': 0.40481871316019796,
#  'GTCAC': 0.4025214747312559,
#  'GTCAG': 0.40987388021851956,
#  'GTCAT': 0.40065613304743336,
#  'GTCCA': 0.4121807640815919,
#  'GTCCC': 0.39350853230574373,
#  'GTCCG': 0.3813692710913261,
#  'GTCCT': 0.3970542222503508,
#  'GTCGA': 0.4010389753103064,
#  'GTCGC': 0.4087674702785983,
#  'GTCGG': 0.41195528840647544,
#  'GTCGT': 0.4022047111252484,
#  'GTCTA': 0.40412837671677826,
#  'GTCTC': 0.4147393975839568,
#  'GTCTG': 0.40216165210295574,
#  'GTCTT': 0.398139218361215,
#  'GTGAA': 0.40848159473001283,
#  'GTGAC': 0.40150766908506863,
#  'GTGAG': 0.38535845378623607,
#  'GTGAT': 0.40767878164105165,
#  'GTGCA': 0.4174739305756153,
#  'GTGCC': 0.39224875970379064,
#  'GTGCG': 0.41004282457267843,
#  'GTGCT': 0.3925528639824137,
#  'GTGGA': 0.4023924760353754,
#  'GTGGC': 0.4120176151840654,
#  'GTGGG': 0.4119989783166263,
#  'GTGGT': 0.4048744307881627,
#  'GTGTA': 0.4122278930533535,
#  'GTGTC': 0.41983249700700204,
#  'GTGTG': 0.40736696313309906,
#  'GTGTT': 0.4088722693494772,
#  'GTTAA': 0.4039315456243686,
#  'GTTAC': 0.4018090498159511,
#  'GTTAG': 0.4166456355794424,
#  'GTTAT': 0.40418017469634643,
#  'GTTCA': 0.4050711765667386,
#  'GTTCC': 0.40166397679064425,
#  'GTTCG': 0.39471411832500536,
#  'GTTCT': 0.3989842765467105,
#  'GTTGA': 0.39905875418796277,
#  'GTTGC': 0.4009276426325427,
#  'GTTGG': 0.40570955358762545,
#  'GTTGT': 0.4026385788395407,
#  'GTTTA': 0.40490450639275066,
#  'GTTTC': 0.4105015043105023,
#  'GTTTG': 0.4031732814984568,
#  'GTTTT': 0.40585883247611615,
#  'TAAAA': 0.4056426871400353,
#  'TAAAC': 0.4070138668734279,
#  'TAAAG': 0.40368396663903516,
#  'TAAAT': 0.39924799395332544,
#  'TAACA': 0.4068493218681452,
#  'TAACC': 0.4072478339563979,
#  'TAACG': 0.39505231714457784,
#  'TAACT': 0.4006563507121515,
#  'TAAGA': 0.3989730649701106,
#  'TAAGC': 0.40530673807478,
#  'TAAGG': 0.4061286741915164,
#  'TAAGT': 0.4008329411981633,
#  'TAATA': 0.4047250438374694,
#  'TAATC': 0.4025429276906518,
#  'TAATG': 0.4015760789739285,
#  'TAATT': 0.39454497883703,
#  'TACAA': 0.40399822584878287,
#  'TACAC': 0.3952223527121643,
#  'TACAG': 0.40488813774449667,
#  'TACAT': 0.4192776321589546,
#  'TACCA': 0.4102919378771731,
#  'TACCC': 0.40212710424436693,
#  'TACCG': 0.4005597463870634,
#  'TACCT': 0.4026842332433129,
#  'TACGA': 0.4113658619431663,
#  'TACGC': 0.40545117846710366,
#  'TACGG': 0.40636097737511934,
#  'TACGT': 0.39911682743892263,
#  'TACTA': 0.39315770600097194,
#  'TACTC': 0.39855665480199687,
#  'TACTG': 0.4056503599269939,
#  'TACTT': 0.40308025143194026,
#  'TAGAA': 0.4046639410501997,
#  'TAGAC': 0.4092895506423668,
#  'TAGAG': 0.39571576450325774,
#  'TAGAT': 0.4058259699018201,
#  'TAGCA': 0.4039016995221502,
#  'TAGCC': 0.4038509855267384,
#  'TAGCG': 0.40683807277376366,
#  'TAGCT': 0.40601388271014616,
#  'TAGGA': 0.41230427673746245,
#  'TAGGC': 0.410262509530989,
#  'TAGGG': 0.3978333961141363,
#  'TAGGT': 0.4060447911435331,
#  'TAGTA': 0.3947607769442951,
#  'TAGTC': 0.41190269732384505,
#  'TAGTG': 0.40699282175845064,
#  'TAGTT': 0.40486772489970957,
#  'TATAA': 0.41100693954672307,
#  'TATAC': 0.39869314371820036,
#  'TATAG': 0.4046087096031886,
#  'TATAT': 0.3990485354900636,
#  'TATCA': 0.3925057524861254,
#  'TATCC': 0.417802085469798,
#  'TATCG': 0.408955786989472,
#  'TATCT': 0.39824727100826995,
#  'TATGA': 0.3990647227958606,
#  'TATGC': 0.4107524920599502,
#  'TATGG': 0.4060188046731078,
#  'TATGT': 0.4035735235869837,
#  'TATTA': 0.40800948284972616,
#  'TATTC': 0.3997240483787156,
#  'TATTG': 0.39917505741585674,
#  'TATTT': 0.4059067993650406,
#  'TCAAA': 0.3996978831591424,
#  'TCAAC': 0.409380527768079,
#  'TCAAG': 0.39937237833708,
#  'TCAAT': 0.40453195654970087,
#  'TCACA': 0.4041726473091903,
#  'TCACC': 0.4066620389025387,
#  'TCACG': 0.4041718324962688,
#  'TCACT': 0.4004889953257264,
#  'TCAGA': 0.4001029275970981,
#  'TCAGC': 0.41333009090319517,
#  'TCAGG': 0.4063843787724312,
#  'TCAGT': 0.40598163323495984,
#  'TCATA': 0.41067353762582615,
#  'TCATC': 0.4048929712425434,
#  'TCATG': 0.3987639655612392,
#  'TCATT': 0.405256765457423,
#  'TCCAA': 0.4008702445385214,
#  'TCCAC': 0.39951487729884055,
#  'TCCAG': 0.4047178900816611,
#  'TCCAT': 0.40555689686352403,
#  'TCCCA': 0.4112346131017553,
#  'TCCCC': 0.4040152852803562,
#  'TCCCG': 0.416002890933092,
#  'TCCCT': 0.4050028629951701,
#  'TCCGA': 0.41629278289029015,
#  'TCCGC': 0.4089497761742509,
#  'TCCGG': 0.3787498396553898,
#  'TCCGT': 0.4119742970920481,
#  'TCCTA': 0.39582826711030006,
#  'TCCTC': 0.4101145943263073,
#  'TCCTG': 0.4041263198597286,
#  'TCCTT': 0.40518089570105764,
#  'TCGAA': 0.3985908786370303,
#  'TCGAC': 0.4011061576368146,
#  'TCGAG': 0.4097148571807056,
#  'TCGAT': 0.402875912974327,
#  'TGTAC': 0.4099279059686053,
#  'TGTAG': 0.4134663399785081,
#  'TGTAT': 0.4048991199209205,
#  'TGTCA': 0.4051456773448505,
#  'TGTCC': 0.40293673106589933,
#  'TGTCG': 0.40715245668696426,
#  'TGTCT': 0.4118112110666285,
#  'TGTGA': 0.4075146668533103,
#  'TGTGC': 0.4094977474742792,
#  'TGTGG': 0.4117350541817627,
#  'TGTGT': 0.40474410963474633,
#  'TGTTA': 0.4196401912403652,
#  'TGTTC': 0.39668461179365755,
#  'TGTTG': 0.4069968824061422,
#  'TGTTT': 0.4042857806735503,
#  'TTAAA': 0.4036111663229813,
#  'TTAAC': 0.39917454211957415,
#  'TTAAG': 0.4039291609406475,
#  'TTAAT': 0.4089933483417322,
#  'TTACA': 0.40883748675209736,
#  'TTACC': 0.40201574229297504,
#  'TTACG': 0.4167307902939429,
#  'TTACT': 0.4010858750208151,
#  'TTAGA': 0.40016634089033615,
#  'TTAGC': 0.40599927325572227,
#  'TTAGG': 0.39825673387089205,
#  'TTAGT': 0.4048590800898311,
#  'TTATA': 0.4056614688257315,
#  'TTATC': 0.39645291907434005,
#  'TTATG': 0.41102615856682984,
#  'TTATT': 0.40708630915333033,
#  'TTCAA': 0.40289488602289186,
#  'TTCAC': 0.41476953484748247,
#  'TTCAG': 0.39851577102200253,
#  'TTCAT': 0.39933507439334237,
#  'TTCCA': 0.40669670604631447,
#  'TTCCC': 0.4028091621282734,
#  'TTCCG': 0.4214834273834176,
#  'TTCCT': 0.40386993883161754,
#  'TTCGA': 0.4004685482432937,
#  'TTCGC': 0.39373425569811205,
#  'TTCGG': 0.4057956579502147,
#  'TTCGT': 0.4017132302049412,
#  'TTCTA': 0.3986891492254153,
#  'TTCTC': 0.39838916496228777,
#  'TTCTG': 0.4028171721069128,
#  'TTCTT': 0.40739093066272675,
#  'TTGAA': 0.40382040272324277,
#  'TTGAC': 0.40515111676557636,
#  'TTGAG': 0.39718438783767324,
#  'TTGAT': 0.40383713428157947,
#  'TTGCA': 0.4034793568285433,
#  'TTGCC': 0.394533407857411,
#  'TTGCG': 0.39853480674787645,
#  'TTGCT': 0.4068555300448352,
#  ...}

# %%
ordered_map_norm1
# Out:
# {'AAAAA': 0.427457450942973,
#  'AAAAC': 0.43484534447977724,
#  'AAAAG': 0.4362907902883212,
#  'AAAAT': 0.43407391785269267,
#  'AAACA': 0.43080971205630847,
#  'AAACC': 0.4328780505449838,
#  'AAACG': 0.4355764045413129,
#  'AAACT': 0.4358122983801609,
#  'AAAGA': 0.43010353634778864,
#  'AAAGC': 0.4290969086213846,
#  'AAAGG': 0.4342604155693839,
#  'AAAGT': 0.43334387174077527,
#  'AAATA': 0.43699174301060667,
#  'AAATC': 0.4335687834145319,
#  'AAATG': 0.4382686081216356,
#  'AAATT': 0.4332579222399284,
#  'AACAA': 0.43093781704891054,
#  'AACAC': 0.42881213356541625,
#  'AACAG': 0.4291412226786198,
#  'AACAT': 0.4324882728607364,
#  'AACCA': 0.4291358074531065,
#  'AACCC': 0.4329144773885217,
#  'AACCG': 0.42974780771490123,
#  'AACCT': 0.43966634571838126,
#  'AACGA': 0.43407180548822677,
#  'AACGC': 0.43195526499085757,
#  'AACGG': 0.4358083450018272,
#  'AACGT': 0.4297369976600702,
#  'AACTA': 0.4283138905947889,
#  'AACTC': 0.43435534172421125,
#  'AACTG': 0.42606646289128,
#  'AACTT': 0.4357780752641223,
#  'AAGAA': 0.43587686175706614,
#  'AAGAC': 0.4346740808358413,
#  'AAGAG': 0.42740498265449983,
#  'AAGAT': 0.4409203983037953,
#  'AAGCA': 0.43707298205471684,
#  'AAGCC': 0.42674861244914314,
#  'AAGCG': 0.4328927651962418,
#  'AAGCT': 0.4396750442149507,
#  'AAGGA': 0.43999643887952156,
#  'AAGGC': 0.42450839972226334,
#  'AAGGG': 0.4342631308796843,
#  'AAGGT': 0.4326434205375925,
#  'AAGTA': 0.4405523037343817,
#  'AAGTC': 0.4270309621609687,
#  'AAGTG': 0.42753419385063346,
#  'AAGTT': 0.4265903835694507,
#  'AATAA': 0.4335062303539672,
#  'AATAC': 0.4378690644019891,
#  'AATAG': 0.43141537978162453,
#  'AATAT': 0.43119049468475407,
#  'AATCA': 0.4348843301161451,
#  'AATCC': 0.4340678234597078,
#  'AATCG': 0.42803373896164026,
#  'AATCT': 0.4388770815264118,
#  'AATGA': 0.43140043842736775,
#  'AATGC': 0.4276750409493042,
#  'AATGG': 0.43193525912399683,
#  'AATGT': 0.42906755696784254,
#  'AATTA': 0.4350960845303179,
#  'AATTC': 0.42617168586344206,
#  'AATTG': 0.4377017638509923,
#  'AATTT': 0.4278351032936695,
#  'ACAAA': 0.4332889882034521,
#  'ACAAC': 0.4375337096089821,
#  'ACAAG': 0.4315295428757451,
#  'ACAAT': 0.43528124141822505,
#  'ACACA': 0.4294373063700362,
#  'ACACC': 0.4286379014277948,
#  'ACACG': 0.41549202011639413,
#  'ACACT': 0.4340524516558697,
#  'ACAGA': 0.4200863983384929,
#  'ACAGC': 0.43101605626771977,
#  'ACAGG': 0.4362566266479669,
#  'ACAGT': 0.44113821709017226,
#  'ACATA': 0.43410437113353467,
#  'ACATC': 0.42719631323217644,
#  'ACATG': 0.42415313236603097,
#  'ACATT': 0.43109758251509933,
#  'ACCAA': 0.43449497833404643,
#  'ACCAC': 0.4270013696124487,
#  'ACCAG': 0.4358713090188542,
#  'ACCAT': 0.4354337807228751,
#  'ACCCA': 0.44329048202493004,
#  'ACCCC': 0.4145233590822214,
#  'ACCCG': 0.4239931529663842,
#  'ACCCT': 0.4218099872213096,
#  'ACCGA': 0.424635150618483,
#  'ACCGC': 0.4263542115807558,
#  'ACCGG': 0.43390631795360357,
#  'ACCGT': 0.43857985185573545,
#  'ACCTA': 0.419219169680202,
#  'ACCTC': 0.4284909182487037,
#  'ACCTG': 0.42586594993447136,
#  'ACCTT': 0.43681263628741523,
#  'ACGAA': 0.4439359153289752,
#  'ACGAC': 0.4269958674010635,
#  'ACGAG': 0.4381848375470648,
#  'ACGAT': 0.435989615421072,
#  'ACGCA': 0.4359863510869077,
#  'ACGCC': 0.4507698942853789,
#  'ACGCG': 0.4369651592309501,
#  'ACGCT': 0.42166108514424466,
#  'ACGGA': 0.4086698340461456,
#  'ACGGC': 0.4366479525506015,
#  'ACGGG': 0.4306126081552242,
#  'ACGGT': 0.44045489677629335,
#  'ACGTA': 0.43316533968495285,
#  'ACGTC': 0.42057687833311064,
#  'ACGTG': 0.42384428814289393,
#  'ACGTT': 0.428541744115623,
#  'ACTAA': 0.42880884732092645,
#  'ACTAC': 0.4285492485671558,
#  'ACTAG': 0.42666743955580305,
#  'ACTAT': 0.4312552200637528,
#  'ACTCA': 0.43467694516276545,
#  'ACTCC': 0.4423410350703973,
#  'ACTCG': 0.42625171291451497,
#  'ACTCT': 0.43350058562993193,
#  'ACTGA': 0.43226841587967174,
#  'ACTGC': 0.42569452480037323,
#  'ACTGG': 0.43151159762724584,
#  'ACTGT': 0.4256890074315594,
#  'ACTTA': 0.4353312148686152,
#  'ACTTC': 0.43228957910201066,
#  'ACTTG': 0.44079140032499325,
#  'ACTTT': 0.43748989352760137,
#  'AGAAA': 0.4283950995760243,
#  'AGAAC': 0.43890175260569764,
#  'AGAAG': 0.43772117769346286,
#  'AGAAT': 0.4343096835516614,
#  'AGACA': 0.4303723184340337,
#  'AGACC': 0.42656343335645436,
#  'AGACG': 0.41306461517359866,
#  'AGACT': 0.4410442646550006,
#  'AGAGA': 0.4223274075161798,
#  'AGAGC': 0.42861185691710346,
#  'AGAGG': 0.42963198499995203,
#  'AGAGT': 0.4379070958116076,
#  'AGATA': 0.43366321484315773,
#  'AGATC': 0.41645399119017423,
#  'AGATG': 0.42977227930906736,
#  'AGATT': 0.4408543206772522,
#  'AGCAA': 0.438709761727281,
#  'AGCAC': 0.43912319554802826,
#  'AGCAG': 0.42866945506459125,
#  'AGCAT': 0.4366424179580324,
#  'AGCCA': 0.4237069445875792,
#  'AGCCC': 0.4300393963988696,
#  'AGCCG': 0.4279572212820183,
#  'AGCCT': 0.42610183398689516,
#  'AGCGA': 0.42889311801702723,
#  'AGCGC': 0.4213244273098167,
#  'AGCGG': 0.43305259294601783,
#  'AGCGT': 0.42713716834101867,
#  'AGCTA': 0.4485835936906159,
#  'AGCTC': 0.43829075835535247,
#  'AGCTG': 0.4344708199029471,
#  'AGCTT': 0.436914179284231,
#  'AGGAA': 0.4306471079649528,
#  'AGGAC': 0.4363440735130406,
#  'AGGAG': 0.43717002286275736,
#  'AGGAT': 0.42706116809544814,
#  'AGGCA': 0.4145094508812339,
#  'AGGCC': 0.4231770571715648,
#  'AGGCG': 0.4313806233752188,
#  'AGGCT': 0.418744452864095,
#  'AGGGA': 0.42187323630246454,
#  'AGGGC': 0.4386103165458364,
#  'AGGGG': 0.43096146898310034,
#  'AGGGT': 0.42810256280965414,
#  'AGGTA': 0.43224817973863455,
#  'AGGTC': 0.42799561985138695,
#  'AGGTG': 0.4260249925542894,
#  'AGGTT': 0.4351520443311707,
#  'AGTAA': 0.4292674581790564,
#  'AGTAC': 0.43480974721015153,
#  'AGTAG': 0.43269916462243346,
#  'AGTAT': 0.4348930661254106,
#  'AGTCA': 0.43185915353562926,
#  'AGTCC': 0.44785654499187283,
#  'AGTCG': 0.44176225719762285,
#  'AGTCT': 0.4241638811650162,
#  'AGTGA': 0.4298008196346104,
#  'AGTGC': 0.4360354574017834,
#  'AGTGG': 0.43235335719991114,
#  'AGTGT': 0.4338218581359034,
#  'AGTTA': 0.4296497927542085,
#  'AGTTC': 0.4302758124040505,
#  'AGTTG': 0.43582612406836047,
#  'AGTTT': 0.43389978717310757,
#  'ATAAA': 0.43808842607788995,
#  'ATAAC': 0.42559090391863563,
#  'ATAAG': 0.443283845514979,
#  'ATAAT': 0.43135104552781767,
#  'ATACA': 0.4314675035753011,
#  'ATACC': 0.43467575927829394,
#  'ATACG': 0.4332313047714186,
#  'ATACT': 0.43290615291418477,
#  'ATAGA': 0.4232433156639787,
#  'ATAGC': 0.429275196639838,
#  'ATAGG': 0.4280384548558468,
#  'ATAGT': 0.43361954485011,
#  'ATATA': 0.42933118563316525,
#  'ATATC': 0.4284178093820253,
#  'ATATG': 0.4276082587009098,
#  'ATATT': 0.4292689594275372,
#  'ATCAA': 0.4413322271540215,
#  'ATCAC': 0.4378344145376827,
#  'ATCAG': 0.43056873005320784,
#  'ATCAT': 0.44029902138815435,
#  'ATCCA': 0.43870139431849825,
#  'ATCCC': 0.4282551962406506,
#  'ATCCG': 0.4129784880906343,
#  'ATCCT': 0.4459400665990518,
#  'ATCGA': 0.42172114845925557,
#  'ATCGC': 0.4525422060688912,
#  'ATCGG': 0.4408230754141483,
#  'ATCGT': 0.4349302973733693,
#  'ATCTA': 0.43960651503039866,
#  'ATCTC': 0.4293205002526451,
#  'ATCTG': 0.4389166030908813,
#  'ATCTT': 0.4293615714462364,
#  'ATGAA': 0.426360503162625,
#  'ATGAC': 0.4293420468597697,
#  'ATGAG': 0.43754440854936405,
#  'ATGAT': 0.43225225105354764,
#  'ATGCA': 0.4290860093263189,
#  'ATGCC': 0.4346981281748671,
#  'ATGCG': 0.4285674191943897,
#  'ATGCT': 0.42410352479450575,
#  'ATGGA': 0.44023597283899096,
#  'ATGGC': 0.42970277109277216,
#  'ATGGG': 0.4356920319831493,
#  'ATGGT': 0.4383049657931752,
#  'ATGTA': 0.4386014914041356,
#  'ATGTC': 0.42793759903563344,
#  'ATGTG': 0.42963781101385123,
#  'ATGTT': 0.42748908834362426,
#  'ATTAA': 0.43928296358952373,
#  'ATTAC': 0.43440179927284023,
#  'ATTAG': 0.43097092950416344,
#  'ATTAT': 0.4388886842760712,
#  'ATTCA': 0.43613107700483794,
#  'ATTCC': 0.4248289849801394,
#  'ATTCG': 0.42863394465921295,
#  'ATTCT': 0.43144064937120596,
#  'ATTGA': 0.4357845395634978,
#  'ATTGC': 0.4241290018378112,
#  'ATTGG': 0.4366020848338676,
#  'ATTGT': 0.4357948686068943,
#  'ATTTA': 0.4332267498583348,
#  'ATTTC': 0.4265357058612851,
#  'ATTTG': 0.43645831065221957,
#  'ATTTT': 0.43175840983437513,
#  'CAAAA': 0.4411823021215683,
#  'CAAAC': 0.43639741008544225,
#  'CAAAG': 0.430262636923418,
#  'CAAAT': 0.4336363455242686,
#  'CAACA': 0.43151079551569366,
#  'CAACC': 0.42717969296416763,
#  'CAACG': 0.4359141162998369,
#  'CAACT': 0.42683481713971383,
#  'CAAGA': 0.4374717598464255,
#  'CAAGC': 0.44832220985478727,
#  'CAAGG': 0.44079762311088844,
#  'CAAGT': 0.42578791450665415,
#  'CAATA': 0.43054725955755196,
#  'CAATC': 0.4379231409411279,
#  'CAATG': 0.43395885681530155,
#  'CAATT': 0.4256465139499364,
#  'CACAA': 0.43064990193744085,
#  'CACAC': 0.42603910953081187,
#  'CACAG': 0.4310165090492688,
#  'CACAT': 0.43570602231399996,
#  'CACCA': 0.428853067400828,
#  'CACCC': 0.4166280143027721,
#  'CACCG': 0.44612739162165077,
#  'CACCT': 0.43372581600437504,
#  'CACGA': 0.4449022668335323,
#  'CACGC': 0.4305951440754055,
#  'CACGG': 0.42348026561876084,
#  'CACGT': 0.42258577585267276,
#  'CACTA': 0.4303172158025583,
#  'CACTC': 0.428289497985321,
#  'CACTG': 0.43119899578842164,
#  'CACTT': 0.43260733956592934,
#  'CAGAA': 0.42754664955782834,
#  'CAGAC': 0.419772310634269,
#  'CAGAG': 0.43251275550655266,
#  'CAGAT': 0.433404576792164,
#  'CAGCA': 0.43525088074069646,
#  'CAGCC': 0.41519216290603317,
#  'CAGCG': 0.4366411410210485,
#  'CAGCT': 0.44546620467849174,
#  'CAGGA': 0.4356003108716219,
#  'CAGGC': 0.43446290966072804,
#  'CAGGG': 0.43309181808166974,
#  'CAGGT': 0.4334176932433415,
#  'CAGTA': 0.431837409295326,
#  'CAGTC': 0.43269068728425275,
#  'CAGTG': 0.44306436292444334,
#  'CAGTT': 0.43637372603102403,
#  'CATAA': 0.4399635326327878,
#  'CATAC': 0.4346429295928099,
#  'CATAG': 0.444612250255581,
#  'CATAT': 0.4237557758034603,
#  'CATCA': 0.43305730524472635,
#  'CATCC': 0.4396246699427524,
#  'CATCG': 0.4419658309118435,
#  'CATCT': 0.43971473415179146,
#  'CATGA': 0.42220057433756936,
#  'CATGC': 0.4269812990906424,
#  'CATGG': 0.4301663170247451,
#  'CATGT': 0.4378085433957619,
#  'CATTA': 0.4279521365952794,
#  'CATTC': 0.42852105076791464,
#  'CATTG': 0.4302123577407817,
#  'CATTT': 0.43591081384703406,
#  'CCAAA': 0.4347172543330598,
#  'CCAAC': 0.4339921403848256,
#  'CCAAG': 0.43850407350049997,
#  'CCAAT': 0.43862521202606153,
#  'CCACA': 0.4304355594507525,
#  'CCACC': 0.43148530027310045,
#  'CCACG': 0.4269965106531615,
#  'CCACT': 0.4331872277392859,
#  'CCAGA': 0.4366923751603828,
#  'CCAGC': 0.441287086044364,
#  'CCAGG': 0.42963363966683094,
#  'CCAGT': 0.4441318538996414,
#  'CCATA': 0.42891122196384723,
#  'CCATC': 0.4353541505304146,
#  'CCATG': 0.4388992352722545,
#  'CCATT': 0.4333625781418954,
#  'CCCAA': 0.44084909530112065,
#  'CCCAC': 0.4179217965691757,
#  'CCCAG': 0.43574786878163707,
#  'CCCAT': 0.42832378925834874,
#  'CCCCA': 0.4334867795384339,
#  'CCCCC': 0.4300413908317419,
#  'CCCCG': 0.4108501787221699,
#  'CCCCT': 0.43755370004961797,
#  'CCCGA': 0.4242970232833841,
#  'CCCGC': 0.42478866630540857,
#  'CCCGG': 0.44614752583696066,
#  'CCCGT': 0.4241010092592163,
#  'CCCTA': 0.43456352675185567,
#  'CCCTC': 0.4452109913905396,
#  'CCCTG': 0.4341005052410574,
#  'CCCTT': 0.44072458437561923,
#  'CCGAA': 0.42210878614904485,
#  'CCGAC': 0.43871954679942166,
#  'CCGAG': 0.43067908666149946,
#  'CCGAT': 0.42268281764936905,
#  'CCGCA': 0.4498527803157041,
#  'CCGCC': 0.44860150867220744,
#  'CCGCG': 0.4096791677934326,
#  'CCGCT': 0.43697631989072727,
#  'CCGGA': 0.44506651823405036,
#  'CCGGC': 0.4267553266784494,
#  'CCGGG': 0.44659316308330294,
#  'CCGGT': 0.4306257378715111,
#  'CCGTA': 0.4448221377523163,
#  'CCGTC': 0.4312996390078944,
#  'CCGTG': 0.4147886600374882,
#  'CCGTT': 0.42659191705352606,
#  'CCTAA': 0.420622544517947,
#  'CCTAC': 0.44077153587721113,
#  'CCTAG': 0.44300764004428217,
#  'CCTAT': 0.43481579179649377,
#  'CCTCA': 0.44435843378827633,
#  'CCTCC': 0.445944327419625,
#  'CCTCG': 0.4144159234905741,
#  'CCTCT': 0.4348142917650842,
#  'CCTGA': 0.4268343726179326,
#  'CCTGC': 0.4297430901917568,
#  'CCTGG': 0.43809909674267006,
#  'CCTGT': 0.42184611991617627,
#  'CCTTA': 0.4339703433486967,
#  'CCTTC': 0.42939047489881166,
#  'CCTTG': 0.4388676910961569,
#  'CCTTT': 0.43521131272663927,
#  'CGAAA': 0.43541340663422007,
#  'CGAAC': 0.4213814373049216,
#  'CGAAG': 0.4304139250812054,
#  'CGAAT': 0.4356632818734729,
#  'CGACA': 0.4329072536100266,
#  'CGACC': 0.42320621523225027,
#  'CGACG': 0.44186832468033344,
#  'CGACT': 0.43756464582443166,
#  'CGAGA': 0.42821920990103235,
#  'CGAGC': 0.45031811320561543,
#  'CGAGG': 0.4398479005696939,
#  'CGAGT': 0.44389913501734546,
#  'CGATA': 0.43462462957149695,
#  'CGATC': 0.43166546010607093,
#  'CGATG': 0.43210868626031945,
#  'CGATT': 0.446074447717447,
#  'CGCAA': 0.43680202650371824,
#  'CGCAC': 0.415467303664466,
#  'CGCAG': 0.43676991692134365,
#  'CGCAT': 0.4242432788501147,
#  'CGCCA': 0.42500811079544754,
#  'CGCCC': 0.43909816836218496,
#  'CGCCG': 0.4508624280032467,
#  'CGCCT': 0.42443489059499473,
#  'CGCGA': 0.42844179981363684,
#  'CGCGC': 0.41756784333878266,
#  'CGCGG': 0.4583266381807873,
#  'CGCGT': 0.4275502842193555,
#  'CGCTA': 0.4461013664232234,
#  'CGCTC': 0.43083619019443375,
#  'CGCTG': 0.42482066081908226,
#  'CGCTT': 0.42936177909032114,
#  'CGGAA': 0.4298316791160709,
#  'CGGAC': 0.4252550344987306,
#  'CGGAG': 0.4470093867041682,
#  'CGGAT': 0.43020749634770467,
#  'CGGCA': 0.4394160975913129,
#  'CGGCC': 0.43339786476855535,
#  'CGGCG': 0.4349510734036847,
#  'CGGCT': 0.4345952905162539,
#  'CGGGA': 0.455436604459942,
#  'CGGGC': 0.4380115554653303,
#  'CGGGG': 0.4411618163448784,
#  'CGGGT': 0.4371908567117969,
#  'CGGTA': 0.4219022526664276,
#  'CGGTC': 0.43720791903752776,
#  'CGGTG': 0.4257968617756231,
#  'CGGTT': 0.43869617399404803,
#  'CGTAA': 0.4272285448821953,
#  'CGTAC': 0.43622556300093734,
#  'CGTAG': 0.44865298578389895,
#  'CGTAT': 0.43434245272111743,
#  'CGTCA': 0.4385947714578996,
#  'CGTCC': 0.4322156083558607,
#  'CGTCG': 0.40453342437249856,
#  'CGTCT': 0.4230993569155776,
#  'CGTGA': 0.41780911304071205,
#  'CGTGC': 0.42041221753584923,
#  'CGTGG': 0.4245319176911565,
#  'CGTGT': 0.4315522983016856,
#  'CGTTA': 0.4342222479094531,
#  'CGTTC': 0.4229284744041773,
#  'CGTTG': 0.4333695107348742,
#  'CGTTT': 0.4352042287006749,
#  'CTAAA': 0.4289091858579761,
#  'CTAAC': 0.4266833316836245,
#  'CTAAG': 0.43025605276245193,
#  'CTAAT': 0.44010576365969634,
#  'CTACA': 0.4288187502713098,
#  'CTACC': 0.4332803904545388,
#  'CTACG': 0.43942535732756177,
#  'CTACT': 0.4306144842670564,
#  'CTAGA': 0.42913958785920836,
#  'CTAGC': 0.4293828150924088,
#  'CTAGG': 0.42355916773749774,
#  'CTAGT': 0.4318195566542143,
#  'CTATA': 0.4425053892539759,
#  'CTATC': 0.4344361093292148,
#  'CTATG': 0.43088893660638555,
#  'CTATT': 0.4353361124705227,
#  'CTCAA': 0.4395948188530527,
#  'CTCAC': 0.4390373981181457,
#  'CTCAG': 0.4348740518360171,
#  'CTCAT': 0.45227582113395254,
#  'CTCCA': 0.4411026692585473,
#  'CTCCC': 0.4236303235803243,
#  'CTCCG': 0.44158030593137443,
#  'CTCCT': 0.4436813202153939,
#  'CTCGA': 0.43212731801415843,
#  'CTCGC': 0.4094035616256933,
#  'CTCGG': 0.4381446536473152,
#  'CTCGT': 0.4408394498170439,
#  'CTCTA': 0.4328755068233785,
#  'CTCTC': 0.43648640364114355,
#  'CTCTG': 0.42935681984703605,
#  'CTCTT': 0.43741574260772575,
#  'CTGAA': 0.42548566442933905,
#  'CTGAC': 0.42861664887783435,
#  'CTGAG': 0.4326698966399033,
#  'CTGAT': 0.42886647941171807,
#  'CTGCA': 0.4178868607135977,
#  'CTGCC': 0.43250201540468364,
#  'CTGCG': 0.4215476680203059,
#  'CTGCT': 0.43404299570293475,
#  'CTGGA': 0.43640613007783036,
#  'CTGGC': 0.4383806487948569,
#  'CTGGG': 0.41920585893272755,
#  'CTGGT': 0.43116611403333516,
#  'CTGTA': 0.43141253475407965,
#  'CTGTC': 0.4218650257198635,
#  'CTGTG': 0.4222980848268247,
#  'CTGTT': 0.42620259906357194,
#  'CTTAA': 0.4293501649982617,
#  'CTTAC': 0.42270700395624394,
#  'CTTAG': 0.4314352888882184,
#  'CTTAT': 0.42850046609969034,
#  'CTTCA': 0.4289236110716046,
#  'CTTCC': 0.45030593410313197,
#  'CTTCG': 0.45405522019132377,
#  'CTTCT': 0.43624772436406317,
#  'CTTGA': 0.43963101987562225,
#  'CTTGC': 0.43414080273891015,
#  'CTTGG': 0.43122553076527687,
#  'CTTGT': 0.43567532455533214,
#  'CTTTA': 0.43228074588275606,
#  'CTTTC': 0.42579390053723126,
#  'CTTTG': 0.43254151620178627,
#  'CTTTT': 0.4384937944953476,
#  'GAAAA': 0.42869102590334185,
#  'GAAAC': 0.42826850838542996,
#  'GAAAG': 0.425198561816075,
#  'GAAAT': 0.42949951090921157,
#  'GAACA': 0.4284605748890279,
#  'GAACC': 0.42461544751857,
#  'GAACG': 0.44961996838561,
#  'GAACT': 0.42833938156438783,
#  'GAAGA': 0.433814282305741,
#  'GAAGC': 0.43362787413182546,
#  'GAAGG': 0.4361705387784828,
#  'GAAGT': 0.42770400746352677,
#  'GAATA': 0.4338222843188444,
#  'GAATC': 0.4274616166024786,
#  'GAATG': 0.4295744592244779,
#  'GAATT': 0.4222123625008689,
#  'GACAA': 0.4310789790399869,
#  'GACAC': 0.4287001021853454,
#  'GACAG': 0.43071169915632196,
#  'GACAT': 0.43214359269204905,
#  'GACCA': 0.42911219514494237,
#  'GACCC': 0.43323440181326955,
#  'GACCG': 0.43949724268876594,
#  'GACCT': 0.4364783577076597,
#  'GACGA': 0.4322141981595564,
#  'GACGC': 0.424829282777389,
#  'GACGG': 0.4358240180459295,
#  'GACGT': 0.43763314603792486,
#  'GACTA': 0.438029385303336,
#  'GACTC': 0.43482370434058953,
#  'GACTG': 0.45166473855906547,
#  'GACTT': 0.4399464812671404,
#  'GAGAA': 0.4375557981750907,
#  'GAGAC': 0.41870937361711774,
#  'GAGAG': 0.4308864568462265,
#  'GAGAT': 0.42842525066186754,
#  'GAGCA': 0.44258922592177036,
#  'GAGCC': 0.4315684131850438,
#  'GAGCG': 0.4282782937113727,
#  'GAGCT': 0.4287803473666271,
#  'GAGGA': 0.4316378630416365,
#  'GAGGC': 0.43129332464166525,
#  'GAGGG': 0.4195978880161288,
#  'GAGGT': 0.4346448827092128,
#  'GAGTA': 0.4300452682313194,
#  'GAGTC': 0.4506042094343501,
#  'GAGTG': 0.4434645817874352,
#  'GAGTT': 0.4324873359356779,
#  'GATAA': 0.4306007727292248,
#  'GATAC': 0.4280526590073564,
#  'GATAG': 0.4417415055618897,
#  'GATAT': 0.4204014372295782,
#  'GATCA': 0.4399580551080098,
#  'GATCC': 0.4213787538886881,
#  'GATCG': 0.4253348757471881,
#  'GATCT': 0.42448854094374533,
#  'GATGA': 0.4347033089508144,
#  'GATGC': 0.43335663817594366,
#  'GATGG': 0.42961365974863147,
#  'GATGT': 0.43260356550106877,
#  'GATTA': 0.44580351065741475,
#  'GATTC': 0.44571172203133097,
#  'GATTG': 0.4426238386956097,
#  'GATTT': 0.4369181086345908,
#  'GCAAA': 0.43351782278050793,
#  'GCAAC': 0.4246204702031317,
#  'GCAAG': 0.43096092050435564,
#  'GCAAT': 0.4298669723932433,
#  'GCACA': 0.42483637336640184,
#  'GCACC': 0.42518521445613,
#  'GCACG': 0.4056459090131441,
#  'GCACT': 0.4346581004851032,
#  'GCAGA': 0.4354508850663255,
#  'GCAGC': 0.4279335091697652,
#  'GCAGG': 0.4421766603185444,
#  'GCAGT': 0.43663761445654053,
#  'GCATA': 0.43716773103755197,
#  'GCATC': 0.4429074476267278,
#  'GCATG': 0.4190491880036251,
#  'GCATT': 0.42653613324872347,
#  'GCCAA': 0.43806694127460344,
#  'GCCAC': 0.4361378624202589,
#  'GCCAG': 0.42955140248873086,
#  'GCCAT': 0.43136708086906067,
#  'GCCCA': 0.42649043609777665,
#  'GCCCC': 0.4316550263210254,
#  'GCCCG': 0.44692071858934407,
#  'GCCCT': 0.44178390850207744,
#  'GCCGA': 0.4299571589586667,
#  'GCCGC': 0.4578470043392816,
#  'GCCGG': 0.4239380760677096,
#  'GCCGT': 0.4417638596081918,
#  'GCCTA': 0.4429772089211812,
#  'GCCTC': 0.4294448686882448,
#  'GCCTG': 0.4261994395441236,
#  'GCCTT': 0.44139599748491143,
#  'GCGAA': 0.42240694570754744,
#  'GCGAC': 0.4436725760359011,
#  'GCGAG': 0.4320134686086772,
#  'GCGAT': 0.43793170355898914,
#  'GCGCA': 0.4166125461112895,
#  'GCGCC': 0.4399752215245366,
#  'GCGCG': 0.4372568913586368,
#  'GCGCT': 0.4369620023340489,
#  'GCGGA': 0.4462574566903782,
#  'GCGGC': 0.43152218338546994,
#  'GCGGG': 0.4417357109983467,
#  'GCGGT': 0.42384729645119107,
#  'GCGTA': 0.4526805350553,
#  'GCGTC': 0.41915766954068295,
#  'GCGTG': 0.43876323214158325,
#  'GCGTT': 0.433402402364524,
#  'GCTAA': 0.43744900891743577,
#  'GCTAC': 0.4217103212500811,
#  'GCTAG': 0.4325080850099687,
#  'GCTAT': 0.44171504549690854,
#  'GCTCA': 0.42633556640743897,
#  'GCTCC': 0.4488341179957493,
#  'GCTCG': 0.4479116072510923,
#  'GCTCT': 0.44066047846032946,
#  'GCTGA': 0.43780888841421584,
#  'GCTGC': 0.44313755132879606,
#  'GCTGG': 0.4306932308763241,
#  'GCTGT': 0.41871657266503376,
#  'GCTTA': 0.42811213177849905,
#  'GCTTC': 0.444844272935773,
#  'GCTTG': 0.43765515788656195,
#  'GCTTT': 0.4285297906040124,
#  'GGAAA': 0.4267233515193642,
#  'GGAAC': 0.42927042556004236,
#  'GGAAG': 0.43112231649428856,
#  'GGAAT': 0.43455955994175816,
#  'GGACA': 0.44029440741455944,
#  'GGACC': 0.4512777086619809,
#  'GGACG': 0.4452991704433311,
#  'GGACT': 0.4323225220984231,
#  'GGAGA': 0.43320859104720544,
#  'GGAGC': 0.41797584223506895,
#  'GGAGG': 0.43290959050478134,
#  'GGAGT': 0.4413872861650047,
#  'GGATA': 0.42346174733943964,
#  'GGATC': 0.43450347163342823,
#  'GGATG': 0.4291572609711631,
#  'GGATT': 0.43639367687236036,
#  'GGCAA': 0.4295949452554786,
#  'GGCAC': 0.40809211914078036,
#  'GGCAG': 0.4322514194681287,
#  'GGCAT': 0.4239600513705343,
#  'GGCCA': 0.41991531836001544,
#  'GGCCC': 0.4502569503420063,
#  'GGCCG': 0.43184327313931586,
#  'GGCCT': 0.43320672698771606,
#  'GGCGA': 0.4256509557955399,
#  'GGCGC': 0.43580879376282816,
#  'GGCGG': 0.43684396234509126,
#  'GGCGT': 0.4313991386402879,
#  'GGCTA': 0.43327514679114565,
#  'GGCTC': 0.4290900607702182,
#  'GGCTG': 0.4352992353496511,
#  'GGCTT': 0.4201340864698261,
#  'GGGAA': 0.4368179475854638,
#  'GGGAC': 0.44400923581710616,
#  'GGGAG': 0.4365823602993212,
#  'GGGAT': 0.4240102165628988,
#  'GGGCA': 0.4283112640880352,
#  'GGGCC': 0.4326883941365156,
#  'GGGCG': 0.42757295905919107,
#  'GGGCT': 0.4266827901377245,
#  'GGGGA': 0.4323724348710675,
#  'GGGGC': 0.4253839043148753,
#  'GGGGG': 0.44031450072040984,
#  'GGGGT': 0.419509868754949,
#  'GGGTA': 0.44517860514703994,
#  'GGGTC': 0.4229806546166429,
#  'GGGTG': 0.42553779307561784,
#  'GGGTT': 0.4307579421452617,
#  'GGTAA': 0.43284422870717915,
#  'GGTAC': 0.4262842027209626,
#  'GGTAG': 0.4358145149657328,
#  'GGTAT': 0.4353688700518906,
#  'GGTCA': 0.4266882211791026,
#  'GGTCC': 0.4239334812203496,
#  'GGTCG': 0.4497263876779068,
#  'GGTCT': 0.4253898679945228,
#  'GGTGA': 0.4380344522903284,
#  'GGTGC': 0.42906952351872235,
#  'GGTGG': 0.42660608092932484,
#  'GGTGT': 0.43138203069008285,
#  'GGTTA': 0.4352026181783632,
#  'GGTTC': 0.4341051317379861,
#  'GGTTG': 0.42342298439783593,
#  'GGTTT': 0.4362248713849316,
#  'GTAAA': 0.43658441380951635,
#  'GTAAC': 0.43761029567278203,
#  'GTAAG': 0.42852822887565895,
#  'GTAAT': 0.4260394273946859,
#  'GTACA': 0.43960948354828255,
#  'GTACC': 0.4245484920764803,
#  'GTACG': 0.4293787538921099,
#  'GTACT': 0.43216626616808906,
#  'GTAGA': 0.4316594963489898,
#  'GTAGC': 0.4517646283545752,
#  'GTAGG': 0.4359431698545137,
#  'GTAGT': 0.4430235364415132,
#  'GTATA': 0.4332148639671247,
#  'GTATC': 0.4258839246921981,
#  'GTATG': 0.4361453516757799,
#  'GTATT': 0.43208685858890195,
#  'GTCAA': 0.44007344185108543,
#  'GTCAC': 0.42480356377518536,
#  'GTCAG': 0.4369517139107668,
#  'GTCAT': 0.43156926094023695,
#  'GTCCA': 0.44438248429320937,
#  'GTCCC': 0.42282594196968853,
#  'GTCCG': 0.4300165291221525,
#  'GTCCT': 0.43832921433043287,
#  'GTCGA': 0.43892952032712207,
#  'GTCGC': 0.4376203654390561,
#  'GTCGG': 0.44416285048246995,
#  'GTCGT': 0.42800715028916814,
#  'GTCTA': 0.4416503939729966,
#  'GTCTC': 0.4298589923313263,
#  'GTCTG': 0.4320972863132105,
#  'GTCTT': 0.4173837440180163,
#  'GTGAA': 0.41442324791367613,
#  'GTGAC': 0.43526439436848513,
#  'GTGAG': 0.4456342170702495,
#  'GTGAT': 0.43924833943669916,
#  'GTGCA': 0.42407243767171543,
#  'GTGCC': 0.4403015162728609,
#  'GTGCG': 0.41273186230850806,
#  'GTGCT': 0.4332900983381881,
#  'GTGGA': 0.4343781245203733,
#  'GTGGC': 0.4269692885708808,
#  'GTGGG': 0.4483209707422153,
#  'GTGGT': 0.42342467042912374,
#  'GTGTA': 0.4150794023299781,
#  'GTGTC': 0.4367447197887303,
#  'GTGTG': 0.42834753756109545,
#  'GTGTT': 0.42840211604649525,
#  'GTTAA': 0.4331881520759904,
#  'GTTAC': 0.42889223090386597,
#  'GTTAG': 0.4310541649248732,
#  'GTTAT': 0.4273743085056006,
#  'GTTCA': 0.4329811017002,
#  'GTTCC': 0.4400846158230103,
#  'GTTCG': 0.4183978540567621,
#  'GTTCT': 0.43831777892959417,
#  'GTTGA': 0.4331363099977631,
#  'GTTGC': 0.43529730556147433,
#  'GTTGG': 0.4209939361625908,
#  'GTTGT': 0.4253298242251099,
#  'GTTTA': 0.4311466471493652,
#  'GTTTC': 0.43083888472365156,
#  'GTTTG': 0.4431388758260435,
#  'GTTTT': 0.4347527259962426,
#  'TAAAA': 0.4322326528413067,
#  'TAAAC': 0.4272883172527225,
#  'TAAAG': 0.43221666056577823,
#  'TAAAT': 0.4367564287751626,
#  'TAACA': 0.43433250669055795,
#  'TAACC': 0.4362240849194057,
#  'TAACG': 0.42754602395661834,
#  'TAACT': 0.4327974721421451,
#  'TAAGA': 0.4346063644307414,
#  'TAAGC': 0.4260565072065518,
#  'TAAGG': 0.43845034136183303,
#  'TAAGT': 0.4374836612205088,
#  'TAATA': 0.43033142393021356,
#  'TAATC': 0.43732193644167877,
#  'TAATG': 0.42689867094615125,
#  'TAATT': 0.4307624555433342,
#  'TACAA': 0.4300150521018786,
#  'TACAC': 0.4220040287235531,
#  'TACAG': 0.428650452979127,
#  'TACAT': 0.4276535030480293,
#  'TACCA': 0.4396877976628198,
#  'TACCC': 0.4300230202193916,
#  'TACCG': 0.4263438380700204,
#  'TACCT': 0.4204802103070971,
#  'TACGA': 0.42606768993587013,
#  'TACGC': 0.43001476137931927,
#  'TACGG': 0.434226354705264,
#  'TACGT': 0.4283480016183554,
#  'TACTA': 0.4280762055962304,
#  'TACTC': 0.4336633379494487,
#  'TACTG': 0.4342322657434481,
#  'TACTT': 0.4289802005273129,
#  'TAGAA': 0.43776343849965993,
#  'TAGAC': 0.4304477763296508,
#  'TAGAG': 0.43326179862242864,
#  'TAGAT': 0.42744609386833754,
#  'TAGCA': 0.4329315846472715,
#  'TAGCC': 0.43442634109931194,
#  'TAGCG': 0.42596529416396817,
#  'TAGCT': 0.4325807514348505,
#  'TAGGA': 0.42619461705596207,
#  'TAGGC': 0.426708439402731,
#  'TAGGG': 0.4348473961332756,
#  'TAGGT': 0.4329018240045331,
#  'TAGTA': 0.43548408989376747,
#  'TAGTC': 0.43683782944133476,
#  'TAGTG': 0.4276986749298335,
#  'TAGTT': 0.4372924362807399,
#  'TATAA': 0.4368150875917063,
#  'TATAC': 0.43177708425780853,
#  'TATAG': 0.427829167477943,
#  'TATAT': 0.43308727316053947,
#  'TATCA': 0.4325693765884598,
#  'TATCC': 0.43218808966215955,
#  'TATCG': 0.43340172064559523,
#  'TATCT': 0.43104728885071986,
#  'TATGA': 0.4301916105585708,
#  'TATGC': 0.4320256677465069,
#  'TATGG': 0.4269078271926817,
#  'TATGT': 0.42978714030994913,
#  'TATTA': 0.43757640693996214,
#  'TATTC': 0.4251424461676,
#  'TATTG': 0.4358922358863336,
#  'TATTT': 0.42980376977000995,
#  'TCAAA': 0.44084580787341204,
#  'TCAAC': 0.4288289775868731,
#  'TCAAG': 0.4381704334633402,
#  'TCAAT': 0.4324575685381921,
#  'TCACA': 0.4328023263218815,
#  'TCACC': 0.4292759200036674,
#  'TCACG': 0.4361171491548416,
#  'TCACT': 0.4431675518086577,
#  'TCAGA': 0.4314458292151688,
#  'TCAGC': 0.4385764924390005,
#  'TCAGG': 0.4305917141582398,
#  'TCAGT': 0.4242713977396702,
#  'TCATA': 0.4377440596769252,
#  'TCATC': 0.440008767943819,
#  'TCATG': 0.42677555608866746,
#  'TCATT': 0.4366622194269838,
#  'TCCAA': 0.43898868529325713,
#  'TCCAC': 0.43695609582084205,
#  'TCCAG': 0.4340316864326956,
#  'TCCAT': 0.43870752929075363,
#  'TCCCA': 0.42425929268778845,
#  'TCCCC': 0.426628461493666,
#  'TCCCG': 0.4386064370830581,
#  'TCCCT': 0.4226772708312004,
#  'TCCGA': 0.4419650385751179,
#  'TCCGC': 0.4265098166126689,
#  'TCCGG': 0.4261895619522165,
#  'TCCGT': 0.4160307262878054,
#  'TCCTA': 0.42982511280596003,
#  'TCCTC': 0.4382884036468657,
#  'TCCTG': 0.43139913123173634,
#  'TCCTT': 0.435019992610792,
#  'TCGAA': 0.42611250386094807,
#  'TCGAC': 0.4281996258834759,
#  'TCGAG': 0.4302415923115084,
#  'TCGAT': 0.4323552573197836,
#  'TCGCA': 0.43922106007372436,
#  'TCGCC': 0.4331087838691457,
#  'TCGCG': 0.44044383393027636,
#  'TCGCT': 0.43718175995363395,
#  'TCGGA': 0.43358553532804994,
#  'TCGGC': 0.4446687456745343,
#  'TCGGG': 0.42768998524031876,
#  'TCGGT': 0.43415236565022874,
#  'TGTGC': 0.43833640439592136,
#  'TGTGG': 0.4357822482990993,
#  'TGTGT': 0.4247109611232971,
#  'TGTTA': 0.4205115660857155,
#  'TGTTC': 0.43557709194870575,
#  'TGTTG': 0.4299728521751796,
#  'TGTTT': 0.4346986279417856,
#  'TTAAA': 0.44036520887159525,
#  'TTAAC': 0.43527513101865306,
#  'TTAAG': 0.4285188716054385,
#  'TTAAT': 0.43030963048449417,
#  'TTACA': 0.4217062860730885,
#  'TTACC': 0.4297799708170503,
#  'TTACG': 0.4255417300651806,
#  'TTACT': 0.4326092678040541,
#  'TTAGA': 0.4364265226555974,
#  'TTAGC': 0.4322261898911242,
#  'TTAGG': 0.432328991363229,
#  'TTAGT': 0.44143902850328975,
#  'TTATA': 0.4382825042065436,
#  'TTATC': 0.4357696764817133,
#  'TTATG': 0.42847375105482105,
#  'TTATT': 0.4318693831853753,
#  'TTCAA': 0.43298812507762546,
#  'TTCAC': 0.4391175359293383,
#  'TTCAG': 0.43123152183704744,
#  'TTCAT': 0.4344726529750513,
#  'TTCCA': 0.4285142900320521,
#  'TTCCC': 0.44158544279204165,
#  'TTCCG': 0.4375365399640431,
#  'TTCCT': 0.4277166176101636,
#  'TTCGA': 0.42297202328698785,
#  'TTCGC': 0.4418108774504802,
#  'TTCGG': 0.43829871191357855,
#  'TTCGT': 0.4375612212720261,
#  'TTCTA': 0.43328923438204686,
#  'TTCTC': 0.4342448355666346,
#  'TTCTG': 0.42595520911281176,
#  'TTCTT': 0.43472273515520166,
#  'TTGAA': 0.4334057374598685,
#  'TTGAC': 0.4335726092553911,
#  'TTGAG': 0.43299062352700063,
#  'TTGAT': 0.4365646266778515,
#  'TTGCA': 0.42274694434029325,
#  'TTGCC': 0.4264443101441011,
#  'TTGCG': 0.4374470380752037,
#  'TTGCT': 0.4359039643751025,
#  ...}

# %%
min(ordered_map_norm.values())
# Out:
# 0.07448837972641753

# %%
max(ordered_map_norm.values())
# Out:
# 1.21699637039396

# %%
AllDNAshape = ['Shear', 'Stretch', 'Stagger', 'Buckle', 'Propel', 'Opening', 
'Shift_-1', 'Shift_1', 'Slide_-1', 'Slide_1', 'Rise_-1', 'Rise_1',
            'Tilt_-1', 'Tilt_1', 
'Roll_-1', 'Roll_1', 'Twist_-1', 'Twist_1', 'mingw', 'mingd', 'majgw', 'majgd', 
'Shear-SD', 'Stretch-SD', 'Stagger-SD', 'Buckle-SD', 'Propel-SD', 'Opening-SD', 
'Shift-SD', 'Slide-SD', 'Rise-SD', 'Tilt-SD', 'Roll-SD', 'Twist-SD', 'mingw-SD', 
'mingd-SD', 'majgw-SD', 'majgd-SD']

All_params_names = ["intra_trans","intra_rot","inter_trans","inter_rot","GrooveWidth","intra_trans_SD","inter_trans_SD","intra_rot_SD","inter_rot_SD","GrooveWidth_SD"]

fileName = "/Users/yibeijia/Downloads/ProjectStuff/mc_pentamer_06042020.txt"
fileName = "/home/yibei/Projects/ProjectStuff/mc_pentamer_06042020.txt"
tb = read_SD_table(fileName);

# all_norm_shape_vals, all_shape_vals2 = shape_param_analysis(tb)
# print(len(all_norm_shape_vals))
len(tb.keys())
# Out:
# 512

# %%
################################### Correlation plots for reverse complements ###################################
def reverseCompPlot(map_to_plot, plot_name, annotation_x, annotation_y):
    import seaborn as sns
    import matplotlib.pyplot

    i=0
    five_mers = {}
    for k in map_to_plot.items():
        if k[0] in tb.keys(): #k[0] is not a reverse complement

            r = reverse_complement(k[0])
            values = [map_to_plot[k[0]], map_to_plot[r]] #first is 5mer, second is reverse complement value
            five_mers[k[0]] = values

    # Plot corr between 5mers and its reverse complements
    corr = pd.DataFrame.from_dict(five_mers,orient='index', columns=['five_mer', 'reverse_comp'])
    sns.set_theme(style="darkgrid")

    g = sns.lmplot(x="five_mer", y="reverse_comp",data=corr);

    plt.gcf().set_size_inches(10, 8)
    # plt.title("Attension Score Correlation: \n5-mers vs. Reverse Complements\nafter Normalization", fontsize=15)
    plt.xlabel("5-mers", fontsize=15);
    plt.ylabel("Reverse complement of 5-mers", fontsize=15);

    # Add person correlation annotation
    from scipy import stats
    num = stats.pearsonr(corr['five_mer'], corr['reverse_comp'])[0]
    text = "Pearson Correlation \n= " + f'{num:.5f}'

    plt.text(annotation_x, annotation_x, text, horizontalalignment='center', size='medium', color='black', weight='semibold')
    
    plt.tight_layout()
    plt.savefig( plot_name, dpi=200)

# %%
fig_path='/home/yibei/Projects/nucleosome_occupancy/figs/'
reverseCompPlot(ordered_map, fig_path + 'ordered_map_all.png', 100000, 12000)
reverseCompPlot(ordered_map_norm, fig_path + 'ordered_map_all_norm.png', 1.0, 1.0)

# %%
reverseCompPlot(ordered_map0, fig_path + 'ordered_map_0.png', 70000, 80000)
reverseCompPlot(ordered_map_norm0, fig_path + 'ordered_map_0_norm.png', 0.42, 0.4)

# %%
reverseCompPlot(ordered_map1, fig_path + 'ordered_map_1.png', 70000, 80000)
reverseCompPlot(ordered_map_norm1, fig_path + 'ordered_map_1_norm.png', 0.42, 0.4)

# %% [markdown]
# ## 1.2 Add reverse complement scores to 5mer scores

# %%
def addReversCompScores(attention_outputs):
    # if you are using batches the outputs will be in batches
    # get exact attentions of chars
    from IPython.display import display
    mapped_add = {}
    mapped_add0 = {}
    mapped_add1 = {}
    testmat = scipy.io.loadmat(data_folder+'Test_data.mat')
    d = testmat['Test_data']
    for seq in range(len(attention_outputs)):
    # for seq in range(1,5):

        # tokens are the 5mers in the current sequence
        tokens = tokenize(ReverseOneHotEncode(d[seq]))

        # for 147bp each sequence, there are 320 feature scores for each bp
        for i in range(len(tokens)):
            token = tokens[i]
            five_mer_attention_output = sum(attention_outputs[seq][i])
            if token in mapped_add.keys():  # if a 5mer is found
                mapped_add[token] = mapped_add[token] + five_mer_attention_output #increase value
                mapped_add[reverse_complement(token)] = mapped_add[token] #set the reverse compliement value to the same

            # if a 5mer's reverse complement is found
            elif reverse_complement(token) in mapped_add.keys():
                mapped_add[reverse_complement(token)] = mapped_add[reverse_complement(token)] + five_mer_attention_output
                mapped_add[token] = mapped_add[reverse_complement(token)] #set the original 5mer value to the same

            #if 5mer not seen yet
            else: 
                mapped_add[token] = five_mer_attention_output
                mapped_add[reverse_complement(token)] = mapped_add[token]
    #     char_df = plot_attention_from_seq(tokens, mapped[token])
    #     display(char_df)

    # Plot the mapped dictionary for each 5 mer; Darker means higher attention score
    import collections
    ordered_map_add = collections.OrderedDict(sorted(mapped_add.items()))
    # char_df = plot_attention_from_map(mapped_add)
    # display(char_df)
    # char_df = plot_attention_from_map(ordered_map_add)
    # display(char_df)
    return ordered_map_add

# %%
ordered_map_add = addReversCompScores(attention_outputs)
print("done")
ordered_map_add0 = addReversCompScores(attention_outputs0)
print("done1")
ordered_map_add1 = addReversCompScores(attention_outputs1)
print("done2")

# %%
# print(ordered_kmerCounts.keys())
def normKmerCount_addReverse(ordered_map, kmerCounts):
    ordered_map_add_norm = {}
    for k, _ in ordered_map.items():
        r = reverse_complement(k)
        v = ordered_map[k] / (kmerCounts[k] + kmerCounts[r])
        ordered_map_add_norm[k] = v
    return ordered_map_add_norm

# %%
ordered_map_add_norm = normKmerCount_addReverse(ordered_map_add, kmerCounts)
print(len(ordered_map_add_norm))
print(len(ordered_map_add))
ordered_map_add_norm0 = normKmerCount_addReverse(ordered_map_add0, kmerCounts0)
ordered_map_add_norm1 = normKmerCount_addReverse(ordered_map_add1, kmerCounts1)
# Out:
# 1024
# 1024

# %%
ordered_map_add0['ATATA']
# Out:
# 27799.40338486906

# %%
kmerCounts0['ATATA'] + kmerCounts0[reverse_complement('ATATA')]
# Out:
# 69188

# %%
ordered_map_add_norm0['ATATA']
# Out:
# 0.40179515790121206

# %%
ordered_map['CGCGC']
# Out:
# 1102.0354292728

# %%
ordered_map['ATATA']
# Out:
# 67960.42427976173

# %%
ordered_map['AAAAA']
# Out:
# 120505.95015182017

# %% [markdown]
# ## 3. Plot correlation for attention scores and DNA shape

# %%
################################### Correlation plots for DNA shape ###################################
import seaborn as sns
import matplotlib.pyplot

# use added reverse complement score way
attention_score = []
attention_score_norm = []

for k in tb.items(): # set values to the 5mer order as seen in tb
    attention_score.append(ordered_map_add[k[0]]) 
    attention_score_norm.append(ordered_map_add_norm[k[0]]) 
    
shape_df =  pd.DataFrame.from_dict(tb,orient='index', columns=['Shear', 'Stretch', 'Stagger', 'Buckle', 'Propel', 'Opening', 
'Shift_-1', 'Shift_1', 'Slide_-1', 'Slide_1', 'Rise_-1', 'Rise_1','Tilt_-1', 'Tilt_1', 
'Roll_-1', 'Roll_1', 'Twist_-1', 'Twist_1', 'mingw', 'mingd', 'majgw', 'majgd', 
'Shear-SD', 'Stretch-SD', 'Stagger-SD', 'Buckle-SD', 'Propel-SD', 'Opening-SD', 
'Shift-SD', 'Slide-SD', 'Rise-SD', 'Tilt-SD', 'Roll-SD', 'Twist-SD', 'mingw-SD', 
'mingd-SD', 'majgw-SD', 'majgd-SD'])
# print(shape_df)
shape_df['attention_score'] = attention_score
shape_df['attention_score_norm'] = attention_score_norm
# print(shape_df)
sns.set_theme(style="darkgrid")

# sns.pairplot(shape_df);
# plt.title("Attension Score Correlation: \n5-mers vs. Reverse Complements", fontsize=15)
# plt.xlabel("5-mers", fontsize=15);
# plt.ylabel("Reverse complement of 5-mers", fontsize=15);

# ######### ADD X ticks!!!#########
# seqs = []
# rseqs = []
# i = 0
# for k in ordered_map.items():
#     if i %20 ==0:
#         seqs.append(k[0])
#         rseqs.append(reverse_complement(k[0]))
#     i+= 1
# #         r = reverse_complement(k[0])
# print(seqs)
# x = range(0,len(seqs))
# print(x)

#################### Add person correlation annotation ###################
# from scipy import stats
# num = stats.pearsonr(corr['five_mer'], corr['reverse_comp'])[0]**2
# text = "$R^2$ = " + f'{num:.5f}'

# plt.text(80, 110, text, horizontalalignment='left', size='medium', color='black', weight='semibold')

# %%
#################### Add person correlation annotation All Normalized ###################
from scipy import stats
AllDNAshape = ['Shear', 'Stretch', 'Stagger', 'Buckle', 'Propel', 'Opening', 
'Shift_-1', 'Shift_1', 'Slide_-1', 'Slide_1', 'Rise_-1', 'Rise_1',
            'Tilt_-1', 'Tilt_1', 
'Roll_-1', 'Roll_1', 'Twist_-1', 'Twist_1', 'mingw', 'mingd', 'majgw', 'majgd', 
'Shear-SD', 'Stretch-SD', 'Stagger-SD', 'Buckle-SD', 'Propel-SD', 'Opening-SD', 
'Shift-SD', 'Slide-SD', 'Rise-SD', 'Tilt-SD', 'Roll-SD', 'Twist-SD', 'mingw-SD', 
'mingd-SD', 'majgw-SD', 'majgd-SD']
pearson=[]
p_val=[]
all_shape_df = {}
for shape in AllDNAshape:
    cor = stats.pearsonr(shape_df[shape], shape_df['attention_score_norm'])[0]
    pval = stats.pearsonr(shape_df[shape], shape_df['attention_score_norm'])[0]
    r2 = stats.pearsonr(shape_df[shape], shape_df['attention_score_norm'])[0]**2
    all_shape_df[shape] = [cor]
#     pearson.append(cor)
#     p_val.append(pval)
#     print(f"{shape} vs. attention_score | Pearson: {cor:.5f}, P-value {pval:.5f} | R^2: {r2:.5f}")

df = pd.DataFrame.from_dict(all_shape_df, orient='index', columns=['Pearson'])
df["Shapes"] =all_shape_df.keys()

df = df.sort_values(by=['Pearson'])
# df = df.T
df_sorted = df
# print(df_sorted)
shape_ordered = df_sorted.keys()
# f, ax = plt.subplots(figsize=(7, 3))

ax = sns.catplot(y="Shapes",x="Pearson",data=df_sorted, kind="bar", edgecolor=".6", height=10, aspect=.8)
ax.set_axis_labels("Pearson Correlation", "Shapes", fontsize=18)
ax.set_yticklabels(fontsize=12)
ax.set_xticklabels(fontsize=12)

# plt.gcf().set_size_inches(35, 8)

# ax.set_xticklabels(ax.get_xticklabels(),rotation = 30, fontsize=20)
# ax.set_ylim(-0.6, 0.6)
# ax.set_xlabel('Shape', fontsize=33)
# ax.set_ylabel('Attention Score', fontsize=35)
# ax.set_title("Average Shape Attention Score Correlations", fontsize=50)
plt.tight_layout()
plt.savefig( fig_path + 'shape_attention_corr_bar.png', dpi=200)

# %%
#################### Add person correlation annotation ABS SORTED ###################
from scipy import stats
AllDNAshape = ['Shear', 'Stretch', 'Stagger', 'Buckle', 'Propel', 'Opening', 
'Shift_-1', 'Shift_1', 'Slide_-1', 'Slide_1', 'Rise_-1', 'Rise_1',
            'Tilt_-1', 'Tilt_1', 
'Roll_-1', 'Roll_1', 'Twist_-1', 'Twist_1', 'mingw', 'mingd', 'majgw', 'majgd', 
'Shear-SD', 'Stretch-SD', 'Stagger-SD', 'Buckle-SD', 'Propel-SD', 'Opening-SD', 
'Shift-SD', 'Slide-SD', 'Rise-SD', 'Tilt-SD', 'Roll-SD', 'Twist-SD', 'mingw-SD', 
'mingd-SD', 'majgw-SD', 'majgd-SD']
pearson=[]
p_val=[]
all_shape_df = {}
for shape in AllDNAshape:
    cor = stats.pearsonr(shape_df[shape], shape_df['attention_score_norm'])[0]
    pval = stats.pearsonr(shape_df[shape], shape_df['attention_score_norm'])[0]
    r2 = stats.pearsonr(shape_df[shape], shape_df['attention_score_norm'])[0]**2
    all_shape_df[shape] = [abs(cor)]
#     pearson.append(cor)
#     p_val.append(pval)
#     print(f"{shape} vs. attention_score | Pearson: {cor:.5f}, P-value {pval:.5f} | R^2: {r2:.5f}")
df = pd.DataFrame.from_dict(all_shape_df, orient='index', columns=['Pearson']).sort_values(by=['Pearson'])
df = df.T
df_sorted = df
shape_ordered = df_sorted.keys()
ax = sns.barplot(data=df_sorted)
plt.gcf().set_size_inches(35, 8)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 30, fontsize=20)
ax.set_ylim(-0.6, 0.6)
ax.set_xlabel('Shape', fontsize=33)
ax.set_ylabel('Attention Score', fontsize=35)
ax.set_title("Average Shape Attention Score Correlations", fontsize=50)
plt.tight_layout()
plt.savefig( fig_path + 'shape_attention_corr_bar.png', dpi=200)

# %%
#################### Add person correlation annotation - UNNORMALIZED ###################
from scipy import stats
AllDNAshape = ['Shear', 'Stretch', 'Stagger', 'Buckle', 'Propel', 'Opening', 
'Shift_-1', 'Shift_1', 'Slide_-1', 'Slide_1', 'Rise_-1', 'Rise_1',
            'Tilt_-1', 'Tilt_1', 
'Roll_-1', 'Roll_1', 'Twist_-1', 'Twist_1', 'mingw', 'mingd', 'majgw', 'majgd', 
'Shear-SD', 'Stretch-SD', 'Stagger-SD', 'Buckle-SD', 'Propel-SD', 'Opening-SD', 
'Shift-SD', 'Slide-SD', 'Rise-SD', 'Tilt-SD', 'Roll-SD', 'Twist-SD', 'mingw-SD', 
'mingd-SD', 'majgw-SD', 'majgd-SD']
pearson=[]
p_val=[]
all_shape_df = {}
for shape in AllDNAshape:
    cor = stats.pearsonr(shape_df[shape], shape_df['attention_score'])[0]
    pval = stats.pearsonr(shape_df[shape], shape_df['attention_score'])[0]
    r2 = stats.pearsonr(shape_df[shape], shape_df['attention_score'])[0]**2
    all_shape_df[shape] = [cor]
#     pearson.append(cor)
#     p_val.append(pval)
#     print(f"{shape} vs. attention_score | Pearson: {cor:.5f}, P-value {pval:.5f} | R^2: {r2:.5f}")
df = pd.DataFrame.from_dict(all_shape_df, orient='index', columns=['Pearson']).sort_values(by=['Pearson'])
df = df.T
df_sorted = df
shape_ordered = df_sorted.keys()
ax = sns.barplot(data=df_sorted)
plt.gcf().set_size_inches(35, 8)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 30, fontsize=20)
ax.set_ylim(-0.6, 0.6)
ax.set_xlabel('Shape', fontsize=35)
ax.set_ylabel('Attention Score', fontsize=35)
ax.set_title("Accumulative Shape Attention Score Correlations", fontsize=50)
plt.tight_layout()
plt.savefig( fig_path + 'accum_shape_attention_corr_bar.png', dpi=200)

# %%
shape_ordered
# Out:
# Index(['mingw', 'Propel', 'Roll_1', 'Opening', 'majgw', 'Tilt_-1', 'Stagger',
#        'Roll_-1', 'majgd', 'majgd-SD', 'Shift-SD', 'Slide-SD', 'Shear',
#        'Shift_1', 'majgw-SD', 'Rise_1', 'Tilt-SD', 'Shift_-1', 'Buckle-SD',
#        'Slide_1', 'Tilt_1', 'Buckle', 'Rise_-1', 'Twist_1', 'Twist-SD',
#        'Slide_-1', 'Roll-SD', 'Twist_-1', 'Rise-SD', 'Shear-SD', 'Stagger-SD',
#        'Propel-SD', 'Stretch-SD', 'Opening-SD', 'mingd-SD', 'Stretch',
#        'mingw-SD', 'mingd'],
#       dtype='object')

# %%
idx = pearson.index(max(pearson))
s = AllDNAshape[idx]
m = max(pearson)
print(idx)
p = p_val[idx]
print(f"Most correlated shape is {s} with Pearson: {m:.5f}, P-value {p:.5f}")
# Out:
# 27
# Most correlated shape is Opening-SD with Pearson: 0.56974, P-value 0.56974

# %% [markdown]
# # 3. Bar plots separting 0 & 1

# %%
# # if you are using batches the outputs will be in batches
# # get exact attentions of chars
# from IPython.display import display
# mapped_add = {}

# for seq in range(len(attention_outputs)):
# # for seq in range(1,5):
    
#     # tokens are the 5mers in the current sequence
#     tokens = tokenize(ReverseOneHotEncode(d[seq]))
    
#     # for 147bp each sequence, there are 320 feature scores for each bp
#     for i in range(len(tokens)):
#         token = tokens[i]
#         five_mer_attention_output = sum(attention_outputs[seq][i])
#         if token in mapped_add.keys():  # if a 5mer is found
#             mapped_add[token] = mapped_add[token] + five_mer_attention_output #increase value
#             mapped_add[reverse_complement(token)] = mapped_add[token] #set the reverse compliement value to the same
        
#         # if a 5mer's reverse complement is found
#         elif reverse_complement(token) in mapped_add.keys():
#             mapped_add[reverse_complement(token)] = mapped_add[reverse_complement(token)] + five_mer_attention_output
#             mapped_add[token] = mapped_add[reverse_complement(token)] #set the original 5mer value to the same
        
#         #if 5mer not seen yet
#         else: 
#             mapped_add[token] = five_mer_attention_output
#             mapped_add[reverse_complement(token)] = mapped_add[token]
# #     char_df = plot_attention_from_seq(tokens, mapped[token])
# #     display(char_df)

# # Plot the mapped dictionary for each 5 mer; Darker means higher attention score
# import collections
# ordered_map_add = collections.OrderedDict(sorted(mapped_add.items()))
# # char_df = plot_attention_from_map(mapped_add)
# # display(char_df)
# # char_df = plot_attention_from_map(ordered_map_add)
# # display(char_df)

# %%
################################### Correlation plots for DNA shape ###################################
import seaborn as sns
import matplotlib.pyplot

# use added reverse complement score way
attention_score_norm0 = []
attention_score_norm1 = []

for k in tb.items(): # set values to the 5mer order as seen in tb
#     attention_score.append(ordered_map_add_norm0[k[0]]) 
    attention_score_norm0.append(ordered_map_add_norm0[k[0]])
    attention_score_norm1.append(ordered_map_add_norm1[k[0]]) 
# print(attention_score_norm0)
# print(attention_score_norm1)
shape_df =  pd.DataFrame.from_dict(tb,orient='index', columns=['Shear', 'Stretch', 'Stagger', 'Buckle', 'Propel', 'Opening', 
'Shift_-1', 'Shift_1', 'Slide_-1', 'Slide_1', 'Rise_-1', 'Rise_1','Tilt_-1', 'Tilt_1', 
'Roll_-1', 'Roll_1', 'Twist_-1', 'Twist_1', 'mingw', 'mingd', 'majgw', 'majgd', 
'Shear-SD', 'Stretch-SD', 'Stagger-SD', 'Buckle-SD', 'Propel-SD', 'Opening-SD', 
'Shift-SD', 'Slide-SD', 'Rise-SD', 'Tilt-SD', 'Roll-SD', 'Twist-SD', 'mingw-SD', 
'mingd-SD', 'majgw-SD', 'majgd-SD'])
# print(shape_df)
shape_df['attention_score'] = attention_score
shape_df['attention_score_norm0'] = attention_score_norm0
shape_df['attention_score_norm1'] = attention_score_norm1

# print(shape_df)
sns.set_theme(style="darkgrid")

#################### Add person correlation annotation All Normalized ###################
def plotAttention(whichAttention, shape_order):
    from scipy import stats
    AllDNAshape = ['Shear', 'Stretch', 'Stagger', 'Buckle', 'Propel', 'Opening', 
    'Shift_-1', 'Shift_1', 'Slide_-1', 'Slide_1', 'Rise_-1', 'Rise_1',
                'Tilt_-1', 'Tilt_1', 
    'Roll_-1', 'Roll_1', 'Twist_-1', 'Twist_1', 'mingw', 'mingd', 'majgw', 'majgd', 
    'Shear-SD', 'Stretch-SD', 'Stagger-SD', 'Buckle-SD', 'Propel-SD', 'Opening-SD', 
    'Shift-SD', 'Slide-SD', 'Rise-SD', 'Tilt-SD', 'Roll-SD', 'Twist-SD', 'mingw-SD', 
    'mingd-SD', 'majgw-SD', 'majgd-SD']
    
    all_shape_df = {}
    for shape in AllDNAshape:
        cor = stats.pearsonr(shape_df[shape], shape_df[whichAttention])[0]
        pval = stats.pearsonr(shape_df[shape], shape_df[whichAttention])[0]
        r2 = stats.pearsonr(shape_df[shape], shape_df[whichAttention])[0]**2
        all_shape_df[shape] = [cor]

    #     print(f"{shape} vs. attention_score | Pearson: {cor:.5f}, P-value {pval:.5f} | R^2: {r2:.5f}")

    df = pd.DataFrame.from_dict(all_shape_df, orient='index', columns=['Pearson'])
    df["Shapes"] =all_shape_df.keys()

    df = df.sort_values(by=['Pearson'])
    # df = df.T
    df_sorted = df
    if (whichAttention == 'attention_score'):
#         print(df_sorted)
        shape_ordered = df_sorted['Shapes']
    else:
        for s in range(shape_order):
            df.loc[shape_order[s], 'order'] = s
    print(df)
        

#     ax = sns.catplot(y="Shapes",x="Pearson",data=df_sorted, kind="bar", edgecolor=".6", height=10, aspect=.8)
#     ax.set_axis_labels("Pearson Correlation", "Shapes", fontsize=18)
#     ax.set_yticklabels(fontsize=12)
#     ax.set_xticklabels(fontsize=12)

#     plt.tight_layout()
#     plt.title(whichAttention)
#     plt.savefig( fig_path + whichAttention + '.png', dpi=200, bbox_inches='tight')
    return shape_ordered
shape_ordered = plotAttention('attention_score', [])
plotAttention('attention_score_norm0', shape_ordered)
plotAttention('attention_score_norm1', shape_ordered)
# Out:
#              Pearson      Shapes
# Propel     -0.451022      Propel
# Opening    -0.437368     Opening
# majgw      -0.335533       majgw
# mingw      -0.321877       mingw
# Stagger    -0.242639     Stagger
# Roll_1     -0.155377      Roll_1
# majgd-SD   -0.154555    majgd-SD
# Roll_-1    -0.089666     Roll_-1
# Rise_-1    -0.083502     Rise_-1
# Tilt_-1    -0.064891     Tilt_-1
# majgw-SD   -0.044406    majgw-SD
# Rise_1     -0.043504      Rise_1
# majgd      -0.029386       majgd
# Tilt_1     -0.029200      Tilt_1
# Shift_-1   -0.011211    Shift_-1
# Shift_1     0.014743     Shift_1
# Tilt-SD     0.020936     Tilt-SD
# Shift-SD    0.022258    Shift-SD
# Twist-SD    0.037556    Twist-SD
# Shear       0.049900       Shear
# Slide-SD    0.101336    Slide-SD
# Buckle-SD   0.133452   Buckle-SD
# Rise-SD     0.142454     Rise-SD
# Roll-SD     0.184125     Roll-SD
# Buckle      0.204678      Buckle
# Twist_1     0.205825     Twist_1
# Twist_-1    0.215265    Twist_-1
# Slide_1     0.261737     Slide_1
# Shear-SD    0.321661    Shear-SD
# Slide_-1    0.324422    Slide_-1
# Stretch     0.375545     Stretch
# mingd-SD    0.376687    mingd-SD
# Propel-SD   0.379267   Propel-SD
# Stretch-SD  0.416668  Stretch-SD
# Stagger-SD  0.512497  Stagger-SD
# mingd       0.521526       mingd
# mingw-SD    0.522396    mingw-SD
# Opening-SD  0.569737  Opening-SD
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4904/2472816805.py in <module>
#      72     return shape_ordered
#      73 shape_ordered = plotAttention('attention_score', [])
# ---> 74 plotAttention('attention_score_norm0', shape_ordered)
#      75 plotAttention('attention_score_norm1', shape_ordered)
#
# /tmp/ipykernel_4904/2472816805.py in plotAttention(whichAttention, shape_order)
#      57         shape_ordered = df_sorted['Shapes']
#      58     else:
# ---> 59         for s in range(shape_order):
#      60             df.loc[shape_order[s], 'order'] = s
#      61     print(df)
#
# TypeError: 'Series' object cannot be interpreted as an integer

# %%
shape_df
# Out:
#        Shear  Stretch  Stagger  Buckle  Propel  Opening  Shift_-1  Shift_1  \
# AAAAA   0.18     0.03    -0.22    7.80  -16.51    -3.71     -0.20    -0.08
# AAAAC   0.15    -0.01    -0.06    9.07  -14.47    -1.90     -0.11     0.13
# AAAAG   0.17     0.01    -0.13    7.39  -14.68    -2.30     -0.11     0.20
# AAAAT   0.17    -0.01    -0.10    7.97  -14.89    -2.05     -0.05     0.11
# AAACA   0.15    -0.01     0.13   11.53  -13.05    -1.30      0.00     0.50
# ...      ...      ...      ...     ...     ...      ...       ...      ...
# TGCCA   0.27    -0.03     0.11   -1.54   -2.98     0.21     -0.03    -0.10
# TGGAA  -0.29    -0.04    -0.01    0.12   -5.20     0.25      0.06    -0.27
# TGTAA  -0.11    -0.03     0.12   -0.58   -7.55    -1.07     -0.23    -0.08
# TTAAA   0.12    -0.00    -0.16    0.32  -10.70    -1.68     -0.04    -0.23
# TTCAA   0.27    -0.04     0.06    0.29   -5.98     0.21      0.30    -0.43
#
#        Slide_-1  Slide_1  ...  Rise-SD  Tilt-SD  Roll-SD  Twist-SD  mingw-SD  \
# AAAAA     -0.97    -0.99  ...     0.05     0.68     2.77      0.99      0.96
# AAAAC     -1.01    -1.11  ...     0.04     0.41     2.31      0.69      0.71
# AAAAG     -1.05    -1.23  ...     0.04     0.51     2.25      0.75      0.61
# AAAAT     -1.08    -1.22  ...     0.06     0.42     2.20      0.67      0.58
# AAACA     -1.06    -1.54  ...     0.14     0.99     1.99      0.93      0.69
# ...         ...      ...  ...      ...      ...      ...       ...       ...
# TGCCA     -1.58    -1.71  ...     0.05     0.50     0.59      1.64      0.24
# TGGAA     -1.77    -1.48  ...     0.03     0.66     0.71      1.20      0.17
# TGTAA     -1.50    -1.29  ...     0.04     0.68     4.29      0.71      0.28
# TTAAA     -1.09    -1.05  ...     0.13     0.51     4.52      0.73      0.50
# TTCAA     -1.46    -1.09  ...     0.03     2.18     2.78      0.62      0.25
#
#        mingd-SD  majgw-SD  majgd-SD  attention_score_norm0  \
# AAAAA      0.18      0.48      0.69               0.396772
# AAAAC      0.16      0.36      0.92               0.407259
# AAAAG      0.11      0.37      0.83               0.401587
# AAAAT      0.11      0.37      0.60               0.404569
# AAACA      0.19      0.33      0.56               0.404889
# ...         ...       ...       ...                    ...
# TGCCA      0.09      0.45      1.54               0.408109
# TGGAA      0.08      0.49      1.87               0.406815
# TGTAA      0.14      0.61      1.23               0.402553
# TTAAA      0.09      0.20      0.33               0.404032
# TTCAA      0.09      0.20      0.27               0.403359
#
#        attention_score_norm1
# AAAAA               0.429359
# AAAAC               0.434799
# AAAAG               0.437382
# AAAAT               0.432927
# AAACA               0.432756
# ...                      ...
# TGCCA               0.430269
# TGGAA               0.432700
# TGTAA               0.426952
# TTAAA               0.437850
# TTCAA               0.433198
#
# [512 rows x 40 columns]

# %%
df
# Out:
#              Pearson      Shapes
# mingw      -0.314378       mingw
# Propel     -0.228836      Propel
# Roll_1     -0.223089      Roll_1
# Opening    -0.181657     Opening
# majgw      -0.138555       majgw
# Tilt_-1    -0.115469     Tilt_-1
# Stagger    -0.101201     Stagger
# Roll_-1    -0.069916     Roll_-1
# majgd      -0.055681       majgd
# majgd-SD   -0.055463    majgd-SD
# Shift-SD   -0.027390    Shift-SD
# Slide-SD   -0.025895    Slide-SD
# Shear      -0.011712       Shear
# Shift_1     0.005715     Shift_1
# majgw-SD    0.007970    majgw-SD
# Rise_1      0.010008      Rise_1
# Tilt-SD     0.029515     Tilt-SD
# Shift_-1    0.043319    Shift_-1
# Buckle-SD   0.048839   Buckle-SD
# Slide_1     0.057480     Slide_1
# Tilt_1      0.062603      Tilt_1
# Buckle      0.065227      Buckle
# Rise_-1     0.066955     Rise_-1
# Twist_1     0.076119     Twist_1
# Twist-SD    0.118340    Twist-SD
# Slide_-1    0.123307    Slide_-1
# Roll-SD     0.131852     Roll-SD
# Twist_-1    0.139379    Twist_-1
# Rise-SD     0.149319     Rise-SD
# Shear-SD    0.164408    Shear-SD
# Stagger-SD  0.171404  Stagger-SD
# Propel-SD   0.177444   Propel-SD
# Stretch-SD  0.183685  Stretch-SD
# Opening-SD  0.247622  Opening-SD
# mingd-SD    0.262445    mingd-SD
# Stretch     0.292527     Stretch
# mingw-SD    0.355194    mingw-SD
# mingd       0.402502       mingd
